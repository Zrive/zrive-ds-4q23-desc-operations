# %% [markdown]
# # Fase 1.- Google Search Engine
#
# *Creamos la cuenta y el buscador en GoogleCloud. Solo 100 API calls/dia. Se ha activado búsqueda segura*

# %%
from credentials import API_KEY, Search_Engine_ID

# %% [markdown]
# La siguientes fucniones hacen una query y exploran el contenido de los N primeros links de una busqueda y appendan la informacion relevante en un excel (incluyendo cierta metadata). Muy interesante para posterior scrapping

# %%
import requests
import pandas as pd
import re

def build_payload(API_KEY, cx, query, start=1, num=10, date_restrict='m1', **params):
    """
    Construye el payload necesario para realizar la solicitud a la API de Google Custom Search.

    Parameters:
    - api_key (str): La clave de API de Google Custom Search.
    - cx (str): El identificador de búsqueda personalizado.
    - query (str): La cadena de búsqueda.

    Returns:
    - dict: El payload para la solicitud.
    """
    payload = {
        'key': API_KEY,
        'q':query,
        'cx': cx,
        'num': num,
        'dateRestrict': date_restrict
    }
    payload.update(params)
    return payload

def make_request(url, payload):
    """
    Realiza la solicitud a la API y maneja posibles errores.

    Parameters:
    - url (str): La URL de la API.
    - payload (dict): El payload de la solicitud.

    Returns:
    - dict: La respuesta de la API en formato JSON.
    """
    try:
        response = requests.get(url, params=payload)
        response.raise_for_status()  # Verifica si hay errores en la respuesta HTTP
        return response.json()
    except requests.exceptions.HTTPError as errh:
        print(f"HTTP Error: {errh}")
    except requests.exceptions.ConnectionError as errc:
        print(f"Error de conexión: {errc}")
    except requests.exceptions.Timeout as errt:
        print(f"Tiempo de espera agotado: {errt}")
    except requests.exceptions.RequestException as err:
        print(f"Error desconocido: {err}")

def clean_filename(filename):
    filename = re.sub(r'[\\/*?:<>|]', "", filename)
    return filename

def main(query, result_total=10):
    url = "https://www.googleapis.com/customsearch/v1"
    items =[]
    reminder = result_total
    if reminder > 0:
        pages = (result_total // 10) + 1
    else:
        pages = result_total // 10 
    
    for i in range(pages    ):
        if pages == i + 1 and reminder > 0:
            payload = build_payload(API_KEY=API_KEY, cx=Search_Engine_ID, query=query, start=(i+1)*10, num=reminder)
        else:
            payload = build_payload(API_KEY=API_KEY, cx=Search_Engine_ID, query=query, start=(i+1)*10)
        response = make_request(url=url, payload=payload)
        items.extend(response['items'])
    query_string_clean = clean_filename(query)
    df = pd.json_normalize(items)
    df.to_excel('Google Result_{0}.xlsx'.format(query_string_clean), index =False)

# %%
import requests
def build_payload(API_KEY, cx, query, **params):
    """
    Construye el payload necesario para realizar la solicitud a la API de Google Custom Search.

    Parameters:
    - api_key (str): La clave de API de Google Custom Search.
    - cx (str): El identificador de búsqueda personalizado.
    - query (str): La cadena de búsqueda.

    Returns:
    - dict: El payload para la solicitud.
    """
    payload = {
        'key': API_KEY,
        'q':query,
        'cx': cx,
    }
    payload.update(params)
    return payload

def get_google_summary(API_KEY, cx, query):
    """
    Obtiene el objeto 'resumen' de Google Search para una búsqueda dada.

    Parameters:
    - api_key (str): La clave de API de Google Custom Search.
    - cx (str): El identificador de búsqueda personalizado.
    - query (str): La cadena de búsqueda.

    Returns:
    - str: El texto resumen de la entradilla o un mensaje indicando que no hay resumen.
    """
    url = "https://www.googleapis.com/customsearch/v1"
    payload = build_payload(API_KEY= API_KEY, cx= cx, query=query)
    
    response_json = make_request(url, payload)

    if response_json and 'items' in response_json:
        # Verifica si hay un resumen disponible en los resultados de la búsqueda
        first_result = response_json['items'][0]
        if 'snippet' in first_result:
            return first_result['snippet']
    
    return 'Item not summarized by google search engine'

# # Uso de las funciones
# query = 'f1 2012'

# resumen = get_google_summary(API_KEY, Search_Engine_ID, query)
# print(resumen)

# %% [markdown]
# Comento las lineas resultado, pero basicamente lo que me esta devolviendo es un resumen de cada link (Snippet es un atributo ya parseado de google que resumen el contenido del link i-essimo). Es una opcion a considerear para la fase1-Scrapping:
#
# - https://cloud.google.com/generative-ai-app-builder/docs/snippets
#
# Parece que la funcion no eta devolviendo los links 'normales' al hacer una busqueda, sino que se esta redirigiendo a la categoria 'Comparation Sites'. No he podido obtener mucha info de esta categoria (es como la categoria imagenes, videos al hacer una busqueda). Parece retornar links que podrian resultar de interes/links promocionados (?). Desde luego no son las entradas que nos interesan

# %% [markdown]
# Voy a fraccionar la busqueda para inspeccionar mejor los resultados

# %%
query = 'f1 2012' # Para este caso esta comprobadoq ue si hay entradilla, quermos ver como parsear el texto resumen
url = "https://www.googleapis.com/customsearch/v1"
payload = build_payload(API_KEY= API_KEY, cx= Search_Engine_ID, query=query)

response_json = make_request(url, payload)

# %%
import json
print(response_json.keys())
print(response_json['items'][0])
#print(json.dumps(response_json, indent=2))
# Out:
# dict_keys(['kind', 'url', 'queries', 'context', 'searchInformation', 'items'])
# {'kind': 'customsearch#result', 'title': 'Norris Mexico GP "masterpiece" reminded Stella of Alonso\'s F1 ...', 'htmlTitle': 'Norris Mexico GP &quot;masterpiece&quot; reminded Stella of Alonso&#39;s <b>F1</b> ...', 'link': 'https://us.motorsport.com/f1/news/norris-mexico-gp-masterpiece-reminded-stella-of-alonsos-f1-valencia-2012-win/10540384/', 'displayLink': 'us.motorsport.com', 'snippet': 'Oct 30, 2023 ... McLaren Formula 1 team principal Andrea Stella has compared Lando Norris\' "masterpiece" Mexico Grand Prix drive to Fernando Alonso\'s iconic 2012 win for Ferrari\xa0...', 'htmlSnippet': 'Oct 30, 2023 <b>...</b> McLaren <b>Formula 1</b> team principal Andrea Stella has compared Lando Norris&#39; &quot;masterpiece&quot; Mexico Grand Prix drive to Fernando Alonso&#39;s iconic <b>2012</b> win for Ferrari&nbsp;...', 'cacheId': 'NUMlVG_q-lEJ', 'formattedUrl': 'https://us.motorsport.com/f1/news/norris-mexico...f1...2012.../10540384/', 'htmlFormattedUrl': 'https://us.motorsport.com/<b>f1</b>/news/norris-mexico...<b>f1</b>...<b>2012</b>.../10540384/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTQ_Na_HI95OSYlbmG15ilkePVzPZi--nriMFAifg9Lwxs59ngcsBdFX_1v', 'width': '275', 'height': '183'}], 'metatags': [{'og:image': 'https://cdn-2.motorsport.com/images/amp/254NPgD0/s6/lando-norris-mclaren-mcl60-fer.jpg', 'apple-itunes-app': 'app-id=1459863859', 'og:type': 'article', 'og:image:width': '1200', 'twitter:card': 'summary_large_image', 'og:title': "Norris Mexico GP &quot;masterpiece&quot; reminded Stella of Alonso's F1 Valencia 2012 win", 'og:image:height': '800', 'fb:pages': '263938209441', 'fb:app_id': '1017388998271288', 'viewport': 'width=device-width, initial-scale=1', 'fb:admins': '100001157785488', 'alexaverifyid': 'bVEzjJq-W0PC2QTcmK4a8fz6__k', 'og:url': 'https://www.motorsport.com/f1/news/norris-mexico-gp-masterpiece-reminded-stella-of-alonsos-f1-valencia-2012-win/10540383/', 'google-play-app': 'app-id=com.motorsport.application', 'datepublished': '2023-10-30T15:42:48Z', 'pubdate': '20231030'}], 'cse_image': [{'src': 'https://cdn-2.motorsport.com/images/amp/254NPgD0/s6/lando-norris-mclaren-mcl60-fer.jpg'}]}}

# %% [markdown]
# Confirmamos que Snippet ofrece un resumen de cada link. Manualmente al hacer la busqueda sore 'f1 2012' no me aparecen como primeros links los de este resultado. Falta profundizar el porque. Vamos a probar a acotar mas los parametros de busqueda y a scrapear el html, ya que parece que el texto resumen (muchas veces ligado al resuemn de wikipedia) que ofrece google es un header 3 (h3) con el nombre de 'Descripcion'

# %%
def build_payload(api_key, cx, query, language='en'):
    payload = {
        'key': api_key,
        'cx': cx,
        'q': query,
        'lr': f'lang_{language}',  # Filtro para buscar solo en el idioma especificado
        'fileType': 'html',  # Obtiene el contenido en formato HTML
    }
    return payload

# %%
def get_google_summary(api_key, cx, query):

    api_url = "https://www.googleapis.com/customsearch/v1"
    payload = build_payload(api_key, cx, query)
    
    response_json = make_request(api_url, payload)

    if response_json and 'items' in response_json:
        # Verifica si hay un resumen disponible en los resultados de la búsqueda
        first_result = response_json['items'][0]
        if 'snippet' in first_result:
            snippet_text = first_result['snippet']

            # Intenta extraer el texto descriptivo de Wikipedia si está presente
            start_index = snippet_text.find('<span class="description">')
            end_index = snippet_text.find('</span>', start_index)
            if start_index != -1 and end_index != -1:
                wikipedia_description = snippet_text[start_index + len('<span class="description">'):end_index]
                return wikipedia_description

    return 'Item not summarized by google search engine'

# Uso de las funciones
query = 'Max Verstappen'

resumen = get_google_summary(api_key=API_KEY, cx=Search_Engine_ID, query=query)
print(resumen)
# Out:
# Item not summarized by google search engine

# %%
def build_payload(api_key, cx, query):
    payload = {
        'key': api_key,
        'cx': cx,
        'q': query,
        'fileType': 'html'
    }
    return payload

# %%
url = "https://www.googleapis.com/customsearch/v1"
payload = build_payload(api_key= API_KEY, cx= Search_Engine_ID, query='Max Verstappen')

response_json = make_request(url, payload)

# %%
for i in range(0,10):
    if 'items' in response_json:
        print(response_json['items'][i])
# Out:
# {'kind': 'customsearch#result', 'title': 'Max Verstappen - F1 Driver for Red Bull Racing', 'htmlTitle': '<b>Max Verstappen</b> - F1 Driver for Red Bull Racing', 'link': 'https://www.formula1.com/en/drivers/max-verstappen.html', 'displayLink': 'www.formula1.com', 'snippet': "Formula 1's youngest ever competitor – and now its reigning, two-time world champion. Say hello to Max Verstappen.", 'htmlSnippet': 'Formula 1&#39;s youngest ever competitor – and now its reigning, two-time world champion. Say hello to <b>Max Verstappen</b>.', 'cacheId': '15G_j1uI8W4J', 'formattedUrl': 'https://www.formula1.com/en/drivers/max-verstappen.html', 'htmlFormattedUrl': 'https://www.formula1.com/en/drivers/<b>max</b>-<b>verstappen</b>.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTYep9-kxs1FG_YjCNoLiMIIpdVi2f6IjoCthA6lGCzdRiodgQZ-2a9R3PV', 'width': '225', 'height': '225'}], 'website': [{'image': 'https://media.formula1.com/content/dam/fom-website/drivers/2023Drivers/verstappen.jpg.img.1536.high.jpg', 'name': 'Max Verstappen - F1 Driver for Red Bull Racing', 'description': "Formula 1's youngest ever competitor – and now its reigning, two-time world champion. Say hello to Max Verstappen."}], 'metatags': [{'apple-itunes-app': 'app-id=835022598, app-argument=http://www.formula1.com', 'og:image': 'https://media.formula1.com/content/dam/fom-website/drivers/2023Drivers/verstappen.jpg.img.1536.high.jpg', 'theme-color': '#000000', 'og:type': 'website', 'twitter:card': 'summary_large_image', 'twitter:title': 'Max Verstappen - F1 Driver for Red Bull Racing', 'og:site_name': 'Formula 1® - The Official F1® Website', 'og:title': 'Max Verstappen - F1 Driver for Red Bull Racing', 'fb:pages': '568665409957112', 'og:description': "Formula 1's youngest ever competitor – and now its reigning, two-time world champion. Say hello to Max Verstappen.", 'twitter:creator': '@f1', 'twitter:image': 'https://www.formula1.com/content/dam/fom-website/drivers/2023Drivers/verstappen.jpg.img.1024.medium.jpg', 'fb:app_id': '833421847009900', 'twitter:site': '@f1', 'viewport': 'width=device-width, initial-scale=1', 'twitter:description': "Formula 1's youngest ever competitor – and now its reigning, two-time world champion. Say hello to Max Verstappen.", 'fb:admins': '568665409957112', 'og:url': '/en/drivers/max-verstappen.html', 'twitter:widgets:theme': 'light', 'twitter:widgets:link-color': '#d31411', 'twitter:widgets:border-color': '#ffffff'}], 'cse_image': [{'src': 'https://media.formula1.com/content/dam/fom-website/drivers/2023Drivers/verstappen.jpg.img.1536.high.jpg'}]}}
# {'kind': 'customsearch#result', 'title': "Las Vegas Grand Prix: 'Viva Las Vegas,' sings Max Verstappen as ...", 'htmlTitle': 'Las Vegas Grand Prix: &#39;Viva Las Vegas,&#39; sings <b>Max Verstappen</b> as ...', 'link': 'https://www.cnn.com/2023/11/19/sport/las-vegas-grand-prix-max-verstappen-spt-intl/index.html', 'displayLink': 'www.cnn.com', 'snippet': "4 days ago ... 'Viva Las Vegas,' sings Max Verstappen as he wins thrilling race. By Aimee Lewis, CNN. 3 minute read. Published 6:08 AM\xa0...", 'htmlSnippet': '4 days ago <b>...</b> &#39;Viva Las Vegas,&#39; sings <b>Max Verstappen</b> as he wins thrilling race. By Aimee Lewis, CNN. 3 minute read. Published 6:08 AM&nbsp;...', 'formattedUrl': 'https://www.cnn.com/2023/11/19/sport/las...max-verstappen.../index.html', 'htmlFormattedUrl': 'https://www.cnn.com/2023/11/19/sport/las...<b>max</b>-<b>verstappen</b>.../index.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRDZ6gJBg1Nz7ELf2bqyTPz5qTbhNi5QQMZ-DobUfGdMmeu7F2j2IgxYQ', 'width': '143', 'height': '80'}], 'metatags': [{'og:image': 'https://media.cnn.com/api/v1/images/stellar/prod/2023-11-19t080142z-680844850-up1ejbj0mar55-rtrmadp-3-motor-f1-lasvegas.JPG?c=16x9&q=w_800,c_fill', 'twitter:title': '‘Viva Las Vegas,’ sings Max Verstappen as he wins thrilling race | CNN', 'og:type': 'article', 'twitter:card': 'summary_large_image', 'article:published_time': '2023-11-19T11:08:01.553Z', 'og:site_name': 'CNN', 'author': 'Aimee Lewis', 'og:title': '‘Viva Las Vegas,’ sings Max Verstappen as he wins thrilling race | CNN', 'meta-section': 'sport', 'type': 'article', 'og:description': 'After spending much of the build-up to the Las Vegas Grand Prix making it clear he was unenthused by the event, Max Verstappen decided it was time for a little less conversation and a little more action on Saturday as he did what he does best – winning Formula One races.', 'twitter:image': 'https://media.cnn.com/api/v1/images/stellar/prod/2023-11-19t080142z-680844850-up1ejbj0mar55-rtrmadp-3-motor-f1-lasvegas.JPG?c=16x9&q=w_800,c_fill', 'article:publisher': 'https://www.facebook.com/CNN', 'fb:app_id': '80401312489', 'twitter:site': '@CNNSport', 'article:modified_time': '2023-11-19T11:08:01.553Z', 'viewport': 'width=device-width,initial-scale=1,shrink-to-fit=no', 'twitter:description': 'After spending much of the build-up to the Las Vegas Grand Prix making it clear he was unenthused by the event, Max Verstappen decided it was time for a little less conversation and a little more action on Saturday as he did what he does best – winning Formula One races.', 'template_type': 'article_leaf', 'theme': 'sport', 'og:url': 'https://www.cnn.com/2023/11/19/sport/las-vegas-grand-prix-max-verstappen-spt-intl/index.html'}], 'cse_image': [{'src': 'https://media.cnn.com/api/v1/images/stellar/prod/2023-11-19t080142z-680844850-up1ejbj0mar55-rtrmadp-3-motor-f1-lasvegas.JPG?c=16x9&q=w_800,c_fill'}]}}
# {'kind': 'customsearch#result', 'title': '2023 Driver Standings', 'htmlTitle': '2023 Driver Standings', 'link': 'https://www.formula1.com/en/results/driver-standings.html', 'displayLink': 'www.formula1.com', 'snippet': 'Pos, Driver, Nationality, Car, PTS. 1, Max Verstappen VER, NED, Red Bull Racing Honda RBPT, 549. 2, Sergio Perez PER, MEX, Red Bull Racing Honda RBPT, 273.', 'htmlSnippet': 'Pos, Driver, Nationality, Car, PTS. 1, <b>Max Verstappen</b> VER, NED, Red Bull Racing Honda RBPT, 549. 2, Sergio Perez PER, MEX, Red Bull Racing Honda RBPT, 273.', 'cacheId': 'ZE6QE_un5NUJ', 'formattedUrl': 'https://www.formula1.com/en/results/driver-standings.html', 'htmlFormattedUrl': 'https://www.formula1.com/en/results/driver-standings.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSkvxVG_FIMJMTMB_LVCurLH3qEH_qhjoiQyo5zVsOjfmu9YdBfyJTbhP0', 'width': '300', 'height': '168'}], 'website': [{'image': '/etc/designs/fom-website/social/f1-default-share.jpg', 'name': 'Results', 'description': 'Results'}], 'metatags': [{'apple-itunes-app': 'app-id=835022598, app-argument=http://www.formula1.com', 'og:image': '/etc/designs/fom-website/social/f1-default-share.jpg', 'theme-color': '#000000', 'og:type': 'website', 'twitter:card': 'summary_large_image', 'twitter:title': 'Results', 'og:site_name': 'Formula 1® - The Official F1® Website', 'og:title': 'Results', 'fb:pages': '568665409957112', 'og:description': 'Results', 'twitter:creator': '@f1', 'twitter:image': 'https://www.formula1.com/etc/designs/fom-website/social/f1-default-share.jpg', 'fb:app_id': '833421847009900', 'twitter:site': '@f1', 'viewport': 'width=device-width, initial-scale=1', 'twitter:description': 'Results', 'fb:admins': '568665409957112', 'og:url': '/en/results.html', 'twitter:widgets:theme': 'light', 'twitter:widgets:link-color': '#d31411', 'twitter:widgets:border-color': '#ffffff'}], 'cse_image': [{'src': 'https://www.formula1.com/etc/designs/fom-website/social/f1-default-share.jpg'}]}}
# {'kind': 'customsearch#result', 'title': 'Max Verstappen wins chaotic Australian Grand Prix as Lewis ...', 'htmlTitle': '<b>Max Verstappen</b> wins chaotic Australian Grand Prix as Lewis ...', 'link': 'https://www.cnn.com/2023/04/02/motorsport/max-verstappen-lewis-hamilton-australian-grand-prix-spt-intl/index.html', 'displayLink': 'www.cnn.com', 'snippet': 'Apr 2, 2023 ... Reigning world champion Max Verstappen won the Australian Grand Prix as Lewis Hamilton finished second in an incident-packed race in\xa0...', 'htmlSnippet': 'Apr 2, 2023 <b>...</b> Reigning world champion <b>Max Verstappen</b> won the Australian Grand Prix as Lewis Hamilton finished second in an incident-packed race in&nbsp;...', 'formattedUrl': 'https://www.cnn.com/2023/04/02/.../max-verstappen-lewis.../index.html', 'htmlFormattedUrl': 'https://www.cnn.com/2023/04/02/.../<b>max</b>-<b>verstappen</b>-lewis.../index.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkfouAYlZfLjRlmN9pgwnOTJ79URmdqNBJ7WVDUSjDVKsskGsO4dXPGN8', 'width': '300', 'height': '168'}], 'metatags': [{'og:image': 'https://media.cnn.com/api/v1/images/stellar/prod/230402042819-01-australian-gp-040223.jpg?c=16x9&q=w_800,c_fill', 'twitter:title': 'Max Verstappen wins chaotic Australian Grand Prix as Lewis Hamilton takes second | CNN', 'og:type': 'article', 'twitter:card': 'summary_large_image', 'article:published_time': '2023-04-02T09:21:50Z', 'og:site_name': 'CNN', 'author': 'Aimee Lewis', 'og:title': 'Max Verstappen wins chaotic Australian Grand Prix as Lewis Hamilton takes second | CNN', 'meta-section': 'sport', 'type': 'article', 'og:description': 'Reigning world champion Max Verstappen won the Australian Grand Prix as Lewis Hamilton finished second in an incident-packed race in Melbourne on Sunday.', 'twitter:image': 'https://media.cnn.com/api/v1/images/stellar/prod/230402042819-01-australian-gp-040223.jpg?c=16x9&q=w_800,c_fill', 'article:publisher': 'https://www.facebook.com/CNN', 'article:tag': 'accidents, disasters and safety, australian grand prix, auto racing, automotive industry, automotive safety, brand safety-nsf products and consumers negative, brand safety-nsf sensitive, business and industry sectors, business, economy and trade, formula one, iab-auto racing, iab-auto safety, iab-automotive, iab-automotive industry, iab-business and finance, iab-industries, iab-sports, lewis hamilton, max verstappen, motor sports organizations, motorsports, motorsports events, product safety, safety issues and practices, sports and recreation, sports events, sports figures, sports organizations and teams', 'fb:app_id': '80401312489', 'twitter:site': '@CNNSport', 'article:modified_time': '2023-04-02T10:09:15Z', 'viewport': 'width=device-width,initial-scale=1,shrink-to-fit=no', 'twitter:description': 'Reigning world champion Max Verstappen won the Australian Grand Prix as Lewis Hamilton finished second in an incident-packed race in Melbourne on Sunday.', 'template_type': 'article_leaf', 'theme': 'sport', 'og:url': 'https://www.cnn.com/2023/04/02/motorsport/max-verstappen-lewis-hamilton-australian-grand-prix-spt-intl/index.html'}], 'cse_image': [{'src': 'https://media.cnn.com/api/v1/images/stellar/prod/230402042819-01-australian-gp-040223.jpg?c=16x9&q=w_800,c_fill'}]}}
# {'kind': 'customsearch#result', 'title': 'Max Verstappen Is the F1 Champion. So, What About Next Year ...', 'htmlTitle': '<b>Max Verstappen</b> Is the F1 Champion. So, What About Next Year ...', 'link': 'https://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html', 'displayLink': 'www.nytimes.com', 'snippet': 'Oct 20, 2022 ... Max Verstappen Is Champion. So, What About Next Year? He took his second title in Japan, but questions about winning a third started right away.', 'htmlSnippet': 'Oct 20, 2022 <b>...</b> <b>Max Verstappen</b> Is Champion. So, What About Next Year? He took his second title in Japan, but questions about winning a third started right away.', 'formattedUrl': 'https://www.nytimes.com/2022/10/.../max-verstappen-f1-2023-season.html', 'htmlFormattedUrl': 'https://www.nytimes.com/2022/10/.../<b>max</b>-<b>verstappen</b>-f1-2023-season.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRr7XraJaFtZNWV4dcglAp8AaIcjuo1heAU2E_PfN5ty9zQtdWzJIbB_F4', 'width': '310', 'height': '162'}], 'metatags': [{'og:image': 'https://static01.nyt.com/images/2022/10/21/multimedia/21sp-us-max-inyt2/21sp-us-max-inyt2-facebookJumbo.jpg?year=2022&h=550&w=1050&s=03b2b9ad1315cf1b6adb4f75d79c4d801328928829e467fb2123fd15909422e1&k=ZQJBKqZ0VN', 'nyt_uri': 'nyt://article/01afa01d-e886-5856-9496-c775d952728e', 'twitter:app:id:googleplay': 'com.nytimes.android', 'twitter:card': 'summary_large_image', 'article:published_time': '2022-10-20T09:00:22.995Z', 'pt': 'article', 'twitter:url': 'https://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html', 'pdate': '20221020', 'articleid': '100000008579928', 'al:android:package': 'com.nytimes.android', 'al:ipad:app_store_id': '357066198', 'twitter:app:name:googleplay': 'NYTimes', 'og:description': 'He took his second title in Japan, but questions about winning a third started right away. “It’s going to depend,” he said.', 'twitter:image': 'https://static01.nyt.com/images/2022/10/21/multimedia/21sp-us-max-inyt2/21sp-us-max-inyt2-videoSixteenByNine3000.jpg?year=2022&h=1688&w=3000&s=e32c8cca787a4abfdebf651910f8fd44ca85b13c026e793d555aba44c8505333&k=ZQJBKqZ0VN&tw=1', 'pst': 'News', 'twitter:image:alt': 'Max Verstappen celebrating his second Formula 1 championship on Oct. 9 along with his win at the Japanese Grand Prix.', 'al:iphone:app_name': 'NYTimes', 'article:modified_time': '2022-10-20T09:00:22.995Z', 'news_keywords': 'Cars,Car Racing,Formula One;Formula 1,International Automobile Federation,Red Bull Racing,Max Verstappen', 'scg': 'autoracing', 'article:content_tier': 'metered', 'msapplication-starturl': 'https://www.nytimes.com', 'image': 'https://static01.nyt.com/images/2022/10/21/multimedia/21sp-us-max-inyt2/21sp-us-max-inyt2-facebookJumbo.jpg?year=2022&h=550&w=1050&s=03b2b9ad1315cf1b6adb4f75d79c4d801328928829e467fb2123fd15909422e1&k=ZQJBKqZ0VN', 'og:type': 'article', 'og:image:alt': 'Max Verstappen celebrating his second Formula 1 championship on Oct. 9 along with his win at the Japanese Grand Prix.', 'twitter:title': 'Max Verstappen Is Champion. So, What About Next Year? (Published 2022)', 'article:section': 'Sports', 'cg': 'sports', 'pubp_event_id': 'pubp://event/077bb55e5ca24f24bfdebeb4bd4a9bbd', 'og:title': 'Max Verstappen Is Champion. So, What About Next Year? (Published 2022)', 'cn': 'formula-one-special-reports', 'url': 'https://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html', 'article:tag': 'Automobiles', 'al:iphone:url': 'nytimes://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html', 'al:android:url': 'nyt://article/01afa01d-e886-5856-9496-c775d952728e', 'ct': 'spotlight', 'twitter:app:url:googleplay': 'nyt://article/01afa01d-e886-5856-9496-c775d952728e', 'al:ipad:url': 'nytimes://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html', 'byl': 'By Ian Parkes', 'twitter:description': 'He took his second tit ...
# {'kind': 'customsearch#result', 'title': 'Max Verstappen crowned Formula One world champion | CNN', 'htmlTitle': '<b>Max Verstappen</b> crowned Formula One world champion | CNN', 'link': 'https://www.cnn.com/2023/10/07/sport/max-verstappen-wins-formula-one-world-title-spt-intl/index.html', 'displayLink': 'www.cnn.com', 'snippet': 'Oct 7, 2023 ... Max Verstappen was crowned Formula One world champion for the third time, securing the title in the sprint race at the Qatar Grand Prix on\xa0...', 'htmlSnippet': 'Oct 7, 2023 <b>...</b> <b>Max Verstappen</b> was crowned Formula One world champion for the third time, securing the title in the sprint race at the Qatar Grand Prix on&nbsp;...', 'formattedUrl': 'https://www.cnn.com/2023/10/07/sport/max-verstappen.../index.html', 'htmlFormattedUrl': 'https://www.cnn.com/2023/10/07/sport/<b>max</b>-<b>verstappen</b>.../index.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRRh1gfuZgRoPU9iS3PjmU1LQSf_rNUOwILVsNd0FE-kfbJ-rWckwC-hXM', 'width': '300', 'height': '168'}], 'metatags': [{'og:image': 'https://media.cnn.com/api/v1/images/stellar/prod/231007143017-02-max-verstappen-qatar-gp-100723.jpg?c=16x9&q=w_800,c_fill', 'twitter:title': 'Max Verstappen crowned Formula One world champion | CNN', 'og:type': 'article', 'twitter:card': 'summary_large_image', 'article:published_time': '2023-10-07T18:10:04.872Z', 'og:site_name': 'CNN', 'author': 'Issy Ronald, Aimee Lewis', 'og:title': 'Max Verstappen crowned Formula One world champion | CNN', 'meta-section': 'sport', 'type': 'article', 'og:description': 'Max Verstappen was crowned Formula One world champion for the third time, securing the title in the sprint race at the Qatar Grand Prix on Saturday.', 'twitter:image': 'https://media.cnn.com/api/v1/images/stellar/prod/231007143017-02-max-verstappen-qatar-gp-100723.jpg?c=16x9&q=w_800,c_fill', 'article:publisher': 'https://www.facebook.com/CNN', 'fb:app_id': '80401312489', 'twitter:site': '@CNNSport', 'article:modified_time': '2023-10-07T19:13:43.732Z', 'viewport': 'width=device-width,initial-scale=1,shrink-to-fit=no', 'twitter:description': 'Max Verstappen was crowned Formula One world champion for the third time, securing the title in the sprint race at the Qatar Grand Prix on Saturday.', 'template_type': 'article_leaf', 'theme': 'sport', 'og:url': 'https://www.cnn.com/2023/10/07/sport/max-verstappen-wins-formula-one-world-title-spt-intl/index.html'}], 'cse_image': [{'src': 'https://media.cnn.com/api/v1/images/stellar/prod/231007143017-02-max-verstappen-qatar-gp-100723.jpg?c=16x9&q=w_800,c_fill'}]}}
# {'kind': 'customsearch#result', 'title': 'F1 World Champion Max Verstappen Just Wants to Keep Winning ...', 'htmlTitle': 'F1 World Champion <b>Max Verstappen</b> Just Wants to Keep Winning ...', 'link': 'http://www.winterparkbookfestival.org/index-44.html', 'displayLink': 'www.winterparkbookfestival.org', 'snippet': "Nov 8, 2023 ... As he heads into the Las Vegas Grand Prix, Formula One's Max Verstappen shows no signs of slowing down.", 'htmlSnippet': 'Nov 8, 2023 <b>...</b> As he heads into the Las Vegas Grand Prix, Formula One&#39;s <b>Max Verstappen</b> shows no signs of slowing down.', 'cacheId': 'cqNR-YuB5pcJ', 'formattedUrl': 'http://www.winterparkbookfestival.org/index-44.html', 'htmlFormattedUrl': 'http://www.winterparkbookfestival.org/index-44.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNcsHS1WUuZyTHKJp-f9GEmTdpC66rRpN6_906qoPvTCm7QQqeXsbie3g2', 'width': '348', 'height': '145'}], 'metatags': [{'pinterest:description': 'As he heads into the Las Vegas Grand Prix, the three-time world champion shows no signs of slowing down', 'og:image': 'https://api.time.com/wp-content/uploads/2023/11/Verstappen3.jpeg?quality=85', 'theme-color': '#e90606', 'article:published_time': '2023-11-08T12:00:00', 'og:image:width': '1024', 'twitter:card': 'summary_large_image', 'og:site_name': 'TIME', 'og:description': 'As he heads into the Las Vegas Grand Prix, the three-time world champion shows no signs of slowing down', 'twitter:creator': '@seanmgregory', 'twitter:image': 'https://api.time.com/wp-content/uploads/2023/11/Verstappen3.jpeg?quality=85&w=1200&h=628&crop=1', 'twitter:site': '@TIME', 'pinterest:media': 'https://api.time.com/wp-content/uploads/2023/11/Verstappen3.jpeg?quality=85', 'article:content_tier': 'free', 'pinterest:url': 'https://time.com/6331364/max-verstappen-formula-one-interview-las-vegas/', 'application-name': 'nextgen', 'og:type': 'article', 'twitter:title': "What Fuels Max Verstappen's Formula One Success", 'og:title': "What Fuels Max Verstappen's Formula One Success", 'og:image:height': '1140', 'fb:pages': '10606591490', 'fb:app_id': '991230477954201', 'viewport': 'width=device-width, initial-scale=1', 'twitter:description': 'As he heads into the Las Vegas Grand Prix, the three-time world champion shows no signs of slowing down', 'primary-tag': 'auto-racing', 'amphtml': 'https://time.com/6331364/max-verstappen-formula-one-interview-las-vegas/?amp=true', 'category': 'Sports', 'og:url': 'https://time.com/6331364/max-verstappen-formula-one-interview-las-vegas/', 'article:opinion': 'false', 'format-detection': 'telephone=no'}], 'cse_image': [{'src': 'https://cdn.cookielaw.org/logos/ec48745c-0b96-47da-aa41-f959ab79a818/270180ce-f72f-444f-aed1-b4e38a3c9db4/0ff46aa7-1948-4f61-8ffd-751b0c4a7b10/ot-logo.png'}]}}
# {'kind': 'customsearch#result', 'title': 'Max Verstappen: World champion is already looking to life beyond ...', 'htmlTitle': '<b>Max Verstappen</b>: World champion is already looking to life beyond ...', 'link': 'https://www.cnn.com/2023/02/09/motorsport/max-verstappen-interview-f1-spt-intl/index.html', 'displayLink': 'www.cnn.com', 'snippet': 'Feb 9, 2023 ... When it comes to Formula One, a sport where danger literally exists around the corner – not for nothing did Netflix call their docuseries\xa0...', 'htmlSnippet': 'Feb 9, 2023 <b>...</b> When it comes to Formula One, a sport where danger literally exists around the corner – not for nothing did Netflix call their docuseries&nbsp;...', 'formattedUrl': 'https://www.cnn.com/2023/02/09/.../max-verstappen-interview.../index.htm...', 'htmlFormattedUrl': 'https://www.cnn.com/2023/02/09/.../<b>max</b>-<b>verstappen</b>-interview.../index.htm...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcS0K929K7jQ0PhHKqCz-gt8rjGBIcPM-e02Ya5TRUcWvqRq0xkMp44sAMhQ', 'width': '300', 'height': '168'}], 'metatags': [{'og:image': 'https://media.cnn.com/api/v1/images/stellar/prod/230207182343-01-max-verstappen-interview-f1-spt-intl.jpg?c=16x9&q=w_800,c_fill', 'twitter:title': "'I already achieved everything I wanted in F1': World champion Max Verstappen looks to life beyond racing | CNN", 'og:type': 'article', 'twitter:card': 'summary_large_image', 'article:published_time': '2023-02-09T11:54:53Z', 'og:site_name': 'CNN', 'author': 'Glen Levy,Carolyn Manno', 'og:title': "'I already achieved everything I wanted in F1': World champion Max Verstappen looks to life beyond racing | CNN", 'meta-section': 'sport', 'type': 'article', 'og:description': 'When it comes to Formula One, a sport where danger literally exists around the corner – not for nothing did Netflix call their docuseries “Drive to Survive” – two-time world champion Max Verstappen doesn’t seem to exhibit fear.', 'twitter:image': 'https://media.cnn.com/api/v1/images/stellar/prod/230207182343-01-max-verstappen-interview-f1-spt-intl.jpg?c=16x9&q=w_800,c_fill', 'article:publisher': 'https://www.facebook.com/CNN', 'article:tag': 'auto racing, companies, formula one, iab-auto racing, iab-sports, max verstappen, motor sports organizations, motorsports, red bull gmbh, sports and recreation, sports figures, sports organizations and teams', 'fb:app_id': '80401312489', 'twitter:site': '@CNNSport', 'article:modified_time': '2023-02-09T14:46:48Z', 'viewport': 'width=device-width,initial-scale=1,shrink-to-fit=no', 'twitter:description': 'When it comes to Formula One, a sport where danger literally exists around the corner – not for nothing did Netflix call their docuseries “Drive to Survive” – two-time world champion Max Verstappen doesn’t seem to exhibit fear.', 'template_type': 'article_leaf', 'theme': 'sport', 'og:url': 'https://www.cnn.com/2023/02/09/motorsport/max-verstappen-interview-f1-spt-intl/index.html'}], 'cse_image': [{'src': 'https://media.cnn.com/api/v1/images/stellar/prod/230207182343-01-max-verstappen-interview-f1-spt-intl.jpg?c=16x9&q=w_800,c_fill'}]}}
# {'kind': 'customsearch#result', 'title': 'Buy Pop! Rides Super Deluxe Max Verstappen at Funko.', 'htmlTitle': 'Buy Pop! Rides Super Deluxe <b>Max Verstappen</b> at Funko.', 'link': 'https://funko.com/pop-rides-super-deluxe-max-verstappen/72617.html', 'displayLink': 'funko.com', 'snippet': 'Check out our Pop! Rides Super Deluxe Max Verstappen and more from Funko!', 'htmlSnippet': 'Check out our Pop! Rides Super Deluxe <b>Max Verstappen</b> and more from Funko!', 'cacheId': 'umCb47RKWpYJ', 'formattedUrl': 'https://funko.com/pop-rides-super-deluxe-max-verstappen/72617.html', 'htmlFormattedUrl': 'https://funko.com/pop-rides-super-deluxe-<b>max</b>-<b>verstappen</b>/72617.html', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQbzz52VPtsnP01Gk9MVX5dCpqqZzvneXuETRI_RT49yxSghvMkEDACTpc', 'width': '225', 'height': '225'}], 'metatags': [{'og:image': 'https://funko.com/on/demandware.static/-/Sites-funko-master-catalog/default/dwb10e98b2/images/funko/upload/72617_POP-Ride-SPRDLX_Formula-1_Verstappe_POP_GLAM-WEB.png', 'og:product:price:amount': '35.00', 'og:type': 'Product', 'og:availability': 'In Stock', 'og:site_name': 'Funko US', 'viewport': 'width=device-width, initial-scale=1', 'og:product:price:currency': 'USD', 'og:title': 'Buy Pop! Rides Super Deluxe Max Verstappen at Funko.', 'og:url': 'https://funko.com/pop-rides-super-deluxe-max-verstappen/72617.html', 'og:description': 'Check out our Pop! Rides Super Deluxe Max Verstappen and more from Funko!'}], 'cse_image': [{'src': 'https://funko.com/on/demandware.static/-/Sites-funko-master-catalog/default/dwb10e98b2/images/funko/upload/72617_POP-Ride-SPRDLX_Formula-1_Verstappe_POP_GLAM-WEB.png'}]}}
# {'kind': 'customsearch#result', 'title': "Max Verstappen on Las Vegas GP's merchandise voucher offer: 'If I ...", 'htmlTitle': '<b>Max Verstappen</b> on Las Vegas GP&#39;s merchandise voucher offer: &#39;If I ...', 'link': 'https://sports.yahoo.com/max-verstappen-on-las-vegas-gps-merchandise-voucher-offer-if-i-was-a-fan-i-would-tear-the-whole-place-down-174353651.html', 'displayLink': 'sports.yahoo.com', 'snippet': '4 days ago ... Max Verstappen understands why fans would be upset at the disaster that was the opening night of the Las Vegas Grand Prix and the Formula 1\xa0...', 'htmlSnippet': '4 days ago <b>...</b> <b>Max Verstappen</b> understands why fans would be upset at the disaster that was the opening night of the Las Vegas Grand Prix and the Formula 1&nbsp;...', 'cacheId': 'HmQXjm-A_E4J', 'formattedUrl': 'https://sports.yahoo.com/max-verstappen-on-las-vegas-gps-merchandise-vo...', 'htmlFormattedUrl': 'https://sports.yahoo.com/<b>max</b>-<b>verstappen</b>-on-las-vegas-gps-merchandise-vo...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRH6rU2JdidVlkK8kaW8gXYA2oTKQ54-hWBSSA4ahYi7h-NSNQbMntEGQ', 'width': '150', 'height': '84'}], 'metatags': [{'apple-itunes-app': 'app-id=286058814,app-argument=ysportacular://v2/news/details?articleUuid=ab6cce3a-993f-4e85-9594-95d51412e6ab&src=web', 'og:image': 'https://s.yimg.com/ny/api/res/1.2/Jdx5rsirUFNazhm4xyKmkw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e1017110-8639-11ee-bff9-d941cf760a17', 'og:image:width': '1200', 'twitter:card': 'summary_large_image', 'og:site_name': 'Yahoo Sports', 'al:android:package': 'com.yahoo.mobile.client.android.sportacular', 'al:ios:url': 'ysportacular://v2/news/details?articleUuid=ab6cce3a-993f-4e85-9594-95d51412e6ab&src=web', 'og:description': "Fans haven't been offered refunds after they saw less than 10 minutes of practice Thursday night.", 'twitter:creator': '@nickbromberg', 'al:ios:app_store_id': '286058814', 'twitter:dnt': 'on', 'twitter:image': 'https://s.yimg.com/ny/api/res/1.2/Jdx5rsirUFNazhm4xyKmkw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e1017110-8639-11ee-bff9-d941cf760a17', 'oath:guce:consent-host': 'guce.yahoo.com', 'twitter:site': '@YahooSports', 'news_keywords': 'Max Verstappen, Las Vegas Grand Prix, Carlos Sainz, Mario Renzi, drain cover, race merchandise, Getty Images', 'twitter:title': "Max Verstappen on Las Vegas GP's merchandise voucher offer: 'If I was a fan, I would tear the whole place down'", 'og:type': 'article', 'al:ios:app_name': 'Yahoo Sports', 'og:title': "Max Verstappen on Las Vegas GP's merchandise voucher offer: 'If I was a fan, I would tear the whole place down'", 'og:image:height': '675', 'twitter:image:src': 'https://s.yimg.com/ny/api/res/1.2/Jdx5rsirUFNazhm4xyKmkw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e1017110-8639-11ee-bff9-d941cf760a17', 'al:android:url': 'ysportacular://v2/news/details?articleUuid=ab6cce3a-993f-4e85-9594-95d51412e6ab&src=web', 'viewport': 'width=device-width, initial-scale=1', 'twitter:description': "Fans haven't been offered refunds after they saw less than 10 minutes of practice Thursday night.", 'og:url': 'https://sports.yahoo.com/max-verstappen-on-las-vegas-gps-merchandise-voucher-offer-if-i-was-a-fan-i-would-tear-the-whole-place-down-174353651.html', 'al:android:app_name': 'Yahoo Sports'}], 'cse_image': [{'src': 'https://s.yimg.com/ny/api/res/1.2/Jdx5rsirUFNazhm4xyKmkw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e1017110-8639-11ee-bff9-d941cf760a17'}]}}

# %%
import json
#print(response_json.keys())
#print(response_json['items'])
print(json.dumps(response_json['items'], indent=5))
# Out:
# [
#      {
#           "kind": "customsearch#result",
#           "title": "Max Verstappen - F1 Driver for Red Bull Racing",
#           "htmlTitle": "<b>Max Verstappen</b> - F1 Driver for Red Bull Racing",
#           "link": "https://www.formula1.com/en/drivers/max-verstappen.html",
#           "displayLink": "www.formula1.com",
#           "snippet": "Formula 1's youngest ever competitor \u2013 and now its reigning, two-time world champion. Say hello to Max Verstappen.",
#           "htmlSnippet": "Formula 1&#39;s youngest ever competitor \u2013 and now its reigning, two-time world champion. Say hello to <b>Max Verstappen</b>.",
#           "cacheId": "15G_j1uI8W4J",
#           "formattedUrl": "https://www.formula1.com/en/drivers/max-verstappen.html",
#           "htmlFormattedUrl": "https://www.formula1.com/en/drivers/<b>max</b>-<b>verstappen</b>.html",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTYep9-kxs1FG_YjCNoLiMIIpdVi2f6IjoCthA6lGCzdRiodgQZ-2a9R3PV",
#                          "width": "225",
#                          "height": "225"
#                     }
#                ],
#                "website": [
#                     {
#                          "image": "https://media.formula1.com/content/dam/fom-website/drivers/2023Drivers/verstappen.jpg.img.1536.high.jpg",
#                          "name": "Max Verstappen - F1 Driver for Red Bull Racing",
#                          "description": "Formula 1's youngest ever competitor \u2013 and now its reigning, two-time world champion. Say hello to Max Verstappen."
#                     }
#                ],
#                "metatags": [
#                     {
#                          "apple-itunes-app": "app-id=835022598, app-argument=http://www.formula1.com",
#                          "og:image": "https://media.formula1.com/content/dam/fom-website/drivers/2023Drivers/verstappen.jpg.img.1536.high.jpg",
#                          "theme-color": "#000000",
#                          "og:type": "website",
#                          "twitter:card": "summary_large_image",
#                          "twitter:title": "Max Verstappen - F1 Driver for Red Bull Racing",
#                          "og:site_name": "Formula 1\u00ae - The Official F1\u00ae Website",
#                          "og:title": "Max Verstappen - F1 Driver for Red Bull Racing",
#                          "fb:pages": "568665409957112",
#                          "og:description": "Formula 1's youngest ever competitor \u2013 and now its reigning, two-time world champion. Say hello to Max Verstappen.",
#                          "twitter:creator": "@f1",
#                          "twitter:image": "https://www.formula1.com/content/dam/fom-website/drivers/2023Drivers/verstappen.jpg.img.1024.medium.jpg",
#                          "fb:app_id": "833421847009900",
#                          "twitter:site": "@f1",
#                          "viewport": "width=device-width, initial-scale=1",
#                          "twitter:description": "Formula 1's youngest ever competitor \u2013 and now its reigning, two-time world champion. Say hello to Max Verstappen.",
#                          "fb:admins": "568665409957112",
#                          "og:url": "/en/drivers/max-verstappen.html",
#                          "twitter:widgets:theme": "light",
#                          "twitter:widgets:link-color": "#d31411",
#                          "twitter:widgets:border-color": "#ffffff"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://media.formula1.com/content/dam/fom-website/drivers/2023Drivers/verstappen.jpg.img.1536.high.jpg"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "Las Vegas Grand Prix: 'Viva Las Vegas,' sings Max Verstappen as ...",
#           "htmlTitle": "Las Vegas Grand Prix: &#39;Viva Las Vegas,&#39; sings <b>Max Verstappen</b> as ...",
#           "link": "https://www.cnn.com/2023/11/19/sport/las-vegas-grand-prix-max-verstappen-spt-intl/index.html",
#           "displayLink": "www.cnn.com",
#           "snippet": "4 days ago ... 'Viva Las Vegas,' sings Max Verstappen as he wins thrilling race. By Aimee Lewis, CNN. 3 minute read. Published 6:08 AM\u00a0...",
#           "htmlSnippet": "4 days ago <b>...</b> &#39;Viva Las Vegas,&#39; sings <b>Max Verstappen</b> as he wins thrilling race. By Aimee Lewis, CNN. 3 minute read. Published 6:08 AM&nbsp;...",
#           "formattedUrl": "https://www.cnn.com/2023/11/19/sport/las...max-verstappen.../index.html",
#           "htmlFormattedUrl": "https://www.cnn.com/2023/11/19/sport/las...<b>max</b>-<b>verstappen</b>.../index.html",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRDZ6gJBg1Nz7ELf2bqyTPz5qTbhNi5QQMZ-DobUfGdMmeu7F2j2IgxYQ",
#                          "width": "143",
#                          "height": "80"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "og:image": "https://media.cnn.com/api/v1/images/stellar/prod/2023-11-19t080142z-680844850-up1ejbj0mar55-rtrmadp-3-motor-f1-lasvegas.JPG?c=16x9&q=w_800,c_fill",
#                          "twitter:title": "\u2018Viva Las Vegas,\u2019 sings Max Verstappen as he wins thrilling race | CNN",
#                          "og:type": "article",
#                          "twitter:card": "summary_large_image",
#                          "article:published_time": "2023-11-19T11:08:01.553Z",
#                          "og:site_name": "CNN",
#                          "author": "Aimee Lewis",
#                          "og:title": "\u2018Viva Las Vegas,\u2019 sings Max Verstappen as he wins thrilling race | CNN",
#                          "meta-section": "sport",
#                          "type": "article",
#                          "og:description": "After spending much of the build-up to the Las Vegas Grand Prix making it clear he was unenthused by the event, Max Verstappen decided it was time for a little less conversation and a little more action on Saturday as he did what he does best \u2013 winning Formula One races.",
#                          "twitter:image": "https://media.cnn.com/api/v1/images/stellar/prod/2023-11-19t080142z-680844850-up1ejbj0mar55-rtrmadp-3-motor-f1-lasvegas.JPG?c=16x9&q=w_800,c_fill",
#                          "article:publisher": "https://www.facebook.com/CNN",
#                          "fb:app_id": "80401312489",
#                          "twitter:site": "@CNNSport",
#                          "article:modified_time": "2023-11-19T11:08:01.553Z",
#                          "viewport": "width=device-width,initial-scale=1,shrink-to-fit=no",
#                          "twitter:description": "After spending much of the build-up to the Las Vegas Grand Prix making it clear he was unenthused by the event, Max Verstappen decided it was time for a little less conversation and a little more action on Saturday as he did what he does best \u2013 winning Formula One races.",
#                          "template_type": "article_leaf",
#                          "theme": "sport",
#                          "og:url": "https://www.cnn.com/2023/11/19/sport/las-vegas-grand-prix-max-verstappen-spt-intl/index.html"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://media.cnn.com/api/v1/images/stellar/prod/2023-11-19t080142z-680844850-up1ejbj0mar55-rtrmadp-3-motor-f1-lasvegas.JPG?c=16x9&q=w_800,c_fill"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "2023 Driver Standings",
#           "htmlTitle": "2023 Driver Standings",
#           "link": "https://www.formula1.com/en/results/driver-standings.html",
#           "displayLink": "www.formula1.com",
#           "snippet": "Pos, Driver, Nationality, Car, PTS. 1, Max Verstappen VER, NED, Red Bull Racing Honda RBPT, 549. 2, Sergio Perez PER, MEX, Red Bull Racing Honda RBPT, 273.",
#           "htmlSnippet": "Pos, Driver, Nationality, Car, PTS. 1, <b>Max Verstappen</b> VER, NED, Red Bull Racing Honda RBPT, 549. 2, Sergio Perez PER, MEX, Red Bull Racing Honda RBPT, 273.",
#           "cacheId": "ZE6QE_un5NUJ",
#           "formattedUrl": "https://www.formula1.com/en/results/driver-standings.html",
#           "htmlFormattedUrl": "https://www.formula1.com/en/results/driver-standings.html",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSkvxVG_FIMJMTMB_LVCurLH3qEH_qhjoiQyo5zVsOjfmu9YdBfyJTbhP0",
#                          "width": "300",
#                          "height": "168"
#                     }
#                ],
#                "website": [
#                     {
#                          "image": "/etc/designs/fom-website/social/f1-default-share.jpg",
#                          "name": "Results",
#                          "description": "Results"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "apple-itunes-app": "app-id=835022598, app-argument=http://www.formula1.com",
#                          "og:image": "/etc/designs/fom-website/social/f1-default-share.jpg",
#                          "theme-color": "#000000",
#                          "og:type": "website",
#                          "twitter:card": "summary_large_image",
#                          "twitter:title": "Results",
#                          "og:site_name": "Formula 1\u00ae - The Official F1\u00ae Website",
#                          "og:title": "Results",
#                          "fb:pages": "568665409957112",
#                          "og:description": "Results",
#                          "twitter:creator": "@f1",
#                          "twitter:image": "https://www.formula1.com/etc/designs/fom-website/social/f1-default-share.jpg",
#                          "fb:app_id": "833421847009900",
#                          "twitter:site": "@f1",
#                          "viewport": "width=device-width, initial-scale=1",
#                          "twitter:description": "Results",
#                          "fb:admins": "568665409957112",
#                          "og:url": "/en/results.html",
#                          "twitter:widgets:theme": "light",
#                          "twitter:widgets:link-color": "#d31411",
#                          "twitter:widgets:border-color": "#ffffff"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://www.formula1.com/etc/designs/fom-website/social/f1-default-share.jpg"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "Max Verstappen drives away for Las Vegas Grand Prix win",
#           "htmlTitle": "<b>Max Verstappen</b> drives away for Las Vegas Grand Prix win",
#           "link": "https://sports.yahoo.com/max-verstappen-drives-away-for-las-vegas-grand-prix-win-073411377.html",
#           "displayLink": "sports.yahoo.com",
#           "snippet": "4 days ago ... A subsequent safety car for the debris from the contact between the two drivers allowed Red Bull to check Verstappen's front wing and put a new\u00a0...",
#           "htmlSnippet": "4 days ago <b>...</b> A subsequent safety car for the debris from the contact between the two drivers allowed Red Bull to check <b>Verstappen&#39;s</b> front wing and put a new&nbsp;...",
#           "cacheId": "lJGiE4L2mT4J",
#           "formattedUrl": "https://sports.yahoo.com/max-verstappen-drives-away-for-las-vegas-grand-...",
#           "htmlFormattedUrl": "https://sports.yahoo.com/<b>max</b>-<b>verstappen</b>-drives-away-for-las-vegas-grand-...",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSeRAlRrKNUoqbVd_pyu1MmHCTXl-ZagCegcFL9FjQ0I4katUr3papNsw",
#                          "width": "150",
#                          "height": "100"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "apple-itunes-app": "app-id=286058814,app-argument=ysportacular://v2/news/details?articleUuid=9f4cbbd2-3a1c-4856-9604-9d76e57a679b&src=web",
#                          "og:image": "https://s.yimg.com/ny/api/res/1.2/iCpOivety9UGJkpXIhsz9w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/3739c0a0-86ad-11ee-b9dd-80d166538b8d",
#                          "og:image:width": "1200",
#                          "twitter:card": "summary_large_image",
#                          "og:site_name": "Yahoo Sports",
#                          "al:android:package": "com.yahoo.mobile.client.android.sportacular",
#                          "al:ios:url": "ysportacular://v2/news/details?articleUuid=9f4cbbd2-3a1c-4856-9604-9d76e57a679b&src=web",
#                          "og:description": "Verstappen won comfortably, but it was not a straightforward victory.",
#                          "twitter:creator": "@nickbromberg",
#                          "al:ios:app_store_id": "286058814",
#                          "twitter:dnt": "on",
#                          "twitter:image": "https://s.yimg.com/ny/api/res/1.2/iCpOivety9UGJkpXIhsz9w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/3739c0a0-86ad-11ee-b9dd-80d166538b8d",
#                          "oath:guce:consent-host": "guce.yahoo.com",
#                          "twitter:site": "@YahooSports",
#                          "news_keywords": "Max Verstappen, Sergio Perez, Charles Leclerc, Red Bull, Las Vegas Grand Prix, George Russell, Mark Thompson, Lewis Hamilton, Oscar Piastri, Lando Norris, Carlos Sainz, Pierre Gasly",
#                          "twitter:title": "Max Verstappen drives away for Las Vegas Grand Prix win",
#                          "og:type": "article",
#                          "al:ios:app_name": "Yahoo Sports",
#                          "og:title": "Max Verstappen drives away for Las Vegas Grand Prix win",
#                          "og:image:height": "800",
#                          "twitter:image:src": "https://s.yimg.com/ny/api/res/1.2/iCpOivety9UGJkpXIhsz9w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/3739c0a0-86ad-11ee-b9dd-80d166538b8d",
#                          "al:android:url": "ysportacular://v2/news/details?articleUuid=9f4cbbd2-3a1c-4856-9604-9d76e57a679b&src=web",
#                          "viewport": "width=device-width, initial-scale=1",
#                          "twitter:description": "Verstappen won comfortably, but it was not a straightforward victory.",
#                          "og:url": "https://sports.yahoo.com/max-verstappen-drives-away-for-las-vegas-grand-prix-win-073411377.html",
#                          "al:android:app_name": "Yahoo Sports"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://s.yimg.com/ny/api/res/1.2/iCpOivety9UGJkpXIhsz9w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/3739c0a0-86ad-11ee-b9dd-80d166538b8d"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "Max Verstappen wins chaotic Australian Grand Prix as Lewis ...",
#           "htmlTitle": "<b>Max Verstappen</b> wins chaotic Australian Grand Prix as Lewis ...",
#           "link": "https://www.cnn.com/2023/04/02/motorsport/max-verstappen-lewis-hamilton-australian-grand-prix-spt-intl/index.html",
#           "displayLink": "www.cnn.com",
#           "snippet": "Apr 2, 2023 ... Reigning world champion Max Verstappen won the Australian Grand Prix as Lewis Hamilton finished second in an incident-packed race in\u00a0...",
#           "htmlSnippet": "Apr 2, 2023 <b>...</b> Reigning world champion <b>Max Verstappen</b> won the Australian Grand Prix as Lewis Hamilton finished second in an incident-packed race in&nbsp;...",
#           "formattedUrl": "https://www.cnn.com/2023/04/02/.../max-verstappen-lewis.../index.html",
#           "htmlFormattedUrl": "https://www.cnn.com/2023/04/02/.../<b>max</b>-<b>verstappen</b>-lewis.../index.html",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkfouAYlZfLjRlmN9pgwnOTJ79URmdqNBJ7WVDUSjDVKsskGsO4dXPGN8",
#                          "width": "300",
#                          "height": "168"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "og:image": "https://media.cnn.com/api/v1/images/stellar/prod/230402042819-01-australian-gp-040223.jpg?c=16x9&q=w_800,c_fill",
#                          "twitter:title": "Max Verstappen wins chaotic Australian Grand Prix as Lewis Hamilton takes second | CNN",
#                          "og:type": "article",
#                          "twitter:card": "summary_large_image",
#                          "article:published_time": "2023-04-02T09:21:50Z",
#                          "og:site_name": "CNN",
#                          "author": "Aimee Lewis",
#                          "og:title": "Max Verstappen wins chaotic Australian Grand Prix as Lewis Hamilton takes second | CNN",
#                          "meta-section": "sport",
#                          "type": "article",
#                          "og:description": "Reigning world champion Max Verstappen won the Australian Grand Prix as Lewis Hamilton finished second in an incident-packed race in Melbourne on Sunday.",
#                          "twitter:image": "https://media.cnn.com/api/v1/images/stellar/prod/230402042819-01-australian-gp-040223.jpg?c=16x9&q=w_800,c_fill",
#                          "article:publisher": "https://www.facebook.com/CNN",
#                          "article:tag": "accidents, disasters and safety, australian grand prix, auto racing, automotive industry, automotive safety, brand safety-nsf products and consumers negative, brand safety-nsf sensitive, business and industry sectors, business, economy and trade, formula one, iab-auto racing, iab-auto safety, iab-automotive, iab-automotive industry, iab-business and finance, iab-industries, iab-sports, lewis hamilton, max verstappen, motor sports organizations, motorsports, motorsports events, product safety, safety issues and practices, sports and recreation, sports events, sports figures, sports organizations and teams",
#                          "fb:app_id": "80401312489",
#                          "twitter:site": "@CNNSport",
#                          "article:modified_time": "2023-04-02T10:09:15Z",
#                          "viewport": "width=device-width,initial-scale=1,shrink-to-fit=no",
#                          "twitter:description": "Reigning world champion Max Verstappen won the Australian Grand Prix as Lewis Hamilton finished second in an incident-packed race in Melbourne on Sunday.",
#                          "template_type": "article_leaf",
#                          "theme": "sport",
#                          "og:url": "https://www.cnn.com/2023/04/02/motorsport/max-verstappen-lewis-hamilton-australian-grand-prix-spt-intl/index.html"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://media.cnn.com/api/v1/images/stellar/prod/230402042819-01-australian-gp-040223.jpg?c=16x9&q=w_800,c_fill"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "Max Verstappen Is the F1 Champion. So, What About Next Year ...",
#           "htmlTitle": "<b>Max Verstappen</b> Is the F1 Champion. So, What About Next Year ...",
#           "link": "https://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html",
#           "displayLink": "www.nytimes.com",
#           "snippet": "Oct 20, 2022 ... Max Verstappen Is Champion. So, What About Next Year? He took his second title in Japan, but questions about winning a third started right away.",
#           "htmlSnippet": "Oct 20, 2022 <b>...</b> <b>Max Verstappen</b> Is Champion. So, What About Next Year? He took his second title in Japan, but questions about winning a third started right away.",
#           "formattedUrl": "https://www.nytimes.com/2022/10/.../max-verstappen-f1-2023-season.html",
#           "htmlFormattedUrl": "https://www.nytimes.com/2022/10/.../<b>max</b>-<b>verstappen</b>-f1-2023-season.html",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRr7XraJaFtZNWV4dcglAp8AaIcjuo1heAU2E_PfN5ty9zQtdWzJIbB_F4",
#                          "width": "310",
#                          "height": "162"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "og:image": "https://static01.nyt.com/images/2022/10/21/multimedia/21sp-us-max-inyt2/21sp-us-max-inyt2-facebookJumbo.jpg?year=2022&h=550&w=1050&s=03b2b9ad1315cf1b6adb4f75d79c4d801328928829e467fb2123fd15909422e1&k=ZQJBKqZ0VN",
#                          "nyt_uri": "nyt://article/01afa01d-e886-5856-9496-c775d952728e",
#                          "twitter:app:id:googleplay": "com.nytimes.android",
#                          "twitter:card": "summary_large_image",
#                          "article:published_time": "2022-10-20T09:00:22.995Z",
#                          "pt": "article",
#                          "twitter:url": "https://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html",
#                          "pdate": "20221020",
#                          "articleid": "100000008579928",
#                          "al:android:package": "com.nytimes.android",
#                          "al:ipad:app_store_id": "357066198",
#                          "twitter:app:name:googleplay": "NYTimes",
#                          "og:description": "He took his second title in Japan, but questions about winning a third started right away. \u201cIt\u2019s going to depend,\u201d he said.",
#                          "twitter:image": "https://static01.nyt.com/images/2022/10/21/multimedia/21sp-us-max-inyt2/21sp-us-max-inyt2-videoSixteenByNine3000.jpg?year=2022&h=1688&w=3000&s=e32c8cca787a4abfdebf651910f8fd44ca85b13c026e793d555aba44c8505333&k=ZQJBKqZ0VN&tw=1",
#                          "pst": "News",
#                          "twitter:image:alt": "Max Verstappen celebrating his second Formula 1 championship on Oct. 9 along with his win at the Japanese Grand Prix.",
#                          "al:iphone:app_name": "NYTimes",
#                          "article:modified_time": "2022-10-20T09:00:22.995Z",
#                          "news_keywords": "Cars,Car Racing,Formula One;Formula 1,International Automobile Federation,Red Bull Racing,Max Verstappen",
#                          "scg": "autoracing",
#                          "article:content_tier": "metered",
#                          "msapplication-starturl": "https://www.nytimes.com",
#                          "image": "https://static01.nyt.com/images/2022/10/21/multimedia/21sp-us-max-inyt2/21sp-us-max-inyt2-facebookJumbo.jpg?year=2022&h=550&w=1050&s=03b2b9ad1315cf1b6adb4f75d79c4d801328928829e467fb2123fd15909422e1&k=ZQJBKqZ0VN",
#                          "og:type": "article",
#                          "og:image:alt": "Max Verstappen celebrating his second Formula 1 championship on Oct. 9 along with his win at the Japanese Grand Prix.",
#                          "twitter:title": "Max Verstappen Is Champion. So, What About Next Year? (Published 2022)",
#                          "article:section": "Sports",
#                          "cg": "sports",
#                          "pubp_event_id": "pubp://event/077bb55e5ca24f24bfdebeb4bd4a9bbd",
#                          "og:title": "Max Verstappen Is Champion. So, What About Next Year? (Published 2022)",
#                          "cn": "formula-one-special-reports",
#                          "url": "https://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html",
#                          "article:tag": "Automobiles",
#                          "al:iphone:url": "nytimes://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html",
#                          "al:android:url": "nyt://article/01afa01d-e886-5856-9496-c775d952728e",
#                          "ct": "spotlight",
#                          "twitter:app:url:googleplay": "nyt://article/01afa01d-e886-5856-9496-c775d952728e",
#                          "al:ipad:url": "nytimes://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html",
#                          "byl": "By Ian Parkes",
#                          "twitter:description": "He took his second title in Japan, but questions about winning a third started right away. \u201cIt\u2019s going to depend,\u201d he said.",
#                          "al:iphone:app_store_id": "284862083",
#                          "al:ipad:app_name": "NYTimes",
#                          "og:url": "https://www.nytimes.com/2022/10/20/sports/autoracing/max-verstappen-f1-2023-season.html",
#                          "al:android:app_name": "NYTimes",
#                          "article:opinion": "false"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://static01.nyt.com/images/2022/10/21/multimedia/21sp-us-max-inyt2/21sp-us-max-inyt2-facebookJumbo.jpg?year=2022&h=550&w=1050&s=03b2b9ad1315cf1b6adb4f75d79c4d801328928829e467fb2123fd15909422e1&k=ZQJBKqZ0VN"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "F1 World Champion Max Verstappen Just Wants to Keep Winning ...",
#           "htmlTitle": "F1 World Champion <b>Max Verstappen</b> Just Wants to Keep Winning ...",
#           "link": "http://www.winterparkbookfestival.org/index-44.html",
#           "displayLink": "www.winterparkbookfestival.org",
#           "snippet": "Nov 8, 2023 ... As he heads into the Las Vegas Grand Prix, Formula One's Max Verstappen shows no signs of slowing down.",
#           "htmlSnippet": "Nov 8, 2023 <b>...</b> As he heads into the Las Vegas Grand Prix, Formula One&#39;s <b>Max Verstappen</b> shows no signs of slowing down.",
#           "cacheId": "cqNR-YuB5pcJ",
#           "formattedUrl": "http://www.winterparkbookfestival.org/index-44.html",
#           "htmlFormattedUrl": "http://www.winterparkbookfestival.org/index-44.html",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNcsHS1WUuZyTHKJp-f9GEmTdpC66rRpN6_906qoPvTCm7QQqeXsbie3g2",
#                          "width": "348",
#                          "height": "145"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "pinterest:description": "As he heads into the Las Vegas Grand Prix, the three-time world champion shows no signs of slowing down",
#                          "og:image": "https://api.time.com/wp-content/uploads/2023/11/Verstappen3.jpeg?quality=85",
#                          "theme-color": "#e90606",
#                          "article:published_time": "2023-11-08T12:00:00",
#                          "og:image:width": "1024",
#                          "twitter:card": "summary_large_image",
#                          "og:site_name": "TIME",
#                          "og:description": "As he heads into the Las Vegas Grand Prix, the three-time world champion shows no signs of slowing down",
#                          "twitter:creator": "@seanmgregory",
#                          "twitter:image": "https://api.time.com/wp-content/uploads/2023/11/Verstappen3.jpeg?quality=85&w=1200&h=628&crop=1",
#                          "twitter:site": "@TIME",
#                          "pinterest:media": "https://api.time.com/wp-content/uploads/2023/11/Verstappen3.jpeg?quality=85",
#                          "article:content_tier": "free",
#                          "pinterest:url": "https://time.com/6331364/max-verstappen-formula-one-interview-las-vegas/",
#                          "application-name": "nextgen",
#                          "og:type": "article",
#                          "twitter:title": "What Fuels Max Verstappen's Formula One Success",
#                          "og:title": "What Fuels Max Verstappen's Formula One Success",
#                          "og:image:height": "1140",
#                          "fb:pages": "10606591490",
#                          "fb:app_id": "991230477954201",
#                          "viewport": "width=device-width, initial-scale=1",
#                          "twitter:description": "As he heads into the Las Vegas Grand Prix, the three-time world champion shows no signs of slowing down",
#                          "primary-tag": "auto-racing",
#                          "amphtml": "https://time.com/6331364/max-verstappen-formula-one-interview-las-vegas/?amp=true",
#                          "category": "Sports",
#                          "og:url": "https://time.com/6331364/max-verstappen-formula-one-interview-las-vegas/",
#                          "article:opinion": "false",
#                          "format-detection": "telephone=no"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://cdn.cookielaw.org/logos/ec48745c-0b96-47da-aa41-f959ab79a818/270180ce-f72f-444f-aed1-b4e38a3c9db4/0ff46aa7-1948-4f61-8ffd-751b0c4a7b10/ot-logo.png"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "Buy Pop! Rides Super Deluxe Max Verstappen at Funko.",
#           "htmlTitle": "Buy Pop! Rides Super Deluxe <b>Max Verstappen</b> at Funko.",
#           "link": "https://funko.com/pop-rides-super-deluxe-max-verstappen/72617.html",
#           "displayLink": "funko.com",
#           "snippet": "Check out our Pop! Rides Super Deluxe Max Verstappen and more from Funko!",
#           "htmlSnippet": "Check out our Pop! Rides Super Deluxe <b>Max Verstappen</b> and more from Funko!",
#           "cacheId": "umCb47RKWpYJ",
#           "formattedUrl": "https://funko.com/pop-rides-super-deluxe-max-verstappen/72617.html",
#           "htmlFormattedUrl": "https://funko.com/pop-rides-super-deluxe-<b>max</b>-<b>verstappen</b>/72617.html",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQbzz52VPtsnP01Gk9MVX5dCpqqZzvneXuETRI_RT49yxSghvMkEDACTpc",
#                          "width": "225",
#                          "height": "225"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "og:image": "https://funko.com/on/demandware.static/-/Sites-funko-master-catalog/default/dwb10e98b2/images/funko/upload/72617_POP-Ride-SPRDLX_Formula-1_Verstappe_POP_GLAM-WEB.png",
#                          "og:product:price:amount": "35.00",
#                          "og:type": "Product",
#                          "og:availability": "In Stock",
#                          "og:site_name": "Funko US",
#                          "viewport": "width=device-width, initial-scale=1",
#                          "og:product:price:currency": "USD",
#                          "og:title": "Buy Pop! Rides Super Deluxe Max Verstappen at Funko.",
#                          "og:url": "https://funko.com/pop-rides-super-deluxe-max-verstappen/72617.html",
#                          "og:description": "Check out our Pop! Rides Super Deluxe Max Verstappen and more from Funko!"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://funko.com/on/demandware.static/-/Sites-funko-master-catalog/default/dwb10e98b2/images/funko/upload/72617_POP-Ride-SPRDLX_Formula-1_Verstappe_POP_GLAM-WEB.png"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "Max Verstappen on Las Vegas GP's merchandise voucher offer: 'If I ...",
#           "htmlTitle": "<b>Max Verstappen</b> on Las Vegas GP&#39;s merchandise voucher offer: &#39;If I ...",
#           "link": "https://sports.yahoo.com/max-verstappen-on-las-vegas-gps-merchandise-voucher-offer-if-i-was-a-fan-i-would-tear-the-whole-place-down-174353651.html",
#           "displayLink": "sports.yahoo.com",
#           "snippet": "4 days ago ... Max Verstappen understands why fans would be upset at the disaster that was the opening night of the Las Vegas Grand Prix and the Formula 1\u00a0...",
#           "htmlSnippet": "4 days ago <b>...</b> <b>Max Verstappen</b> understands why fans would be upset at the disaster that was the opening night of the Las Vegas Grand Prix and the Formula 1&nbsp;...",
#           "cacheId": "HmQXjm-A_E4J",
#           "formattedUrl": "https://sports.yahoo.com/max-verstappen-on-las-vegas-gps-merchandise-vo...",
#           "htmlFormattedUrl": "https://sports.yahoo.com/<b>max</b>-<b>verstappen</b>-on-las-vegas-gps-merchandise-vo...",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRH6rU2JdidVlkK8kaW8gXYA2oTKQ54-hWBSSA4ahYi7h-NSNQbMntEGQ",
#                          "width": "150",
#                          "height": "84"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "apple-itunes-app": "app-id=286058814,app-argument=ysportacular://v2/news/details?articleUuid=ab6cce3a-993f-4e85-9594-95d51412e6ab&src=web",
#                          "og:image": "https://s.yimg.com/ny/api/res/1.2/Jdx5rsirUFNazhm4xyKmkw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e1017110-8639-11ee-bff9-d941cf760a17",
#                          "og:image:width": "1200",
#                          "twitter:card": "summary_large_image",
#                          "og:site_name": "Yahoo Sports",
#                          "al:android:package": "com.yahoo.mobile.client.android.sportacular",
#                          "al:ios:url": "ysportacular://v2/news/details?articleUuid=ab6cce3a-993f-4e85-9594-95d51412e6ab&src=web",
#                          "og:description": "Fans haven't been offered refunds after they saw less than 10 minutes of practice Thursday night.",
#                          "twitter:creator": "@nickbromberg",
#                          "al:ios:app_store_id": "286058814",
#                          "twitter:dnt": "on",
#                          "twitter:image": "https://s.yimg.com/ny/api/res/1.2/Jdx5rsirUFNazhm4xyKmkw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e1017110-8639-11ee-bff9-d941cf760a17",
#                          "oath:guce:consent-host": "guce.yahoo.com",
#                          "twitter:site": "@YahooSports",
#                          "news_keywords": "Max Verstappen, Las Vegas Grand Prix, Carlos Sainz, Mario Renzi, drain cover, race merchandise, Getty Images",
#                          "twitter:title": "Max Verstappen on Las Vegas GP's merchandise voucher offer: 'If I was a fan, I would tear the whole place down'",
#                          "og:type": "article",
#                          "al:ios:app_name": "Yahoo Sports",
#                          "og:title": "Max Verstappen on Las Vegas GP's merchandise voucher offer: 'If I was a fan, I would tear the whole place down'",
#                          "og:image:height": "675",
#                          "twitter:image:src": "https://s.yimg.com/ny/api/res/1.2/Jdx5rsirUFNazhm4xyKmkw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e1017110-8639-11ee-bff9-d941cf760a17",
#                          "al:android:url": "ysportacular://v2/news/details?articleUuid=ab6cce3a-993f-4e85-9594-95d51412e6ab&src=web",
#                          "viewport": "width=device-width, initial-scale=1",
#                          "twitter:description": "Fans haven't been offered refunds after they saw less than 10 minutes of practice Thursday night.",
#                          "og:url": "https://sports.yahoo.com/max-verstappen-on-las-vegas-gps-merchandise-voucher-offer-if-i-was-a-fan-i-would-tear-the-whole-place-down-174353651.html",
#                          "al:android:app_name": "Yahoo Sports"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://s.yimg.com/ny/api/res/1.2/Jdx5rsirUFNazhm4xyKmkw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/e1017110-8639-11ee-bff9-d941cf760a17"
#                     }
#                ]
#           }
#      },
#      {
#           "kind": "customsearch#result",
#           "title": "Max Verstappen qualifies on pole for the Qatar Grand Prix. He can ...",
#           "htmlTitle": "<b>Max Verstappen</b> qualifies on pole for the Qatar Grand Prix. He can ...",
#           "link": "https://www.benningtonbanner.com/lifestyle/max-verstappen-qualifies-on-pole-for-the-qatar-grand-prix-he-can-win-the-title/article_35218f12-0086-534c-b26d-ac9843b2aaa3.html",
#           "displayLink": "www.benningtonbanner.com",
#           "snippet": "Oct 6, 2023 ... Max Verstappen has qualified on pole for the Qatar Grand Prix, a day before he can secure his third consecutive Formula One title in the\u00a0...",
#           "htmlSnippet": "Oct 6, 2023 <b>...</b> <b>Max Verstappen</b> has qualified on pole for the Qatar Grand Prix, a day before he can secure his third consecutive Formula One title in the&nbsp;...",
#           "cacheId": "g8mAMDxs9bgJ",
#           "formattedUrl": "https://www.benningtonbanner.com/.../max-verstappen.../article_35218f12-...",
#           "htmlFormattedUrl": "https://www.benningtonbanner.com/.../<b>max</b>-<b>verstappen</b>.../article_35218f12-...",
#           "pagemap": {
#                "cse_thumbnail": [
#                     {
#                          "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRn0Z0nCL67czMNlGStatLiKuZ9T7RVwTahK-b04y1YyAnJq4FLYTNqx4KI",
#                          "width": "300",
#                          "height": "168"
#                     }
#                ],
#                "thumbnail": [
#                     {
#                          "src": "https://dims.apnews.com/dims4/default/dce115c/2147483647/strip/true/crop/4606x2591+0+240/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F1a%2F52%2F141208826ef521a9b64d08ac1703%2Fbb42ead86c454d3aad892a82fa652e73"
#                     }
#                ],
#                "metatags": [
#                     {
#                          "og:image": "https://dims.apnews.com/dims4/default/dce115c/2147483647/strip/true/crop/4606x2591+0+240/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F1a%2F52%2F141208826ef521a9b64d08ac1703%2Fbb42ead86c454d3aad892a82fa652e73",
#                          "og:image:width": "1440",
#                          "article:published_time": "2023-10-06T14:43:42",
#                          "twitter:card": "summary_large_image",
#                          "og:site_name": "AP News",
#                          "og:image:type": "image/jpeg",
#                          "og:description": "Max Verstappen has qualified on pole for the Qatar Grand Prix, a day before he can secure his third consecutive Formula One title in the sprint race.",
#                          "twitter:image": "https://dims.apnews.com/dims4/default/dce115c/2147483647/strip/true/crop/4606x2591+0+240/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F1a%2F52%2F141208826ef521a9b64d08ac1703%2Fbb42ead86c454d3aad892a82fa652e73",
#                          "twitter:image:alt": "Red Bull driver Max Verstappen of the Netherlands walks aftter the qualifying session ahead of the Qatar Formula One Grand Prix at the Lusail International Circuit in Lusail, Qatar, Friday, Oct. 6, 2023. (AP Photo/Ariel Schalit, Pool)",
#                          "twitter:site": "@AP",
#                          "article:modified_time": "2023-10-06T22:11:33.534",
#                          "brightspot.contentid": "5b354fa2-c644-3e7d-b171-9f08a8774885",
#                          "thumbnail": "https://dims.apnews.com/dims4/default/dce115c/2147483647/strip/true/crop/4606x2591+0+240/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F1a%2F52%2F141208826ef521a9b64d08ac1703%2Fbb42ead86c454d3aad892a82fa652e73",
#                          "og:image:alt": "Red Bull driver Max Verstappen of the Netherlands walks aftter the qualifying session ahead of the Qatar Formula One Grand Prix at the Lusail International Circuit in Lusail, Qatar, Friday, Oct. 6, 2023. (AP Photo/Ariel Schalit, Pool)",
#                          "og:type": "article",
#                          "article:section": "Sports",
#                          "twitter:title": "Max Verstappen qualifies on pole for the Qatar Grand Prix. He can win the title in Saturday's sprint",
#                          "og:image:url": "https://dims.apnews.com/dims4/default/dce115c/2147483647/strip/true/crop/4606x2591+0+240/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F1a%2F52%2F141208826ef521a9b64d08ac1703%2Fbb42ead86c454d3aad892a82fa652e73",
#                          "ga-datalayer": "{\n  \"dimension1\" : \"692f17dbfdf29e68e3ab31ee0c1bde96\",\n  \"dimension15\" : \"George Russell,Sports - Europe,Auto Racing,Automobile racing,Formula One racing,Max Verstappen\",\n  \"dimension9\" : \"2023-10-06 10:43:42\",\n  \"dimension10\" : \"\"\n}",
#                          "og:title": "Max Verstappen qualifies on pole for the Qatar Grand Prix. He can win the title in Saturday's sprint",
#                          "og:image:height": "810",
#                          "article:tag": "George Russell",
#                          "fb:app_id": "2220391788200892",
#                          "viewport": "width=device-width, initial-scale=1, minimum-scale=1",
#                          "twitter:description": "Max Verstappen has qualified on pole for the Qatar Grand Prix, a day before he can secure his third consecutive Formula One title in the sprint race.",
#                          "og:url": "https://apnews.com/article/f1-qatar-max-verstappen-practice-qualifying-692f17dbfdf29e68e3ab31ee0c1bde96",
#                          "gtm-datalayer": "{\n  \"event\" : \"Article Visited\",\n  \"Item_Id\" : \"692f17dbfdf29e68e3ab31ee0c1bde96\",\n  \"TagArray\" : \"George Russell,Sports - Europe,Auto Racing,Automobile racing,Formula One racing,Max Verstappen\",\n  \"item_ID\" : \"692f17dbfdf29e68e3ab31ee0c1bde96\",\n  \"tag_array\" : \"George Russell,Sports - Europe,Auto Racing,Automobile racing,Formula One racing,Max Verstappen\",\n  \"headline\" : \"Max Verstappen qualifies on pole for the Qatar Grand Prix. He can win the title in Saturday's sprint\",\n  \"publication_date\" : \"2023-10-06 10:43:42\",\n  \"author\" : \"\",\n  \"linked_video\" : \"NO\",\n  \"pr_content\" : \"NO\",\n  \"featured\" : \"NO\",\n  \"lead_media\" : \"Photo\"\n}"
#                     }
#                ],
#                "cse_image": [
#                     {
#                          "src": "https://dims.apnews.com/dims4/default/dce115c/2147483647/strip/true/crop/4606x2591+0+240/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F1a%2F52%2F141208826ef521a9b64d08ac1703%2Fbb42ead86c454d3aad892a82fa652e73"
#                     }
#                ]
#           }
#      }
# ]
