# %%
import requests
from bs4 import BeautifulSoup # para analizar el HTML
import pandas as pd
import numpy as np
from boilerpy3 import extractors
import html2text
import re
import time
from openai import OpenAI

# %% [markdown]
# ### OBTAIN THE METADATA OF THE PAGE
# The metadata is a simple description of the page.

# %% [markdown]
# First we scrape the url of the company to extract the html in raw

# %%
def html_request(url: str):
    try:
        # Realizar la solicitud HTTP
        response = requests.get(url)
        response.raise_for_status()  # Lanzar una excepción para errores HTTP 

        # Verificar si la solicitud fue exitosa (código de estado 200)
        print(response.status_code)
        if response.status_code == 200:
            # Parsear el contenido HTML de la página
            soup = BeautifulSoup(response.text, 'html.parser')
            return soup
        else:
            print(f'Error al realizar la solicitud. Código de estado: {response.status_code}')
            return f'ERROR!: {response.status_code}'
    
    except requests.exceptions.RequestException as e:
        # Capturar excepción de solicitud y devolver un mensaje de error
        return f'Request_error!: {e}'

    except Exception as e:
        # Capturar cualquier otra excepción y devolver un mensaje de error
        return f'Unexpected_error!: {e}'

# %% [markdown]
# We filter the html to obtain the tag meta where we obtain a little description of the url

# %%
def obtain_metadata(html):
    if html is None or not isinstance(html, BeautifulSoup):
        return html
    
    meta_tags = html.find_all('meta')  

    # Inicializar un diccionario para almacenar la metadata
    metadata = {}

    # Iterar sobre las etiquetas meta y extraer información relevante
    for tag in meta_tags:
        nombre = tag.get('name', '').lower()
        propiedad = tag.get('property', '').lower()
        contenido = tag.get('content', '')

        if nombre or propiedad:
            # Almacenar la información en el diccionario de metadata
            metadata[nombre or propiedad] = contenido

    return metadata

# %%
csv_file = '/home/unai/datasets/POC Description of operations - Sheet3.csv'
# Leer el archivo CSV y crear un DataFrame
data = pd.read_csv(csv_file)

# %%
data.head()
# Out:
#                           Company_NAME  SIC1            URL  \
# 0                BRINK'S UKRAINE, INC.  7381  us.brinks.com
# 1                    AES CALGARY, INC.  4911    www.aes.com
# 2              AURORA AES HOLDINGS INC  4911    www.aes.com
# 3  AES CENTRAL AMERICAN HOLDINGS, INC.  4911    www.aes.com
# 4             AES CARBON HOLDINGS, LLC  4911    www.aes.com
#
#                                                  WEB  \
# 0  see my product options\nThe way in which you h...
# 1  e n e r g y\nAccelerating the future of\nenerg...
# 2  e n e r g y\nAccelerating the future of\nenerg...
# 3  e n e r g y\nAccelerating the future of\nenerg...
# 4  e n e r g y\nAccelerating the future of\nenerg...
#
#                                         wikipedia_v1  \
# 0                                                NaN
# 1  TransAlta Corporation (formerly Calgary Power ...
# 2  This is a list of companies in the United Stat...
# 3  Union Pacific Corporation is a publicly traded...
# 4  The Abu Dhabi National Oil Company (Arabic: شر...
#
#                                         wikipedia_v2  wikipedia_v3  \
# 0  Joseph Robinette Biden Jr. (  BY-dən; born Nov...           NaN
# 1  TransAlta Corporation (formerly Calgary Power ...           NaN
# 2  This is a list of companies in the United Stat...           NaN
# 3  Union Pacific Corporation is a publicly traded...           NaN
# 4  The Abu Dhabi National Oil Company (Arabic: شر...           NaN
#
#                                                WEB_2
# 0  #  Navigation\n\n  * Skip to Content \n\n##  A...
# 1  Skip to main content\n\n[ ![Home](/themes/cust...
# 2  Skip to main content\n\n[ ![Home](/themes/cust...
# 3  Skip to main content\n\n[ ![Home](/themes/cust...
# 4  Skip to main content\n\n[ ![Home](/themes/cust...

# %%
data.loc[data['URL'] == 'www.columbuslibrary.org']
# Out:
#                       Company_NAME  SIC1                      URL  \
# 190  COLUMBUS METROPOLITAN LIBRARY  8231  www.columbuslibrary.org
#
#                                                    WEB  \
# 190  Tuesday, Dec. 5 | 7 p.m.\nTune in to watch Sta...
#
#                                           wikipedia_v1  \
# 190  Downtown Columbus is the central business dist...
#
#                                           wikipedia_v2  wikipedia_v3 WEB_2
# 190  Downtown Columbus is the central business dist...           NaN   NaN

# %%
url = 'https://'
url = url + 'www.columbuslibrary.org'  #'www.carlyle.com', 'www.creelighting.com'
html = html_request(url)
# Out:
# 200

# %%
metadata = obtain_metadata(html)
# Imprimir la metadata obtenida
for clave, valor in metadata.items():
    print(f'{clave}: {valor}')
# Out:
# viewport: width=device-width, initial-scale=1
# robots: index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1
# description: Columbus Metropolitan Library offers helpful services and resources to the Columbus, Ohio community. Browse our library, find information, and access our tools today!
# og:locale: en_US
# og:type: website
# og:title: Columbus Metropolitan Library
# og:description: Columbus Metropolitan Library offers helpful services and resources to the Columbus, Ohio community. Browse our library, find information, and access our tools today!
# og:url: https://www.columbuslibrary.org/
# og:site_name: Columbus Metropolitan Library
# article:publisher: https://www.facebook.com/columbuslibrary/
# article:modified_time: 2023-12-11T12:25:43+00:00
# og:image: https://www.columbuslibrary.org/wp-content/uploads/2023/02/150_orange_nt-1024x734.png
# twitter:card: summary_large_image
# twitter:site: @columbuslibrary
# generator: Elementor 3.18.2; features: e_dom_optimization, e_optimized_assets_loading, additional_custom_breakpoints, block_editor_assets_optimize, e_image_loading_optimization; settings: css_print_method-external, google_font-enabled, font_display-auto
# theme-color: #FFF
# msapplication-tileimage: https://www.columbuslibrary.org/wp-content/uploads/2020/08/CML_favicon.jpg

# %% [markdown]
# Here in an example, we can see the info obtained inside the meta tag of the html. As we can see the description field, summarizes in a single line the objectives of the organization

# %% [markdown]
# ### Verify the type of response from the metadata in 10 companies

# %%
urls = data['URL'].sample(n=10, random_state=1)

# %%
all_urls = data['URL']

# %%
url_descriptions_all = {}
url_descriptions_all = pd.DataFrame({'URL': all_urls})
url_base = 'http://'
for url in all_urls:
    print(url)
    url_completa = url_base + url
    html = html_request(url_completa)
    metadata = obtain_metadata(html)
    if type(metadata) != str:
        print(metadata.get('description'))
        url_descriptions_all.loc[url_descriptions_all['URL'] == url, 'metadata'] = metadata.get('description')
    else:
        url_descriptions_all.loc[url_descriptions_all['URL'] == url, 'metadata'] = metadata
# Out:
# us.brinks.com
# 200
# When you choose Brink’s, you’ll help your business save time and money while optimizing your operations, protecting your funds, managing your cash.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.haydonkerkpittman.com
# www.ametek.com
# www.ametek.com
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.hilton.com
# 200
# Explore Hilton's portfolio of hotels and distinct brands across the globe. Book directly for the best rates during your next stay. Expect better, expect Hilton.
# jobs.uhsinc.com
# 200
# UHS Careers
# www.aptar.com
# 200
# Aptar is a global leader in drug and consumer product dosing, dispensing and protection technologies. Learn more about our innovative solutions.
# www.avaya.com
# 200
#  Build great experiences for your brand with Avaya's suite of cloud-based solutions designed to suit the specific needs of your team.
# www.avaya.com
# 200
#  Build great experiences for your brand with Avaya's suite of cloud-based solutions designed to suit the specific needs of your team.
# www.15w61.com
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.aetnabetterhealth.com
# 200
# Aetna Better Health offers Medicaid plans in many states across the country. Learn more about what Medicaid health plans are available to you.
# www.rentgulphmillsvillage.com
# 200
# Looking for King of Prussia apartments for rent? Gulph Mills Village Apartments offers the location, floor plans, and amenities you desire. Contact us today!
# www.chrobinson.com
# 200
# Reliably meet all your global logistics and technology needs with C.H. Robinson. Supply chain management is optimized with our experience, data, and scale.
# www.chrobinson.com
# 200
# Reliably meet all your global logistics and technology needs with C.H. Robinson. Supply chain management is optimized with our experience, data, and scale.
# jobs.uhsinc.com
# 200
# UHS Careers
# www.atkore.com
# 200
# Atkore manufactures electrical conduit and fittings, cable and cable management systems, infrastructure, safety and security products.
# www.american-equity.com
# 200
# An American-owned and operated company, American Equity Investment Life Insurance Company® is a leader in the fixed index annuities marketplace.
# www.bshv-sc.com
# 200
# None
# products.bankerslife.com
# 200
# Bankers Life insurance agents/producers help 1.3 million policyholders to safeguard against unexpected health costs, generate guaranteed income, protect loved ones and promote an enduring legacy. Our knowledgeable team members sit down with you to understand your preferences and retirement goals.  You can rest assured that you’ll learn about insurance products and solutions that are appropriate for you and your family.
# aramark.gcs-web.com
# 200
# The Investor Relations website contains information about Aramark's business for stockholders, potential investors, and financial analysts.
# jobs.uhsinc.com
# 200
# UHS Careers
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.aspentech.com
# 200
# Our software tackles the most complex process manufacturing challenges, creating value and improving profitability for our customers. The industries that drive our economies and touch our lives are optimized by aspenONE software every day. The world’s leading oil & gas, chemical, engineering & construction, pharmaceutical, food, beverage, and consumer packaged goods companies all rely on AspenTech to run their business.
# www.asbhawaii.com
# 200
# American Savings Bank Hawaii offers consumer and business banking services including checking, savings, CDs, mortgages, loans and lines, and online banking.
# www.asburycareers.com
# 200
# Asbury Automotive offers various career oppotunties across the country. Browse positions in sales, service, and corporate to help us become the most admired automotive retailer.
# www.asburyauto.com
# 200
# Browse vehicles, make a selection, purchase and finance your next vehicle, and schedule your next service. All completely online.
# www.chrysler.com
# 200
# Unleash luxury and versatility with Chrysler's minivans and the 300 sedan. Explore Pacifica, Pacifica Hybrid, dealerships, incentives & more at Chrysler.com.
# www.arescre.com
# 200
# None
# www.animalsinc.net
# www.bookingholdings.com
# www.aspencore.com
# www.aspentech.com
# 200
# Our software tackles the most complex process manufacturing challenges, creating value and improving profitability for our customers. The industries that drive our economies and touch our lives are optimized by aspenONE software every day. The world’s leading oil & gas, chemical, engineering & construction, pharmaceutical, food, beverage, and consumer packaged goods companies all rely on AspenTech to run their business.
# www.aikenregional.com
# 200
# Aiken Regional is a 273-bed acute care facility that provides emergency, oncology and internal medicine services.
# www.blueridgesurgicalcenter.com
# 200
# None
# www.asburyauto.com
# 200
# Browse vehicles, make a selection, purchase and finance your next vehicle, and schedule your next service. All completely online.
# www.amkor.com
# www.amnhealthcare.com
# 200
# AMN Healthcare offers innovative staffing and total talent solutions. People are at the heart of everything you do as we empower the future of care.
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# www.sertasimmonsbedding.com
# 200
# Serta Simmons Bedding, LLC is the world’s leading producer of mattresses and sleep experiences. We have been defining and refining the world of sleep since 1870 and every day we continue to give people the sleep they need to live the lives they want.
# www.atmosenergy.com
# 200
# None
# www.beazer.com
# 200
# One of the nation’s largest homebuilders, Beazer Homes builds homes that set the industry standard for energy efficiency and personalization.
# www.chevrolet.com
# 200
# Official Chevrolet site: see Chevy cars, trucks, crossovers & SUVs - see photos/videos, find vehicles, compare competitors, build your own Chevy & more.
# www.honda.com
# www.aflac.com
# 200
# Aflac provides supplemental insurance to help pay out-of-pocket expenses your major medical insurance doesn't cover. Get started with a quote today!
# www.aflac.com
# 200
# Aflac provides supplemental insurance to help pay out-of-pocket expenses your major medical insurance doesn't cover. Get started with a quote today!
# www.capitalonecareers.com
# 200
# You’re tenacious and driven, so the last place you want to work is some boring bank. Same. Learn about careers at Capital One and view jobs here.
# www.brighthousefinancial.com
# www.brighthousefinancial.com
# www.onebarnes.com
# 200
# Barnes is a global provider of highly engineered products, differentiated industrial technologies, and innovative solutions, serving a wide range of end markets and customers.
# www.davita.com
# 200
#
# www.assemblyroomstudios.la
# www.hrblock.com
# 200
# Get the online tax preparation services you need with the tax refund you want. Whether you efile or work with an H&R Block tax pro, our services are guaranteed.
# www.hbfuller.com
# 200
# H.B. Fuller, experts in industrial adhesives, industrial coatings, industrial sealants and specialty materials in two dozen markets. Learn more.
# cabotog.gcs-web.com
# 200
# The Investor Relations website contains information about Cabot Corporation's business for stockholders, potential investors, and financial analysts.
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# www.beazer.com
# 200
# One of the nation’s largest homebuilders, Beazer Homes builds homes that set the industry standard for energy efficiency and personalization.
# www.bdbiosciences.com
# 200
# BD Biosciences provides flow cytometers, reagents, tools, and a wide range of services to support the work of researchers and clinicians who understand disease and improve care.
# www.buffalowildwings.com
# 200
# Enjoy all Buffalo Wild Wings to you has to offer when you order delivery or pick it up yourself or stop by a location near you. Buffalo Wild Wings to you is the ultimate place to get together with your friends, watch sports, drink beer, and eat wings.
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# www.assurant.com
# 200
# We help our global clients protect and support the major purchases consumers make — like homes, cars, appliances, and phones — in new and thoughtful ways.
# www.brookdale.com
# www.brookdale.com
# www.amscan.com
# 200
# None
# www.aftonchemical.com
# www.agstatesagency.com
# 200
# None
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# uhs.jibeapply.com
# 200
# UHS Careers
# www.greenmountainenergy.com
# 200
# Green Mountain Energy is a 100% renewable energy company providing clean electricity to consumers & businesses in TX, IL, PA, NY, MA, NJ, MD, & OR. Join our mission.
# www.moorscabot.com
# 200
# Wealth management founded on a relationship.
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# www.calumet.com
# www.middleby.com
# 200
# Middleby is a world leader in manufacturing innovative cooking equipment for the commercial, residential, and industrial foodservice markets.
# www.liveventures.com
# 200
# Live Ventures
# www.belden.com
# 200
# We design, manufacture and market networking, connectivity, cable products and solutions for industrial automation, smart buildings and broadcast markets.
# aloft-hotels.marriott.com
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.stanleyblackanddecker.com
# 200
# Headquartered in the USA, Stanley Black & Decker is the world’s largest tool company with 50 manufacturing American facilities and more than 100 worldwide.
# www.stanleyblackanddecker.com
# 200
# Headquartered in the USA, Stanley Black & Decker is the world’s largest tool company with 50 manufacturing American facilities and more than 100 worldwide.
# www.assurant.com
# 200
# We help our global clients protect and support the major purchases consumers make — like homes, cars, appliances, and phones — in new and thoughtful ways.
# www.carespot.com
# 200
# None
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# www.zimmerbiomet.com
# 200
# As a global medical technology leader, Zimmer Biomet pushes the boundaries of implant innovation to redefine what's possible across all stages of the patient journey.
# www.zimmerbiomet.com
# 200
# As a global medical technology leader, Zimmer Biomet pushes the boundaries of implant innovation to redefine what's possible across all stages of the patient journey.
# www.outback.com
# insurance.adp.com
# 200
# ADPIA (Automatic Data Processing Insurance Agency) is here to offer simple business insurance options for your company.
# www.arcolasecurities.com
# 200
# Arcola Securities
# www.stanleyblackanddecker.com
# 200
# Headquartered in the USA, Stanley Black & Decker is the world’s largest tool company with 50 manufacturing American facilities and more than 100 worldwide.
# www.outback.com
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.gpreinc.com
# 200
# We are a leading agri-tech company committed to transforming our platform to process annually renewable crops into more sustainable, high-value ingredients.
# www.carrabbas.com
# www.carrabbas.com
# www.guess.com
# us.brinks.com
# 200
# When you choose Brink’s, you’ll help your business save time and money while optimizing your operations, protecting your funds, managing your cash.
# us.brinks.com
# 200
# When you choose Brink’s, you’ll help your business save time and money while optimizing your operations, protecting your funds, managing your cash.
# us.brinks.com
# 200
# When you choose Brink’s, you’ll help your business save time and money while optimizing your operations, protecting your funds, managing your cash.
# www.blackhillscorp.com
# www.gbrx.com
# 200
# The Greenbrier Companies can trace its roots to a 1919 steel fabricator company in Portland, OR. Since then, we’ve evolved to become a global leader in transportation manufacturing and freight services.
# www.ensignnr.com
# 200
# Ensign Natural Resources is a private equity backed exploration and production company focused on acquiring, developing, and producing US unconventional resources.
# www.hhzf23.com
# www.mongodb.com
# 200
# Get your ideas to market faster with a developer data platform built on the leading modern database. MongoDB makes working with data easy.
# www.ocgoodwill.org
# new.siemens.com
# 200
# Visit Siemens, the technology company focused on industry, infrastructure, transport, and healthcare.
# www.tpb.co
# 200
# Founded by Dave Friedberg, The Production Board (TPB) is a holding company of businesses established to solve the most fundamental problems that affect our planet, by reimagining systems of production in agriculture, food, biomanufacturing, human health and life sciences. TPB builds new businesses from scratch based on emerging scientific discoveries, partners with exceptional talent, and provides them with the capital, infrastructure and market insights needed to deliver a 10x improvement in the cost, energy, time, or carbon footprint of conventional systems.
# www.tecovas.com
# 200
# Tecovas offers beautiful, handmade western boots & accessories sold directly to you at honest prices. Free shipping, returns, & exchanges.
# www.oilstatesintl.com
# 200
#
# www.kindermorgan.com
# 200
# We're one of North America's largest energy infrastructure companies. Our pipelines transport natural gas, carbon dioxide (CO2) and more. Contact us today.
# www.zerohash.com
# 200
# None
# www.pinecrestnnv.org
# 200
# Our mission is to provide an innovative, challenging curriculum in a loving environment that furthers a philosophy of respect and high expectations for all students, parents, teachers, and staff.
# www.turnriver.com
# 200
# None
# drugdevelopment.labcorp.com
# 200
# Labcorp's global research, development and testing organization provides drug and medical device development services. We serve pharmaceutical and biotechnology companies.
# www.ftdi.com
# 200
# For more than 100 years, FTD has stood for quality, creativity and worldwide floral delivery. Our network of florists continues to be the lifeblood of FTD. We continue to support our floral network through our innovative spirit and commitment to raising the awareness of giving flowers. New products and technology solutions are designed to help you increase revenue and drive local business to your shop.
# www.masterdesignguide.com
# 200
# Phoenix Contact - the innovative market leader of industrial connection technology, automation technology, electronic Interface systems and surge protection
# www.cex.io
# 200
# The leading cryptocurrency exchange platform offers different trading options, provides 24/7 customer support, high level of security, and stable deposits and withdrawals. Buy &amp; sell crypto &amp; bitcoin online with CEX.IO
# www.nmhealthcarevalue.org
# jobs.owenscorning.com
# 200
# Apply online for jobs at Owens Corning Career Site
# www.porsche.com
# 200
# Welcome to the official Porsche Website with detailed information about Porsche Models, Pre-owned Cars, Porsche Motorsport, the company, etc.
# www.dsmiami.com
# www.spectrumvisionpartners.com
# www.oneok.com
# www.rubyseas.com
# 200
# Seafood Company with decades of experience in international seafood markets. We specialize in fish and seafood commodity items such as tilapia, swai, grouper, shrimp, scallops, crab and lobster from our Bahama processing plant.
# www.gulfside.org
# 200
# GHS is a non-profit organization offering hospice, skilled home health care, and palliative care for serious, chronic and late stage illnesses.
# www.ridebeep.com
# 200
# Beep is an Autonomous Mobility as a Service provider servicing public transit operators, communities, campuses and airports.
# www.xperiencerg.com
# 200
# Xperience Restaurant Group is a leading full-service casual dining operator! Check out all of the brands that we operate!
# www.rrd.com
# 200
# RRD offers the most trusted portfolio of marketing, packaging, print, and supply chain solutions. We transform customer touchpoints into moments of impact.
# www.nexeoplastics.com
# 200
# Nexeo Plastics distributes plastic and polymer resins from top suppliers for automotive parts, medical applications, packaging, 3D printing, and more.
# www.credit-suisse.com
# 200
# Credit Suisse Group is a leading financial services company, advising clients in all aspects of finance, across the globe and around the clock.
# www.altoneuroscience.com
# 200
# Precision medicine for the brain is here. We are pioneering an approach to psychiatric drug development which matches the right patient with the right Alto drug based on AI-derived brain biomarkers.
# www.dresserutility.com
# www.berryglobal.com
# 200
# Berry Global, leaders in plastic packaging manufacturing, process & sustainable product innovation & design. Learn more about our capabilities
# www.bold.com
# www.nationsconstruction.com
# 200
# Are you in need of a reliable construction company in Houston, TX? Nations Construction is the company for you. Contact us today!
# www.trmc-al.com
# 200
# None
# www.aflac.com
# 200
# Aflac provides supplemental insurance to help pay out-of-pocket expenses your major medical insurance doesn't cover. Get started with a quote today!
# www.bfly.com
# 200
# Butterfly Equity is a Los Angeles-based private equity firm specializing in the food sector from seed to fork across the following key verticals: agriculture & aquaculture, food & beverage products, food distribution and foodservice. Our team has significant experience across food, private equity and technology and has been involved in investing more than $10 billion of equity capital in companies ranging from growth-stage to Fortune 500 enterprises.
# www.onarchipelago.com
# 200
# Archipelago helps you overcome challenges you experience in working with traditional spreadsheet property schedules.
# www.rapiddeploy.com
# 200
# Every moment matters in the mission to save lives. RapidDeploy is the leading cloud-native platform for Public Safety. We provide Next Generation solutions that deliver intelligent information and drive better outcomes in mission critical situations.
# www.altg.com
# 200
# Alta is your source for new and used material handling and construction equipment for sale with 57 locations in Florida, Illinois, Michigan, New England, New York, Northern Indiana, and Ohio.
# www.core4ce.com
# www.desktopmetal.com
# 200
# Desktop Metal™ exists to make metal 3D printing and carbon fiber 3D printing accessible to all engineers, designers, and manufacturers.
# www.enochianbio.com
# www.contixo.com
# 200
# Help your child grow and prepare for the next stage of their life. Invest in their future with Contixo education al products such as kids tablets, STEM products, and more. Explore our products today!
# www.missionhealth.org
# www.illingworthresearch.com
# 200
# Passion for research, compassion for patients. Clincal research services designed to make clincal research easier for the patient.
# www.digitalocean.com
# 200
# Simple, scalable cloud hosting solutions built for small and mid-sized businesses.
# www.kwu.edu
# 200
# Discover The Power of AND at Kansas Wesleyan University!
# www.workday.com
# 200
# Workday Enterprise Management Cloud gives organizations of all sizes the power to adapt through finance, HR, planning, spend management, and analytics applications. Move beyond ERP and deliver extraordinary results in a changing world. Learn more.
# www.aveciapharma.com
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.pingcap.com
# 200
# TiDB is an advanced, open-source, distributed SQL database for modern apps. MySQL compatible, TiDB powers companies like Block, Catalyst, and Capcom.
# www.usaretirement.org
# 200
# American Retirement Association (ARA) is a nonprofit organization comprised of five associations, dedicated to the nation’s private retirement system.
# www.tsys.com
# www.momentus.space
# 200
# None
# www.vikingpest.com
# secure.libertycable.com
# 200
# None
# www.kindredhospitals.com
# 200
# At Kindred, our mission is to help our patients reach their highest potential for health and healing with intensive medical and rehabilitative care through a compassionate patient experience.
# www.intervenn.com
# www.havenparkcommunities.com
# www.tmacompanies.com
# 200
# TMA
# www.kkr.com
# 200
# KKR is a leading global investment firm offering solutions in alternative assets spanning real estate, private credit, private equity, and infrastructure, as well as liquid credit, capital markets and insurance.
# www.alector.com
# 200
# Alector is a biopharmaceutical company that develops therapies for the treatment of neurodegeneration diseases.
# www.republicservices.jobs
# 200
# Be part of a team and make a difference with Republic Services. Join us now and help us leave the planet better than we found it.
# www.vanguardkia.com
# 200
# Get a new or used Kia from Vanguard Kia of Arlington. Browse our online inventory, schedule service, or order parts today!
# www.creelighting.com
# 200
# Cree Lighting is an LED lighting pioneer with deep roots and even deeper expertise. Shop our solutions today from LED outdoor lights to recessed lighting!
# www.columbuslibrary.org
# 200
# Columbus Metropolitan Library offers helpful services and resources to the Columbus, Ohio community. Browse our library, find information, and access our tools today!
# www.crestrockpartners.com
# 200
# Crest Rock Partners is an operationally focused investment firm dedicated
# to making control-oriented investments in the lower middle market. We
# invest in Software, Technology, Business Services and Industrial companies
# where we can bring substantial value to the companies and management teams
# we partner with.
# www.esprovisions.com
# 200
# Eastern Standard Provisions delivers expertly crafted, one-of-a-kind artisanal soft pretzels, Liège Belgian waffles, sourdough hard pretzel pieces, artfully blended sauces, and gourmet flavored salts and sugars. Because when it comes to snacking, you should love every bite.
# www.oakleafsurgical.com
# 200
# None
# www.indusholdingsinc.com
# 200
#
# www.thewengergroup.com
# 200
# We're a comprehensive Agricultural Company that includes Wenger Feeds, Dutchland Farms, Nutrify, Risser Grain, and Hoober Feeds.
# www.trewautomation.com
# 200
# Find TREW smart material handling automation | Warehouse Execution (WES), Warehouse Control (WCS), Robotics, Order Fulfillment and Conveyor Systems.
# www.bain.com
# 200
# Bain & Company is a top management consulting firm. We advise leaders on strategy, marketing, organization, operations, IT and M&A, across all industries and geographies.
# www.oceansoundpartners.com
# 200
# None
# www.savionenergy.com
# 200
# Savion delivers utility-scale solar and energy storage project development. Advancing photovoltaic energy to decarbonize the grid and deploy modern power.
# www.ferro.com
# www.sonalasense.com
# 200
# SonALAsense is the first company to advance Sonodynamic Therapy into clinical trials.
# www.coinmetrics.io
# www.arystalifescience.com
# www.saintlukeskc.org
# 200
# Saint Luke’s Health System consists of 16 area hospitals and campuses and several primary and specialty care practices, and provides a range of inpatient, outpatient, and home care services.
# www.bestchevrolet.com
# 200
# Welcome to Best Chevrolet in Kenner, LA! Supplying the New Orleans, Metairie & Baton Rouge area with quality new Chevys & used cars for sale. Visit us today!
# wordpress-352188-1092167.cloudwaysapps.com
# www.kadiant.com
# 200
# Kadiant provides world-class Applied Behavior Analysis (ABA) therapy for children. In-home, center, school, and community-based services.
# www.junehomes.com
# 200
# June Homes is a network of fully furnished bedrooms in prime spots available on flexible month-to-month terms in major American cities.
# www.minneapolisfoundation.org
# www.allianzlife.com
# 200
# Allianz Life offers annuities, life insurance, and Buffered ETFs that can help you manage risks to your retirement security.
# www.residentialhealthcaregroup.com
# www.patrickind.com
# 200
# For more than half a century, Patrick and its network of trusted, independent brands have worked to improve the quality of everyday life through better component products and building materials for our partners. Better living starts here.
# www.winktowebsterpipeline.com
# www.calix.com
# 200
# At Calix, we live to empower Communication Service providers of all sizes to simplify their business, excite their subscribers and grow their value.
# www.coalitioninc.com
# 200
# Coalition combines comprehensive cyber insurance coverage and security services to help businesses prevent digital risk before it strikes.
# www.infobip.com
# 200
# Engage your customers and prospects with simple drag and drop email, SMS, chatbot or build custom solutions with the best in class APIs
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# jobs.uhsinc.com
# 200
# UHS Careers
# www.scdunedin.com
# 200
# None
# www.itw.com
# 200
# Find out why our decentralized business model, customer-back innovation and support of our colleagues and community give us the competitive advantage.
# www.mosaic.co
# 200
# Mosaic Group
# www.oxy.com
# 200
# We are a best-in-class, low-cost operator with assets in the United States, Middle East, Africa and Latin America, applying technology to drive operational excellence and leveraging our global leadership in carbon management to advance our business.
# www.1635marketst.com
# www.hilton.com
# 200
# Explore Hilton's portfolio of hotels and distinct brands across the globe. Book directly for the best rates during your next stay. Expect better, expect Hilton.
# www.chilewich.com
# 200
# We make beautiful, durable and easy to clean placemats, indoor-outdoor mats, rugs, woven floor mats and runners. Free shipping on orders $200+. Shop the full collection.
# www.hibercell.com
# www.commsell.com
# www.springworkstx.com
# www.prudentamerican.com
# 200
# None
# www.mananalu.com
# 200
# Jason Momoa, founder of Mananalu, is creating a WAVE OF CHANGE to unplastic the planet by eliminating single-use plastic bottles.
# www.ocpna.com
# www.sciphermedicine.com
# www.emoryhealthcare.org
# 200
# Emory is your one-stop shop for all of your health care needs, both in sickness and in health.
# www.smartshift.com
# 200
# smartShift is the most advanced SAP transformation tool powered by intelligent automation AI, built by real SAP experts. Move to S/4HANA fast without disrupting business operations while reducing long timelines and operational risks.
# www.precisionbiosciences.com
# www.bhhsvdw.com
# 200
# Find homes for sale. Meet network agents who can help you buy or sell with confidence. Search for luxury properties, investment properties and other real estate.
# www.revescoproperties.com
# 200
#
# www.hiltongrandvacations.com
# 200
# At Hilton Grand Vacations, we believe life is incomplete without vacations. Learn how you can see the world from the comfort of our timeshare resorts
#
# www.mh.dental
# 200
#
# www.flexwheels.com
# www.energixrenewables.com
# 200
# Energix Renewables. A breakthrough green utility, committed to our future on the planet
# www.rocnation.com
# 200
# Roc Nation is a full-service entertainment company, inclusive of artist and athlete management, label, publishing, touring, film / TV and new ventures.
# www.bnbrenewables.com
# 200
# BNB Renewable Energy Holdings is a leading developer of wind, solar, and
# biogas power plants, focused primarily on helping utilities and Fortune 500
# companies in North and Latin America green their energy mix. BNB has
# originated in excess of 200MW of generation currently in operation, with
# another 200MW-plus under construction and a development pipeline of
# 1,200MW, including projects in Ohio, New Jersey, Connecticut, Pennsylvania,
# North Carolina, Florida, Utah, Illinois, Texas, and Mexico.
# www.welltower.com
# 200
# None
# ir.nasdaq.com
# 200
# The Investor Relations website contains information about Nasdaq, Inc.'s business for stockholders, potential investors, and financial analysts.
# www.yktal.com
# www.aterian.io
# 200
# At Aterian, we transform the way companies approach online sales. We empower brands of all sizes with technology and services that increase sales, automate marketing strategies, and provide continuous critical business intelligence.
# www.housby.com
# 200
# Housby is the home of Online Truck Sales, Mack Trucks, Used Trucks, Volvo Construction Equipment, Isuzu, Truck Service, Truck Parts and Mixers in Des Moines, IA
# www.novamedsurgeryofnashua.com
# 200
# None
# www.currentbyge.com
# 200
# None
# www.leamericas.com
# 200
# Linde is a global leader in the production, processing, storage and distribution of hydrogen.
# www.nspencer.k12.in.us
# www.morganstanley.com
# 200
# Discover how we help individuals, families, institutions and governments raise, manage and distribute the capital they need to achieve their goals.
# www.locomation.ai
# www.nexeoplastics.com
# 200
# Nexeo Plastics distributes plastic and polymer resins from top suppliers for automotive parts, medical applications, packaging, 3D printing, and more.
# www.sarens.com
# 200
# Sarens is the recognized worldwide leader and reference in heavy lifting and engineered transport.
# www.baystatehealth.org
# 200
# Baystate Health is a not-for-profit health system in western Massachusetts providing both specialized and primary care 200+ medical practices and 5 hospitals.
# www.basf.com
# 200
# None
# www.revitalize.earth
# 200
# Revitalize Earth is on a mission to raise the frequency of the planet through global wellness centers, cutting-edge agriculture, plant based medicines and indigenous job creation. The donations we receive here will help expedite this process and make a larger impact on those around us.
# www.tdxcorp.com
# 200
# None
# www.selectmedical.com
# www.selectmedical.com
# www.gogcg.com
# 200
# Making Connections Possible At GCG We Make Connections Possible through a nationwide network of facilities providing the wire, cable, automation and associated products and services that ensure connections, among families and friends, co-workers and customers, and the industrial equipment used across the country. Serving a wide variety of industries our experienced teams are Service-Oriented, Responsive […]
# www.kikcorp.com
# www.bluewhitelegalcapital.com
# 200
# None
# www.jackchevrolet.com
# 200
# Jack Chevrolet. The highest-rated Chevrolet dealership in Maine. We include a 15-year/ 150,000-mile warranty on all new and most pre-owned vehicles.
# www.aig.com
# 200
# American International Group, Inc, (AIG), is a global insurance organization providing a range of insurance and other financial services. Get to know us better.
# www.umoja-biopharma.com
# www.bkmedical.com
# www.celona.io
# 200
# At Celona, weâre engineering the future of networks with blazing fast 5G LAN solutions for the enterprise
# www.opwglobal.com
# 200
# OPW is the only manufacturer that can deliver the best quality loading arms, from pre-manufactured to custom designed for your specifications. Contact us today!
# www.sauers.com
# 200
# Shop Sauer Brands expansive line of mayonnaise, pourable salad dressings, condiments, sauces, spices, extracts and flavorings online!
# www.ameritas.com
# 200
# Competitive insurance and financial strategies do more than target your long-term financial goals. They give you freedom to enjoy today.
# www.ftportfolios.com
# 200
# None
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.tmlt.io
# 200
# State-of-the-art privacy technology that delivers better data insights to every enterprise.
# www.latitude38ent.com
# 200
#
# www.radicleinsights.com
# 200
# Radicle's network of hypergrowth professionals helps you surface critical insights, identify actionable opportunities, and hire transformational talent.
# www.pfizer.com
# 200
# Discover the commonalities and differences between biologics vs. biosimilars — especially when it comes to cost.
# www.uhaul.com
# www.uhaul.com
# www.welltower.com
# 200
# None
# www.kindermorgan.com
# 200
# We're one of North America's largest energy infrastructure companies. Our pipelines transport natural gas, carbon dioxide (CO2) and more. Contact us today.
# www.ritzcarlton.com
# 200
# Reserve now & choose from our collection of luxury hotel and resorts as you plan your next travel experience. Join our members Club for exclusive benefits.
# www.logisticspropco.com
# 200
# LPC is a logistics real estate platform focused on the acquisition, development & management of logistics properties in key North American markets.
# www.fmdiversion.gov
# 200
# The Metro Flood Diversion Authority (MFDA) is responsible for delivering the timely construction of the Fargo-Moorhead Area Diversion.
# www.victoriacp.com
# 200
# Victoria Capital Partners is managed by one of the most experienced private equity teams in South America, the senior members of which have been working together for an average of 13 years, investing in more than 20 companies since 1995.
# www.cambridgetrust.com
# 200
# Cambridge Trust is dedicated to providing private banking, business banking, and wealth management services.
# www.skims.com
# 200
# None
# www.enesco.com
# www.finhabits.com
# 200
# Finhabits ofrece el servicio de inversiones en la bolsa de valores de los Estados Unidos. Es la app financiera #1 en la comunidad latina de USA.
# www.rex-lumber.com
# www.thewaltdisneycompany.com
# 200
# The mission of The Walt Disney Company is to be one of the world's leading producers and providers of entertainment and information.
# www.epicmid.com
# www.arizonacollisioncenter.com
# www.hayesvalleyinn.com
# www.sea-electric.com
# www.kadiant.com
# 200
# Kadiant provides world-class Applied Behavior Analysis (ABA) therapy for children. In-home, center, school, and community-based services.
# www.thealliedgrp.com
# 200
# The Allied Group is New England's leading provider of fulfillment services. Allied Group offers printing, kitting, mailing and fulfillment services all under one roof. Allied Printing is the only ISO certified supplier in Rhode Island.

# %% [markdown]
# It looks good for a first approach, but a bit simple

# %%
url_descriptions_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   URL       300 non-null    object
#  1   metadata  267 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB

# %% [markdown]
# As we can see 33 organizations hadn't meta tag inside their html

# %%
metadata_csv = 'metadata_empresas.csv'

# Guardar el DataFrame en un archivo CSV
url_descriptions_all.to_csv(metadata_csv, index=False)

# %% [markdown]
# Now we want to see how many error have meen obtained during the request of the html because different reasons

# %%
errores_metadata = url_descriptions_all
errores_metadata['errores'] = url_descriptions_all['metadata'].apply(lambda x: str(x).lower().find('error'))

# %%
errores_metadata['errores'].value_counts(normalize=True)
# Out:
# errores
# -1    0.766667
#  8    0.233333
# Name: proportion, dtype: float64

# %% [markdown]
# ## INSIGHTS
# - We obtain a correct summarize of the organization role with the meta tag in 76% of the cases.
# - The company is the one that takes charge of writing the meta field. This implies that it can be something subjective

# %% [markdown]
# # OBTAIN DESCRIPTION BASED ON THE HTML TEXT AND A SUMMARIZER (CHATGPT)

# %%
html_extractor = extractors.ArticleExtractor()
html_extractor.get_content_from_url('https://www.carlyle.com/our-firm')
# Out:
# "Sorry, your browser doesn't support embedded videos\nWho We Are\nOur Firm\nCarlyle is one of the world’s largest and most diversified global investment firms, with $382 billion of assets under management across 3 business segments and 600 investment vehicles. Founded in 1987 in Washington, DC, our global team today is comprised of more than 2,200 professionals operating in 28 offices across 4 continents. Together, across our firm, our mission is to drive long-term value for our investors, companies, shareholders, people and communities.\nOur Business Segments\nGLOBAL PRIVATE EQUITY\nDirectory\nOur Approach\nSince our founding over 30 years ago, we have always looked to create lasting partnerships across all of our businesses. We work with our partners to find solutions that drive sustainable value and impact over the long term. We have built trust and credibility by leveraging our global scale, industry expertise and diverse insights to deliver better solutions and build better businesses. By approaching every investment with our full platform, we uncover new opportunities, transform businesses and foster innovation.\nThe Carlyle Advantage\nAs a leader in the industry, we’ve developed a formula for success that brings our full platform to every interaction and transaction. The combination of our global reach, industry expertise and diverse teams allow us to maintain our competitive advantage and partner with great management teams to build better businesses and make an impact.\nImage\nOur Reach\nGlobal Platform\nThrough our scale and extensive reach, our team is able to deliver a truly global platform. We are comprised of more than 2,200 professionals across 4 continents, which gives a broad perspective based on local knowledge and trusted relationships across the globe. Our team invests across asset classes, regions and industries on behalf of more than 3,000 investors from 87 countries, which further reflects our ability to reach all corners of the globe. Our investors range from public and private pension funds to wealthy individuals and families to sovereign wealth funds, unions and corporations. Through our reach, we are able to meet the dynamic needs of the world’s most sophisticated investors.\nImage\nOur Expertise\nDeep Industry Knowledge\nAt Carlyle, we lead with our depth of knowledge and industry expertise. We leverage our expertise across our businesses to ensure we are delivering the best solutions to our partners and companies. Maintaining our focus within key asset classes and industry sectors is what has allowed us to create true value for our partners and diligently grow our business over time.\xa0We focus on the\xa0industries in which we believe our deep expertise provides us with a competitive advantage. Across all of our businesses, we look to leverage our extensive knowledge in order to create the most value and impact over the long term.\nImage\nOur Diverse & Inclusive Team\nBetter Insights\nWe work hard to cultivate diverse and inclusive teams—with diverse perspectives, knowledge bases, interests and cultural identities—who can examine ideas from every angle to generate competitive business insights and make better decisions. We know diverse teams ask better questions and inclusive teams find better answers. By cultivating a diverse workforce and inclusive culture, we believe we can empower innovation and have an even greater impact on our investors, companies, shareholders, people and communities.\nCarlyle by the Numbers\nAs one of the world’s largest investment management firms, our assets are diversified across our business segments as well as the industries, sectors and regions in which we invest.\nImage\n"

# %% [markdown]
# This is a way of extracting only the text of the html with the boilerpy3 library

# %% [markdown]
# ### We try implementing spyder with the scraping (extract new info from the links inside the web)

# %%
# Ejemplo: Extraer todos los enlaces de la página
links = html.find_all('a')

# Imprimir los enlaces encontrados
href_values = [link.get('href') for link in links]
href_array = np.array(href_values, dtype=object)
href_array
# Out:
# array(['/?lang=en', '/?lang=fr',
#        '/document-library/?document_categories=spec-sheets',
#        '/company/careers/', '/contact/', '/resources/general-form/',
#        '/lighting-contact-form/', '/consumer-lighting-form/',
#        '/where-to-buy/', '/where-to-buy/commercial/',
#        '/where-to-buy/petroleum/',
#        '/products/intelligent-lighting/connected-max-smart-products/#where-to-buy',
#        'tel:800-236-6800', 'tel:800-473-1234', '/', '/products/',
#        '/products/outdoor/', '/products/outdoor/area/',
#        '/products/outdoor/canopy-and-soffit/',
#        '/products/outdoor/street-and-roadway/',
#        '/products/outdoor/decorative-street-and-roadway/',
#        '/products/outdoor/parking-structure/',
#        '/products/outdoor/bollards-and-pathway/',
#        '/products/outdoor/flood/', '/products/outdoor/wall-mount/',
#        '/products/outdoor/vapor-tight/',
#        '/products/outdoor/accessories-outdoor/',
#        '/products/outdoor/accessories-outdoor/?product_categories=poles-tenons-brackets',
#        '/products/indoor/', '/products/indoor/troffers/',
#        '/products/indoor/high-bay-low-bay/',
#        '/products/indoor/dynamic-skylight/',
#        '/products/indoor/specification-linear/',
#        '/products/indoor/surface-ambient/',
#        '/products/indoor/new-construction-downlights/',
#        '/products/indoor/retrofit-downlights/',
#        '/products/indoor/upgrade-solutions/', '/products/indoor/lamps/',
#        '/products/indoor/track/', '/products/indoor/exit-and-emergency/',
#        '/products/indoor/accessories/',
#        '/products/intelligent-lighting/connected-max-smart-products/',
#        '/products/residential/connected-max-smart-lighting/',
#        '/products/residential/connected-max-smart-cameras/',
#        '/products/residential/connected-max-smart-controllers/',
#        '/products/residential/',
#        '/products/residential/general-purpose-bulbs/',
#        '/products/residential/candelabras-residential/',
#        '/products/residential/outdoor-reflectors/',
#        '/products/residential/indoor-reflectors/',
#        '/products/residential/downlights/',
#        '/products/residential/tape-lighting/',
#        '/products/intelligent-lighting/',
#        '/products/intelligent-lighting/smartcast-wireless/',
#        '/products/intelligent-lighting/synapse-simplysnap/',
#        '/products/intelligent-lighting/lutron-enabled-solutions/',
#        '/products/intelligent-lighting/connected-max-smart-products/',
#        '/products/', '/products/outdoor/', '/products/outdoor/area/',
#        '/products/outdoor/canopy-and-soffit/',
#        '/products/outdoor/street-and-roadway/',
#        '/products/outdoor/decorative-street-and-roadway/',
#        '/products/outdoor/parking-structure/',
#        '/products/outdoor/bollards-and-pathway/',
#        '/products/outdoor/flood/', '/products/outdoor/wall-mount/',
#        '/products/outdoor/vapor-tight/',
#        '/products/outdoor/accessories-outdoor/',
#        '/products/outdoor/accessories-outdoor/?product_categories=poles-tenons-brackets',
#        '/products/indoor/', '/products/indoor/troffers/',
#        '/products/indoor/high-bay-low-bay/',
#        '/products/indoor/dynamic-skylight/',
#        '/products/indoor/specification-linear/',
#        '/products/indoor/surface-ambient/',
#        '/products/indoor/new-construction-downlights/',
#        '/products/indoor/retrofit-downlights/',
#        '/products/indoor/upgrade-solutions/', '/products/indoor/lamps/',
#        '/products/indoor/track/', '/products/indoor/exit-and-emergency/',
#        '/products/indoor/accessories/',
#        '/products/intelligent-lighting/connected-max-smart-products/',
#        '/products/residential/connected-max-smart-lighting/',
#        '/products/residential/connected-max-smart-cameras/',
#        '/products/residential/connected-max-smart-controllers/',
#        '/products/residential/',
#        '/products/residential/general-purpose-bulbs/',
#        '/products/residential/candelabras-residential/',
#        '/products/residential/outdoor-reflectors/',
#        '/products/residential/indoor-reflectors/',
#        '/products/residential/downlights/',
#        '/products/residential/tape-lighting/',
#        '/products/intelligent-lighting/',
#        '/products/intelligent-lighting/smartcast-wireless/',
#        '/products/intelligent-lighting/synapse-simplysnap/',
#        '/products/intelligent-lighting/lutron-enabled-solutions/',
#        '/products/intelligent-lighting/connected-max-smart-products/',
#        '/brands/', '/brands/cree-lighting-solutions/',
#        '/products/outdoor/?brands=cree-lighting',
#        '/products/indoor/?brands=cree-lighting', '/brands/c-lite/',
#        '/products/outdoor/?brands=c-lite',
#        '/products/indoor/?brands=c-lite', '/brands/',
#        '/brands/cree-lighting-solutions/',
#        '/products/outdoor/?brands=cree-lighting',
#        '/products/indoor/?brands=cree-lighting', '/brands/c-lite/',
#        '/products/outdoor/?brands=c-lite',
#        '/products/indoor/?brands=c-lite', '/applications/',
#        '/applications/gas-stations-c-stores/',
#        '/applications/cities-and-towns/',
#        '/applications/utility-lighting/',
#        '/applications/warehouse-and-industrial/',
#        '/applications/transportation/', '/applications/commercial/',
#        '/applications/schools-and-universities/', '/applications/retail/',
#        '/applications/auto-dealerships/', '/applications/healthcare/',
#        '/applications/parking-structures/', '/applications/case-studies/',
#        '/applications/', '/applications/gas-stations-c-stores/',
#        '/applications/cities-and-towns/',
#        '/applications/utility-lighting/',
#        '/applications/warehouse-and-industrial/',
#        '/applications/transportation/', '/applications/commercial/',
#        '/applications/schools-and-universities/', '/applications/retail/',
#        '/applications/auto-dealerships/', '/applications/healthcare/',
#        '/applications/parking-structures/', '/applications/case-studies/',
#        '/resources/', '/resources/',
#        '/resources/led-lighting-incentives/',
#        'https://cree.widen.net/s/mkdsn5gr5r/dlc-ssl-qualified-products-list',
#        '/resources/sales-terms-and-conditions/', '/resources/warranties/',
#        '/resources/technical-support-warranty-request/',
#        '/resources/end-of-life-disposal/',
#        'https://cree.widen.net/s/vgmnrxcl9s/cree-6-for-60-program-distributor-guidelines-2020',
#        '/resources/for-designers/',
#        '/document-library/?document_categories=spec-sheets',
#        '/applications/case-studies/',
#        '/resources/outdoor-layout-request/',
#        '/resources/indoor-layout-request/',
#        'https://cree.widen.net/s/vmhkmlshwj/cree-lighting-product-catalog',
#        '/resources/for-installers/',
#        '/document-library/?document_categories=installation-guides',
#        '/qr-code-enabled-field-serviceability/',
#        '/resources/for-consumers/', '/document-library/?keyword=dim',
#        '/products/intelligent-lighting/connected-max-smart-products/#set-up-support',
#        '/resources/warranties/', '/consumer-lighting-form/', '/insights/',
#        '/insights/',
#        'https://youtube.com/playlist?list=PLtNOdQhLNNaSVlttI2dymanpZsi5ce_Ic',
#        '/events/', '/resources/', '/resources/',
#        '/resources/led-lighting-incentives/',
#        'https://cree.widen.net/s/mkdsn5gr5r/dlc-ssl-qualified-products-list',
#        '/resources/sales-terms-and-conditions/', '/resources/warranties/',
#        '/resources/technical-support-warranty-request/',
#        '/resources/end-of-life-disposal/',
#        'https://cree.widen.net/s/vgmnrxcl9s/cree-6-for-60-program-distributor-guidelines-2020',
#        '/resources/for-designers/',
#        '/document-library/?document_categories=spec-sheets',
#        '/applications/case-studies/',
#        '/resources/outdoor-layout-request/',
#        '/resources/indoor-layout-request/',
#        'https://cree.widen.net/s/vmhkmlshwj/cree-lighting-product-catalog',
#        '/resources/for-installers/',
#        '/document-library/?document_categories=installation-guides',
#        '/qr-code-enabled-field-serviceability/',
#        '/resources/for-consumers/', '/document-library/?keyword=dim',
#        '/products/intelligent-lighting/connected-max-smart-products/#set-up-support',
#        '/resources/warranties/', '/consumer-lighting-form/', '/insights/',
#        '/insights/',
#        'https://youtube.com/playlist?list=PLtNOdQhLNNaSVlttI2dymanpZsi5ce_Ic',
#        '/events/', '/company/about/', '/company/about/',
#        '/company/about/#why-cree-lighting', '/news/',
#        'https://go.creelighting.com/usa-made',
#        '/company/about/#sustainability', '/company/careers/',
#        'https://www2.adlt.com/about-us/', '/company/about/',
#        '/company/about/', '/company/about/#why-cree-lighting', '/news/',
#        'https://go.creelighting.com/usa-made',
#        '/company/about/#sustainability', '/company/careers/',
#        'https://www2.adlt.com/about-us/',
#        '/document-library/?document_categories=spec-sheets',
#        '/company/careers/', '/contact/', '/where-to-buy/',
#        'tel:800-236-6800', '/en/', '/fr/', '/', '/company/about/',
#        '/products/outdoor/wall-mount/osq-series-2/',
#        '/products/outdoor/street-and-roadway/guideway-series/',
#        '/news/cree-lighting-introduces-guideway-series-street-light-to-deliver-levels-of-performance-and-visual-comfort-previously-out-of-reach/',
#        '/products/indoor/high-bay-low-bay/kbl-series/',
#        '/products/indoor/dynamic-skylight/cadiant/',
#        '/products/intelligent-lighting/lutron-enabled-solutions/#athena',
#        '/applications/case-studies/beck-suppliers-inc/',
#        '/news/leading-petroleum-marketer-selects-cree-lighting/',
#        '/products/outdoor/area/osq-series/',
#        '/news/new-cree-lighting-area-and-flood-portfolio-delivers-unmatched-performance-control-and-comfort/',
#        '/insights/article/let-there-be-light-the-right-kind-of-light/',
#        '/products/indoor/troffers/flex-series/',
#        '/products/indoor/troffers/zr-series/',
#        '/products/indoor/exit-and-emergency/',
#        '/products/indoor/troffers/cr-series/',
#        '/products/outdoor/street-and-roadway/rul-series/',
#        '/products/outdoor/parking-structure/ig-series/',
#        '/news/cree-lighting-honored-with-2022-leds-magazine-brightstar-award/',
#        '/company/about/', '/products/outdoor/wall-mount/osq-series-2/',
#        '/products/outdoor/street-and-roadway/guideway-series/',
#        '/news/cree-lighting-introduces-guideway-series-street-light-to-deliver-levels-of-performance-and-visual-comfort-previously-out-of-reach/',
#        '/products/indoor/high-bay-low-bay/kbl-series/',
#        '/products/indoor/dynamic-skylight/cadiant/',
#        '/products/intelligent-lighting/lutron-enabled-solutions/#athena',
#        '/applications/case-studies/beck-suppliers-inc/',
#        '/news/leading-petroleum-marketer-selects-cree-lighting/',
#        '/products/outdoor/area/osq-series/',
#        '/news/new-cree-lighting-area-and-flood-portfolio-delivers-unmatched-performance-control-and-comfort/',
#        '/insights/article/let-there-be-light-the-right-kind-of-light/',
#        '/products/indoor/troffers/flex-series/',
#        '/products/indoor/troffers/zr-series/',
#        '/products/indoor/exit-and-emergency/',
#        '/products/indoor/troffers/cr-series/',
#        '/products/outdoor/street-and-roadway/rul-series/',
#        '/products/outdoor/parking-structure/ig-series/',
#        '/news/cree-lighting-honored-with-2022-leds-magazine-brightstar-award/',
#        '/company/about/', '/applications/cities-and-towns/',
#        '/applications/gas-stations-c-stores/',
#        '/applications/warehouse-and-industrial/',
#        '/applications/schools-and-universities/', '/company/about/',
#        '/insights/article/let-there-be-light-the-right-kind-of-light/',
#        '/insights/article/the-color-of-money-profitable-lighting-for-the-outdoor-auto-showroom/',
#        '/insights/article/dlc-luna-energy-savings-meets-reduced-light-pollution/',
#        '/insights/', '/document-library/?document_categories=spec-sheets',
#        '/resources/outdoor-layout-request/',
#        '/resources/led-lighting-incentives/',
#        'https://cree.widen.net/s/sbccg5gz8k/dlc-ssl-qualified-products-list',
#        '/resources/faq/', '/company/about/#why-cree-lighting',
#        '/products/intelligent-lighting/connected-max-smart-products/',
#        '/products/intelligent-lighting/', '/resources/general-form/',
#        'tel:8002366800',
#        '/products/intelligent-lighting/connected-max-smart-products/#where-to-buy',
#        '/privacy-policy', '/products/', '/products/indoor/',
#        '/products/outdoor/', '/products/intelligent-lighting/',
#        '/products/residential/', '/brands/c-lite/', '/applications/',
#        '/applications/gas-stations-c-stores/',
#        '/applications/cities-and-towns/',
#        '/applications/utility-lighting/', '/applications/transportation/',
#        '/applications/warehouse-and-industrial/',
#        '/applications/commercial/',
#        '/applications/schools-and-universities/', '/applications/retail/',
#        '/applications/auto-dealerships/', '/applications/healthcare/',
#        '/applications/case-studies/', '/lighting-contact-form/',
#        '/resources/general-form/',
#        '/resources/sales-terms-and-conditions/', '/resources/warranties/',
#        '/resources/technical-support-warranty-request/',
#        '/consumer-lighting-form/', '/resources/warranties/',
#        '/resources/technical-support-warranty-request/',
#        '/contractor-info/', '/contractor-info/', '/supplier-resources/',
#        '/supplier-resources/supplier-information-form/',
#        '/supplier-resources/global-supplier-manual/', '/company/about/',
#        '/resources/general-form/', '/company/about/', '/company/careers/',
#        '/news/', '/company/legal/', '/company/about/licensing/',
#        'https://files.creelighting.com/documents/Slavery-and-Human-Trafficking-Statement-for-2022.pdf',
#        '/privacy-policy/', '/sitemap/sitemap-index.xml'], dtype=object)

# %%
filtro = np.array(['www.hilton.com' in href if href is not None else False for href in href_array])

# Solo links relacionados con la pagina
href_filtrados = href_array[filtro]

# %%
len(href_filtrados)
# Out:
# 42

# %%
href_filtrados
# Out:
# array(['https://www.hilton.com/en/',
#        'https://www.hilton.com/en/locations/?cid=OH,WW,LocationsNav,MULTIPR,Header,Home,Brand',
#        'https://www.hilton.com/en/offers/?cid=OH,WW,OffersNav,MULTIPR,Header,Home,Brand',
#        'https://www.hilton.com/en/events/?cid=OH,WW,MeetingsEventsNav,MULTIPR,Header,Home,Brand',
#        'https://www.hilton.com/en/hilton-honors/credit-cards/?cid=OH,WW,CobrandNav,MULTIPR,Header,Home,Brand',
#        'https://www.hilton.com/en/hilton-honors/join/',
#        'https://www.hilton.com/en/locations/?cid=OH,WW,DreamingLocations,MULTIPR,imageHeadliner,Home,Brand',
#        'https://www.hilton.com/en/hotels/pdxbeqq-the-benson-portland/?cid=OH,MB,EntHPCarouselTagFriendsPDXBEQQ,MultiBR,Carousel,Home,SingleLink,i82345',
#        'https://www.hilton.com/en/p/winter-travel/?cid=OH,WW,FriendsStayDec,MULTIPR,brandscarousel,Home,Brand',
#        'https://www.hilton.com/en/beach/?cid=OH,WW,Beach,MULTIPR,gridthreesixnine2,Home,Brand',
#        'https://www.hilton.com/en/p/pools/?cid=OH,WW,Pools,MULTIPR,gridthreesixnine2,Home,Brand',
#        'https://www.hilton.com/en/locations/boutique/?cid=OH,WW,Boutique,MULTIPR,gridthreesixnine2,Home,Brand',
#        'https://www.hilton.com/en/new-hotels/?cid=OH,WW,NewHotels,MULTIPR,gridthreesixnine2,Home,Brand',
#        'https://www.hilton.com/en/p/hilton-honors-mobile-app?cid=OH,WW,AppDownload,MULTIPR,tabs,Home,Brand',
#        'https://www.hilton.com/en/brands/waldorf-astoria/',
#        'https://www.hilton.com/en/brands/lxr-hotels/',
#        'https://www.hilton.com/en/brands/conrad-hotels/',
#        'https://www.hilton.com/en/brands/canopy-by-hilton/',
#        'https://www.hilton.com/en/brands/signia-by-hilton/',
#        'https://www.hilton.com/en/brands/hilton-hotels/',
#        'https://www.hilton.com/en/brands/curio-collection/',
#        'https://www.hilton.com/en/brands/doubletree-by-hilton/',
#        'https://www.hilton.com/en/brands/tapestry-collection/',
#        'https://www.hilton.com/en/brands/embassy-suites/',
#        'https://www.hilton.com/en/brands/tempo-by-hilton/',
#        'https://www.hilton.com/en/brands/motto-by-hilton/',
#        'https://www.hilton.com/en/brands/hilton-garden-inn/',
#        'https://www.hilton.com/en/brands/hampton-by-hilton/',
#        'https://www.hilton.com/en/brands/tru-by-hilton/',
#        'https://www.hilton.com/en/brands/spark-by-hilton/',
#        'https://www.hilton.com/en/brands/homewood-suites/',
#        'https://www.hilton.com/en/brands/home2-suites/',
#        'https://www.hilton.com/en/corporate/development/',
#        'https://www.hilton.com/en/p/sitemap/',
#        'https://www.hilton.com/en/p/global-privacy-statement/',
#        'https://www.hilton.com/en/travel/?cid=OH,MB,THFooter,MULTIPR,Tile,AboutUs,SingleLink,i81797',
#        'https://www.hilton.com/en/brands/?cid=OH,MB,OurBrandsFooter,MULTIPR,Aux,Home,SingleLink,i84866',
#        'https://www.hilton.com/en/p/accessibility/',
#        'https://www.hilton.com/en/hilton-honors/terms/',
#        'https://www.hilton.com/en/hilton-honors/personal-data-requests/',
#        'https://www.hilton.com/en/hilton-honors/personal-data-requests/',
#        'https://www.hilton.com/en/p/site-usage-agreement/'], dtype=object)

# %%
# Ejemplo: Extraer todos los enlaces de los menus de la pagina
links = html.find_all('li')

# Imprimir los enlaces encontrados
for link in links:
    if link.get('class') == ['menu-item']:
        item = link.find_all('a')
        item_links = [a['href'] for a in item]
        print(item_links[0])

# %%
def obtain_menu_link(html):
    # Ejemplo: Extraer todos los enlaces de los menus de la pagina
    links = html.find_all('li')
    print(links)
    # Imprimir los enlaces encontrados
    for link in links:
        if link.get('class') == ['menu-item']: # nos quedamos con los de tipo menu
            item = link.find_all('a')
            item_links = [a['href'] for a in item]
    return item_links[0]

# %% [markdown]
# ## INSIGHTS:
# - Bit difficult to implement, because there are too many references inside a web
# - We could pick a few random links to get new information. This could also introduce some bias into the summarizer.
# - Each html has it way of implementing the menu option of the header of the web. Not always does it with the menu item tag, sometimes is done with JS, which makes it more difficult to filter the search of important links

# %%
def get_html_text(html):
    for script in html(["script", "style"]):
        script.extract() 
        
    text = html.get_text()
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)
    return text

# %% [markdown]
# Another way of extracting the text from the html

# %%
get_html_text(html)
# Out:
# "Columbus Metropolitan Library\nSkip to content\nFAQs\nLocations\nContact Us\nMy Account\nFAQs\nLocations\nContact Us\nMy Account\nBooks & eContent\nExplore\nBookseContent\nFind your next great read or binge-worthy show.\nWe have it all – books, eBooks, streaming movies, music, TV shows and more.\nEvents\nWhat’s Happening\nPrograms & EventsVirtual Events (Crowdcast)Sesquicentennial Author Series (special-events)Battelle Author SeriesCulture Pass\nSesquicentennial Author Series\nOur series brings engaging national authors to you, free and open to all.Choose the Sesquicentennial Author Series (special-events) link under What’s Happening to see the lineup.\nKids & Teens\nKids, Teens & Teachers\nReady for KindergartenSchool HelpTeensTeacher ResourcesDial-A-Story\nSchool Help\nK-12 Students: Get free after-school help with your schoolwork in our School Help Centers.Choose the School Help link under\xa0Kids, Teens & Teachers.\nLEARN MORE\nAdults\nPrograms & Resources\nJob & Career HelpAdult EducationSocial ServicesVoter ResourcesLibrary ServicesBusiness & Nonprofit Resource Center\nWe’re here to help you succeed in your job search.\nGet free, live coaching for help with resumes, interview practice, career coaching and job searching.\nLEARN MORE\nResearch\nResearch\nResearch ToolsFrequently Used WebsitesAll Resources by SubjectAll Resources A-Z\nFind the Tools you NeedExplore our digital resources to help you learn something new or deep dive into a topic of interest.\nHistory & Genealogy\nExplore Your History\nLocal History & GenealogyMy History\nLocal History & Genealogy\nVisit Main Library in person or Reserve an Expert online for one-on-one help with your research and genealogy questions.Choose the Local History & Genealogy link under Explore Your History for more information.\nLEARN MORE\nNews\nNews & Updates\nPress RoomCOVID-19 UpdatesDiversity, Equity & InclusionNew BuildingsOne Book - One CommunitySpeak Up / Speak OutAddiction and Mental Health Resources\nWe’ll keep you up-to-date on library news.\nStop back often to see what’s happening at your library.\nLEARN MORE\nI'm looking for\nSearch Term\nSearch:\nWebsite\nCatalog\nEvents\nResearch Tools\nArticles\nColumbus Children’s Theatre Visits Main Library\nSunday, Dec. 3 | 2-3 p.m.Main Library | 96 S. Grant Ave.\nThis family-friendly adaptation of A Christmas Carol features Tiny Tim, Bob Cratchit, Jacob Marley and other colorful characters who help Ebenezer Scrooge learn the true meaning of Christmas. Free and open to all.\nClick below to see how our community partners are helping us celebrate our 150th birthday all year long.\nCelebrate With Us!\nStaff Picks Live: Best of 2023\nTuesday, Dec. 5 | 7 p.m.\nTune in to watch Staff Picks Live!\nOur staff will share their favorite titles from 2023. Join us and share your recommendations too!\nRegister Here\nSee Author Jason Mott\nSunday, Dec. 10 | 2 p.m.Main Library | 96 S. Grant Ave.\nOur Sesquicentennial Author Series concludes with Jason Mott, who will discuss his career and his latest novel, Hell of a Book, which earned the 2021 National Book Award. Register for your free ticket below.\nThe Sesquicentennial Author Series is sponsored by NBC4.\nRegister Here\nJoin us for our sesquicentennial celebration!\nLearn More\nDon’t forget to track your reading by July 31!\nYou must track in the Beanstack app or on the website to earn prizes and raffle entries.\nSign in or ask staff for help.\nSign Up / Sign In\nTHANK YOU FOR CELEBRATING WITH US\nWatch Here\nJoin Us\nSESQUICENTENNIALAUTHOR SERIES\nAuthor Talks at Main Library\nget details\nCome see the\nNow through Jan. 7, 2024\nlearn more\nJoin us for oursesquicentennialcelebration!\nLearn More\nJoin Us\nat Main Library Wednesday, Nov. 29\nlearn more\nDigital Content At Your Fingertips.\nGet online access to movies, music, eBooks, audiobooks and more, free with your library card.\nLEARN MORE\nApply for your library card today to unlock a world of knowledge.\nYour library card gives you acce ...

# %%
def get_html_text2(html):
    h = html2text.HTML2Text()
    h.ignore_links = True # False para los links
    texto = h.handle(html.prettify())
    solo_letras = re.sub(r'[^a-zA-Z\s]', '', texto)
    texto_sin_links = re.sub(r'\b(.*image.*|.*png.*|.*http.*)\b', '', solo_letras)
    return texto_sin_links

# %% [markdown]
# Best way of extracting text (also the refs could be extracted). It returns a better format than the other options

# %%
urls_extractor = data.sample(n=15, random_state=1).reset_index(drop=True)

# %%
urls_extractor.head()
# Out:
#                                        Company_NAME  SIC1  \
# 0                     IDEAL INDUSTRIES LIGHTING LLC  3641
# 1  GOODWILL INDUSTRIES OF ORANGE COUNTY, CALIFORNIA  5932
# 2                      KKR GROUP FINANCE CO. VI LLC  6282
# 3                      WINK TO WEBSTER PIPELINE LLC  1623
# 4  AUTOMATIC DATA PROCESSING INSURANCE AGENCY, INC.  7374
#
#                              URL  \
# 0           www.creelighting.com
# 1             www.ocgoodwill.org
# 2                    www.kkr.com
# 3  www.winktowebsterpipeline.com
# 4              insurance.adp.com
#
#                                                  WEB  \
# 0  Search Spec Sheets & Design Files\nLight the W...
# 1                                                NaN
# 2  As of September 30, 2023\nExplore our shared s...
# 3                                                NaN
# 4  Talk to Sales 1-855-237-5335 Start Quote\nFind...
#
#                                         wikipedia_v1  \
# 0                                                NaN
# 1  Goodwill Industries International Inc., often ...
# 2                                                NaN
# 3  Delek US Holdings, Inc. is a diversified downs...
# 4  UNIVAC (Universal Automatic Computer) was a li...
#
#                                         wikipedia_v2  wikipedia_v3 WEB_2
# 0  Philippe Starck (French pronunciation: [filip ...           NaN   NaN
# 1  Goodwill Industries International Inc., often ...           NaN   NaN
# 2  Blackstone Inc. is an American alternative inv...           NaN   NaN
# 3  Delek US Holdings, Inc. is a diversified downs...           NaN   NaN
# 4  Big data primarily refers to data sets that ar...           NaN   NaN

# %%
url_base = 'https://'
html_text = np.empty(15, dtype=object)
for i, url in urls_extractor.iterrows():
    print(url['Company_NAME'])
    url_complete = url_base + url['URL']
    html = html_request(url_complete)
    if str(html).lower().find('error!:') != -1:
        print(html)
    else:
        html_text[i] = get_html_text2(html)
# Out:
# IDEAL INDUSTRIES LIGHTING LLC
# 200
# GOODWILL INDUSTRIES OF ORANGE COUNTY, CALIFORNIA
# Request_error!: 403 Client Error: Forbidden for url: https://www.ocgoodwill.org/
# KKR GROUP FINANCE CO. VI LLC
# 200
# WINK TO WEBSTER PIPELINE LLC
# Request_error!: 403 Client Error: Forbidden for url: https://winktowebsterpipeline.com/
# AUTOMATIC DATA PROCESSING INSURANCE AGENCY, INC.
# 200
# OIL STATES INDUSTRIES US, INC.
# 200
# AMERICAN RETIREMENT ASSOCIATION
# 200
# BECTON DICKINSON LUXEMBOURG III LLC
# 200
# CARLYLE ASIA REAL ESTATE II GP, L.P.
# 200
# ROC NATION ADVERTISING LLC
# 200
# RAH SACO-CH, LLC
# 200
# NEXEO PLASTICS, LLC
# 200
# ALLIED GROUP, LLC
# 200
# INDY ASBURY CHEV LLC
# 200
# MONGODB, INC.
# 200

# %%
html_text[5]
# Out:
# '\n\nNYSE  OIS    scriptsNASDAQarrowdownRedgif \n\n   Contact Us \n    \n      \n  \n  \n  \n\n   About \n     Company Overview \n     Management Team \n     Board of Directors \n     Operations Map \n   Operations \n     OffshoreManufactured Products \n     Well Site Services \n     Downhole Technologies \n     Location Listings \n   Investors \n     Stock Information \n     SEC Filings \n     News Releases \n     Events  Presentations \n     Annual Reports  Presentations \n     Proxy Materials \n     Reconciliation of NonGAAP Financial Measures \n     Analyst Coverage \n     Investor FAQ \n     Contact Us \n   News \n     Press Releases \n   Corporate Governance \n     Management Team \n     Board of Directors \n     Committee Composition \n     Sustainability \n     FAQ \n   Careers \n     Training and Development \n     Benefits \n     Company Culture and Workforce Diversity \n     Equal Opportunity Employer \n     Career Opportunities \n     Operations Map \n\\n\n  Oil States International Inc  \nprovides innovative solutions  \nto the worldwide energy industry\n\nAbout   Operations   Sustainability   \n  \nSpotlight on New Technology Awards for FTLP Floating Wind Platform and\nActive Seat Gate Valve\n\n    \n\nOil States Announces Third Quarter  Results\n\n    \n\nOil States Announces Rescheduled Third Quarter  Earnings Conference Call\n\n    \n\nOil States Announces Third Quarter  Earnings Conference Call\n\n  \nMore News \n\nfilelibImageGalleryInternationalupdateoperations\nupdateoffshoreproductsjpg\n\n  OffshoreManufactured Products\n\nDesigns manufactures and sells capital equipment utilized on floating\nproduction systems subsea pipelines offshore drilling rigs and vessels and\nfor industrial applications along with shortercycle products used in land\napplications\n\nLearn More \n\nfilelibImageGalleryInternationalupdateoperations\nupdatewellsiteservicesjpg\n\n  Well Site Services\n\nProvides service equipment and personnel primarily for completion and\nproduction operations throughout the active regions of the United States Gulf\nof Mexico and internationally along with land drilling services in the US\nRocky Mountain region\n\nLearn More \n\nfilelibImageGalleryInternationalupdateIMGxjpg\n\n  Downhole Technologies\n\nResearcher developer and manufacturer of highly engineered consumable\nproducts used in completion applications\n\nLearn More \n\n\n\nSite Map    Terms  Conditions    Patents\n\n  Oil States International Inc All rights reserved\n\n   \n   \n\n'

# %% [markdown]
# Final example of the text that we obtain

# %% [markdown]
# # IMPLEMENTING THE SUMMARIZER WITH CHATGPT API

# %%
data.head()
# Out:
#                           Company_NAME  SIC1            URL  \
# 0                BRINK'S UKRAINE, INC.  7381  us.brinks.com
# 1                    AES CALGARY, INC.  4911    www.aes.com
# 2              AURORA AES HOLDINGS INC  4911    www.aes.com
# 3  AES CENTRAL AMERICAN HOLDINGS, INC.  4911    www.aes.com
# 4             AES CARBON HOLDINGS, LLC  4911    www.aes.com
#
#                                                  WEB  \
# 0  see my product options\nThe way in which you h...
# 1  e n e r g y\nAccelerating the future of\nenerg...
# 2  e n e r g y\nAccelerating the future of\nenerg...
# 3  e n e r g y\nAccelerating the future of\nenerg...
# 4  e n e r g y\nAccelerating the future of\nenerg...
#
#                                         wikipedia_v1  \
# 0                                                NaN
# 1  TransAlta Corporation (formerly Calgary Power ...
# 2  This is a list of companies in the United Stat...
# 3  Union Pacific Corporation is a publicly traded...
# 4  The Abu Dhabi National Oil Company (Arabic: شر...
#
#                                         wikipedia_v2  wikipedia_v3  \
# 0  Joseph Robinette Biden Jr. (  BY-dən; born Nov...           NaN
# 1  TransAlta Corporation (formerly Calgary Power ...           NaN
# 2  This is a list of companies in the United Stat...           NaN
# 3  Union Pacific Corporation is a publicly traded...           NaN
# 4  The Abu Dhabi National Oil Company (Arabic: شر...           NaN
#
#                                                WEB_2
# 0  #  Navigation\n\n  * Skip to Content \n\n##  A...
# 1  Skip to main content\n\n[ ![Home](/themes/cust...
# 2  Skip to main content\n\n[ ![Home](/themes/cust...
# 3  Skip to main content\n\n[ ![Home](/themes/cust...
# 4  Skip to main content\n\n[ ![Home](/themes/cust...

# %%
def api_chatgpt(text: str, company_name: str):
    api_key = "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"
    client = OpenAI(api_key=api_key)

    message_content = f'''me haces un resumen de este html de la empresa {company_name}, 
                    en un maximo de 3 lineas que resuma a que se dedica dicha empresa por favor.
                      Respira profundamente y trabajo en este problema paso a paso:''' + text
    # Enviar solicitud de completación de chat
    response = client.chat.completions.create(
        model="gpt-3.5-turbo-0301",
        messages=[{"role": "user", "content": message_content}],
        stream=False,
    )

    choices = response.choices
    if choices:
        first_choice = choices[0]
        message = first_choice.message
        content = message.content
        return content
    else:
        return None

# %%
data_notnull = data.dropna(subset=['WEB'])

# %%
data_notnull = data_notnull[['Company_NAME', 'URL']]
data_notnull['Description'] = np.nan

# %%
data_15 = data_notnull[['Company_NAME', 'URL']]

# Seleccionar 15 filas aleatorias
filas_aleatorias = np.random.choice(data_15.index, 15, replace=False)
data_15 = data_15.loc[filas_aleatorias]
data_15['Description'] = np.nan

# %%
url_base = 'https://'
for i, fila in data_notnull.iterrows():
    if i > 72:
        print(fila['Company_NAME'])
        print(i)
        url = url_base + fila['URL']
        html = html_request(url)
        text = get_html_text2(html)
        if len(text) >= 4096:
            text = text[:4096]
        description = api_chatgpt(text, fila['Company_NAME'])
        data_notnull.at[i, 'Description'] = description
    
        # Esperar 1 minuto
        time.sleep(30)  # 60 segundos = 1 minuto
# Out:
# BECTON DICKINSON LUXEMBOURG III LLC
# 73
# 200
# BW/IP NEW MEXICO, INC.
# 74
# 200
# BET DOCUMENTARIES, LLC
# 75
# 200
# BET LIVE FROM LA, LLC
# 76
# 200
# BET OH DRAMA , LLC
# 77
# 200
# ASSURANT NEW VENTURES, INCORPORATED
# 78
# 200
# AMSCAN NM LAND, LLC
# 81
# 200
# BET ST LLC
# 84
# 200
# ARBOUR ELDER SERVICES, INC.
# 85
# 200
# GREEN MOUNTAIN ENERGY SUN CLUB
# 86
# 200
# CABOT US INVESTMENTS LLC
# 87
# 200
# BIOGEN HOLDING I LLC
# 88
# 200
# BEECH OVENS LLC
# 90
# 200
# LIVE VENTURES INCORPORATED
# 91
# 200
# BELDEN CDT INTERNATIONAL INC.
# 92
# 200
# BLACK & DECKER INVESTMENTS (AUSTRALIA) LIMITED
# 97
# 200
# BLACK & DECKER DE PANAMA LLC
# 98
# 200
# ASSURANT SOLUTIONS HOLDING PUERTO RICO, INC.
# 99
# 200
# CARESPOT OF ORLANDO/HSI URGENT CARE, LLC
# 100
# 200
# BIOGEN THERAPEUTICS INC.
# 101
# 200
# BIOGEN SRO INC.
# 102
# 200
# BIOMET MANUFACTURING, LLC
# 103
# 200
# BIOMET INTERNATIONAL ORTHOPEDICS, LLC
# 104
# 200
# AUTOMATIC DATA PROCESSING INSURANCE AGENCY, INC.
# 106
# 200
# ARCOLA SECURITIES, INC.
# 107
# 200
# BOSTITCH-HOLDING, L.L.C.
# 108
# 200
# CARLYLE CAVALIER GP, L.L.C.
# 110
# 200
# GREEN PLAINS SHENANDOAH LLC FKA GPRE SHENANDOAH, LLC
# 111
# 200
# BRINK'S ADMINISTRATIVE SERVICES INC.
# 115
# 200
# BRINK'S GLOBAL SERVICES KL, INC.
# 116
# 200
# BRINK'S EXPRESS COMPANY
# 117
# 200
# GREENBRIER-GIMSA, LLC
# 119
# 200
# ENSIGN OPERATING LLC
# 120
# 200
# MONGODB, INC.
# 122
# 200
# EMETER CORPORATION
# 124
# 200
# THE PRODUCTION BOARD LLC
# 125
# 200
# TECOVAS, INC.
# 126
# 200
# OIL STATES INDUSTRIES US, INC.
# 127
# 200
# KINDER MORGAN RESOURCES II LLC
# 128
# 200
# ZERO HASH LLC
# 129
# 200
# PINECREST ACADEMY OF NORTHERN NEVADA
# 130
# 200
# TURN/RIVER MANAGEMENT LLC
# 131
# 200
# LABCORP EARLY DEVELOPMENT LABORATORIES INC.
# 132
# 200
# FTD, LLC
# 133
# 200
# CEX.IO CORP
# 135
# 200
# OWENS CORNING INTELLECTUAL CAPITAL, LLC
# 137
# 200
# ONEOK UNIT HOLDINGS, INC.
# 141
# 200
# GULFSIDE HEALTHCARE SERVICES, INC.
# 143
# 200
# BEEP, INC.
# 144
# 200
# XPERIENCE RESTAURANT GROUP
# 145
# 200
# COURIER PRINTING CO. INC.
# 146
# 200
# NEXEO PLASTICS, LLC
# 147
# 200
# CREDIT SUISSE SERVICES (USA) LLC
# 148
# 200
# ALTO NEUROSCIENCE, INC.
# 149
# 200
# BERRY FILM PRODUCTS ACQUISITION COMPANY, INC.
# 151
# 200
# NATIONS CONSTRUCTION, LLC
# 153
# 200
# THOMASVILLE REGIONAL MEDICAL CENTER, LLC
# 154
# 200
# AFLAC CORPORATE VENTURES LLC
# 155
# 200
# BUTTERFLY EQUITY LP
# 156
# 200
# ARCHIPELAGO ANALYTICS HOLDINGS INC
# 157
# 200
# RAPIDDEPLOY, INC.
# 158
# 200
# ALTA ENTERPRISES, LLC
# 159
# 200
# DESKTOP METAL, INC.
# 161
# 200
# CONTIXO INC.
# 163
# 200
# ILLINGWORTH RESEARCH GROUP (USA) INC
# 165
# 200
# DIGITALOCEAN HOLDINGS, INC.
# 166
# 200
# KANSAS WESLEYAN UNIVERSITY
# 167
# 200
# WORKDAY GLOBAL, INC
# 168
# 200
# PINGCAP (US), INC.
# 175
# 200
# MOMENTUS INC.
# 178
# 200
# KENTUCKY HOSPITAL INTERMEDIATE, LLC
# 181
# 200
# TMA INTERSTATE CORPORATION
# 184
# 200
# KKR GROUP FINANCE CO. VI LLC
# 185
# 200
# ALECTOR, INC.
# 186
# 200
# REPUBLIC SERVICES OF OHIO TRANSPORTATION, LLC
# 187
# 200
# VANGUARD AUTO GROUP, LLC
# 188
# 200
# IDEAL INDUSTRIES LIGHTING LLC
# 189
# 200
# COLUMBUS METROPOLITAN LIBRARY
# 190
# 200
# CREST ROCK PARTNERS GP LLC
# 191
# 200
# HAWTHORNE FOOD COMPANY
# 192
# 200
# OAK LEAF SURGICAL HOSPITAL LLC
# 193
# 200
# INDUS HOLDINGS, INC
# 194
# 200
# THE WENGER GROUP INC
# 195
# 200
# TREW, LLC
# 196
# 200
# BAIN INDONESIA EAST, LLC
# 197
# 200
# OCEANSOUND PARTNERS, LP
# 198
# 200
# SAVION, LLC
# 199
# 200
# SONALASENSE INC
# 201
# 200
# SAINT LUKE'S PHYSICIAN GROUP, INC.
# 204
# 200
# BEST CHEVROLET, INC.
# 205
# 200
# KADIANT CAS, LLC
# 207
# 200
# JUNE HOMES US, INC.
# 208
# 200
# ALLIANZ LIFE INSURANCE COMPANY OF MISSOURI
# 210
# 200
# PATRICK TRANSPORTATION, LLC
# 212
# 200
# CALIX, INC.
# 214
# 200
# INFOBIP LLC
# 216
# 200
# BIOGEN (RTP) REALTY LLC
# 217
# 200
# UHS OF RIDGE, LLC
# 218
# 200
# SURGCENTER CLEARWATER, LLC
# 219
# 200
# ITW HOLDINGS INC.
# 220
# 200
# OXY LOW CARBON VENTURES, LLC
# 222
# 200
# ASHFORD TRS NEW YORK LLC
# 224
# 200
# CHILEWICH SULTAN LLC
# 225
# 200
# PRUDENT AMERICAN TECHNOLOGIES, INC.
# 229
# 200
# MANANALU, LLC
# 230
# 200
# EMORY HEALTHCARE, INC.
# 233
# 200
# SMARTSHIFT GROUP, INC.
# 234
# 200
# BERKSHIRE HATHAWAY HOME SERVIES
# 236
# 200
# REVESCO PROPERTY SERVICES, LLC
# 237
# 200
# HILTON GRAND VACATIONS TRUST 2019-A
# 238
# 200
# MATTSON HELLICKSON DENTAL LLC
# 239
# 200
# ENERGIX US, LLC
# 241
# 200
# ROC NATION ADVERTISING LLC
# 242
# 200
# BNB LAMESA SOLAR LLC
# 243
# 200
# NASDAQ ISE, LLC
# 245
# 200
# ATERIAN, INC.
# 247
# 200
# HOUSBY HEAVY EQUIPMENT, LLC
# 248
# 200
# NOVAMED SURGERY CENTER OF NASHUA, LLC
# 249
# 200
# LINDE ENGINEERING US LLC
# 251
# 200
# MORGAN STANLEY PRINCIPAL FUNDING, INC.
# 253
# 200
# NEXEO PLASTICS, LLC
# 255
# 200
# SARENS NORTH AMERICA HOLDING, INC.
# 256
# 200
# BAYSTATE MEDICAL CENTER, INC.
# 257
# 200
# BASF AGRICULTURAL SOLUTIONS SEED US LLC
# 258
# 200
# REVITALIZE EARTH
# 259
# 200
# TDX INTERNATIONAL, LLC
# 260
# 200
# GENUINE CABLE GROUP, LLC
# 263
# 200
# RAH SACO-CH, LLC
# 266
# 200
# AIG CLAIMS, INC.
# 267
# 200
# CELONA INC
# 270
# 200
# BELANGER, INC.
# 271
# 200
# SAUER BRANDS, INC.
# 272
# 200
# AMERITAS LIFE INSURANCE CORP.
# 273
# 200
# FIRST TRUST ALPHADEX EXCHANGE-TRADED FUNDS
# 274
# 200
# CARLYLE ASIA REAL ESTATE II GP, L.P.
# 275
# 200
# TUMULT LABS, INC.
# 276
# 200
# BOTTLEROCK MARKETING GROUP, LLC
# 277
# 200
# RADICLE LABS, INC.
# 278
# 200
# THE PFIZER INCUBATOR LLC
# 279
# 200
# KINDER MORGAN BALTIMORE TRANSLOAD TERMINAL LLC
# 283
# 200
# LUXURY HOTELS INTERNATIONAL OF PUERTO RICO, INC.
# 284
# 200
# LOGISTICS PROPERTY COMPANY, LLC
# 285
# 200
# METRO FLOOD PROJECT DIVERSION AUTHORITY
# 286
# 200
# VICTORIA CAPITAL PARTNERS, L.P.
# 287
# 200
# CAMBRIDGE TRUST COMPANY
# 288
# 200
# FINHABITS INC.
# 291
# 200
# THE WALT DISNEY COMPANY
# 293
# 200
# KADIANT, LLC
# 298
# 200
# ALLIED GROUP, LLC
# 299
# 200

# %%
csv_file = "/home/unai/datasets/All_Description_Unai.csv"
data_notnull.to_csv(csv_file, index=False, sep=",")

# %%
data_notnull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 210 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_NAME  210 non-null    object
#  1   URL           210 non-null    object
#  2   Description   210 non-null    object
# dtypes: object(3)
# memory usage: 14.7+ KB
