# %%
import requests
from bs4 import BeautifulSoup # para analizar el HTML
import pandas as pd
import numpy as np

# %% [markdown]
# ### OBTAIN THE METADATA OF THE PAGE
# The metadata is a simple description of the page.

# %%
def html_request(url: str):
    try:
        # Realizar la solicitud HTTP
        response = requests.get(url)
        response.raise_for_status()  # Lanzar una excepción para errores HTTP 

        # Verificar si la solicitud fue exitosa (código de estado 200)
        print(response.status_code)
        if response.status_code == 200:
            # Parsear el contenido HTML de la página
            soup = BeautifulSoup(response.text, 'html.parser')
            return soup
        else:
            print(f'Error al realizar la solicitud. Código de estado: {response.status_code}')
            return f'ERROR: {response.status_code}'
    
    except requests.exceptions.RequestException as e:
        # Capturar excepción de solicitud y devolver un mensaje de error
        return f'Request_error: {e}'

    except Exception as e:
        # Capturar cualquier otra excepción y devolver un mensaje de error
        return f'Unexpected_error: {e}'

# %%
def obtain_metadata(html):
    if html is None or not isinstance(html, BeautifulSoup):
        return html
    
    meta_tags = html.find_all('meta')  

    # Inicializar un diccionario para almacenar la metadata
    metadata = {}

    # Iterar sobre las etiquetas meta y extraer información relevante
    for tag in meta_tags:
        nombre = tag.get('name', '').lower()
        propiedad = tag.get('property', '').lower()
        contenido = tag.get('content', '')

        if nombre or propiedad:
            # Almacenar la información en el diccionario de metadata
            metadata[nombre or propiedad] = contenido

    return metadata

# %%
csv_file = '/home/unai/datasets/POC Description of operations - Sheet3.csv'
# Leer el archivo CSV y crear un DataFrame
data = pd.read_csv(csv_file)

# %%
data.head()
# Out:
#                           Company_NAME  SIC1            URL
# 0                BRINK'S UKRAINE, INC.  7381  us.brinks.com
# 1                    AES CALGARY, INC.  4911    www.aes.com
# 2              AURORA AES HOLDINGS INC  4911    www.aes.com
# 3  AES CENTRAL AMERICAN HOLDINGS, INC.  4911    www.aes.com
# 4             AES CARBON HOLDINGS, LLC  4911    www.aes.com

# %%
url = 'https://'
url = url + 'www.carlyle.com'
html = html_request(url)
type(html)

# %%
metadata = obtain_metadata(html)
# Imprimir la metadata obtenida
for clave, valor in metadata.items():
    print(f'{clave}: {valor}')
# Out:
# description: With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# abstract: With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# robots: index, follow
# google-site-verification: 2Y2hej7s3nXX9HyOiRt8ZoZ5bImc4N2_iigmai9tSpY
# generator: Drupal 9 (https://www.drupal.org)
# mobileoptimized: width
# handheldfriendly: true
# viewport: width=device-width, initial-scale=1.0

# %% [markdown]
# Here in an example, we can see the info obtained inside the meta tag of the html. As we can see the description field, summarizes in a single line the objectives of the organization

# %%
urls = data['URL'].sample(n=10, random_state=1)

# %%
all_urls = data['URL']

# %%
url_descriptions_all = {}
url_descriptions_all = pd.DataFrame({'URL': all_urls})
url_base = 'http://'
for url in all_urls:
    print(url)
    url_completa = url_base + url
    html = html_request(url_completa)
    metadata = obtain_metadata(html)
    if type(metadata) != str:
        print(metadata.get('description'))
        url_descriptions_all.loc[url_descriptions_all['URL'] == url, 'metadata'] = metadata.get('description')
    else:
        url_descriptions_all.loc[url_descriptions_all['URL'] == url, 'metadata'] = metadata
# Out:
# us.brinks.com
# 200
# When you choose Brink’s, you’ll help your business save time and money while optimizing your operations, protecting your funds, managing your cash.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.haydonkerkpittman.com
# www.ametek.com
# www.ametek.com
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.hilton.com
# 200
# Explore Hilton's portfolio of hotels and distinct brands across the globe. Book directly for the best rates during your next stay. Expect better, expect Hilton.
# jobs.uhsinc.com
# 200
# UHS Careers
# www.aptar.com
# 200
# Aptar is a global leader in drug and consumer product dosing, dispensing and protection technologies. Learn more about our innovative solutions.
# www.avaya.com
# 200
#  Build great experiences for your brand with Avaya's suite of cloud-based solutions designed to suit the specific needs of your team.
# www.avaya.com
# 200
#  Build great experiences for your brand with Avaya's suite of cloud-based solutions designed to suit the specific needs of your team.
# www.15w61.com
# www.aes.com
# 200
# AES is a global energy company that creates greener, smarter and innovative energy solutions. Together, we can accelerate the future of energy.
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.aetnabetterhealth.com
# 200
# Aetna Better Health offers Medicaid plans in many states across the country. Learn more about what Medicaid health plans are available to you.
# www.rentgulphmillsvillage.com
# 200
# Looking for King of Prussia apartments for rent? Gulph Mills Village Apartments offers the location, floor plans, and amenities you desire. Contact us today!
# www.chrobinson.com
# 200
# Reliably meet all your global logistics and technology needs with C.H. Robinson. Supply chain management is optimized with our experience, data, and scale.
# www.chrobinson.com
# 200
# Reliably meet all your global logistics and technology needs with C.H. Robinson. Supply chain management is optimized with our experience, data, and scale.
# jobs.uhsinc.com
# 200
# UHS Careers
# www.atkore.com
# 200
# Atkore manufactures electrical conduit and fittings, cable and cable management systems, infrastructure, safety and security products.
# www.american-equity.com
# 200
# An American-owned and operated company, American Equity Investment Life Insurance Company® is a leader in the fixed index annuities marketplace.
# www.bshv-sc.com
# 200
# None
# products.bankerslife.com
# 200
# Bankers Life insurance agents/producers help 1.3 million policyholders to safeguard against unexpected health costs, generate guaranteed income, protect loved ones and promote an enduring legacy. Our knowledgeable team members sit down with you to understand your preferences and retirement goals.  You can rest assured that you’ll learn about insurance products and solutions that are appropriate for you and your family.
# aramark.gcs-web.com
# 200
# The Investor Relations website contains information about Aramark's business for stockholders, potential investors, and financial analysts.
# jobs.uhsinc.com
# 200
# UHS Careers
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.amg.com
# 200
# Affiliated Managers Group (AMG) is a global asset management company that partners with outstanding alpha-generating independent firms.
# www.aspentech.com
# 200
# Our software tackles the most complex process manufacturing challenges, creating value and improving profitability for our customers. The industries that drive our economies and touch our lives are optimized by aspenONE software every day. The world’s leading oil & gas, chemical, engineering & construction, pharmaceutical, food, beverage, and consumer packaged goods companies all rely on AspenTech to run their business.
# www.asbhawaii.com
# 200
# American Savings Bank Hawaii offers consumer and business banking services including checking, savings, CDs, mortgages, loans and lines, and online banking.
# www.asburycareers.com
# 200
# Asbury Automotive offers various career oppotunties across the country. Browse positions in sales, service, and corporate to help us become the most admired automotive retailer.
# www.asburyauto.com
# 200
# Browse vehicles, make a selection, purchase and finance your next vehicle, and schedule your next service. All completely online.
# www.chrysler.com
# 200
# Unleash luxury and versatility with Chrysler's minivans and the 300 sedan. Explore Pacifica, Pacifica Hybrid, dealerships, incentives & more at Chrysler.com.
# www.arescre.com
# 200
# None
# www.animalsinc.net
# www.bookingholdings.com
# www.aspencore.com
# www.aspentech.com
# 200
# Our software tackles the most complex process manufacturing challenges, creating value and improving profitability for our customers. The industries that drive our economies and touch our lives are optimized by aspenONE software every day. The world’s leading oil & gas, chemical, engineering & construction, pharmaceutical, food, beverage, and consumer packaged goods companies all rely on AspenTech to run their business.
# www.aikenregional.com
# 200
# Aiken Regional is a 273-bed acute care facility that provides emergency, oncology and internal medicine services.
# www.blueridgesurgicalcenter.com
# 200
# None
# www.asburyauto.com
# 200
# Browse vehicles, make a selection, purchase and finance your next vehicle, and schedule your next service. All completely online.
# www.amkor.com
# www.amnhealthcare.com
# 200
# AMN Healthcare offers innovative staffing and total talent solutions. People are at the heart of everything you do as we empower the future of care.
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# www.sertasimmonsbedding.com
# 200
# Serta Simmons Bedding, LLC is the world’s leading producer of mattresses and sleep experiences. We have been defining and refining the world of sleep since 1870 and every day we continue to give people the sleep they need to live the lives they want.
# www.atmosenergy.com
# 200
# None
# www.beazer.com
# 200
# One of the nation’s largest homebuilders, Beazer Homes builds homes that set the industry standard for energy efficiency and personalization.
# www.chevrolet.com
# 200
# Official Chevrolet site: see Chevy cars, trucks, crossovers & SUVs - see photos/videos, find vehicles, compare competitors, build your own Chevy & more.
# www.honda.com
# www.aflac.com
# 200
# Aflac provides supplemental insurance to help pay out-of-pocket expenses your major medical insurance doesn't cover. Get started with a quote today!
# www.aflac.com
# 200
# Aflac provides supplemental insurance to help pay out-of-pocket expenses your major medical insurance doesn't cover. Get started with a quote today!
# www.capitalonecareers.com
# 200
# You’re tenacious and driven, so the last place you want to work is some boring bank. Same. Learn about careers at Capital One and view jobs here.
# www.brighthousefinancial.com
# www.brighthousefinancial.com
# www.onebarnes.com
# 200
# Barnes is a global provider of highly engineered products, differentiated industrial technologies, and innovative solutions, serving a wide range of end markets and customers.
# www.davita.com
# 200
#
# www.assemblyroomstudios.la
# www.hrblock.com
# 200
# Get the online tax preparation services you need with the tax refund you want. Whether you efile or work with an H&R Block tax pro, our services are guaranteed.
# www.hbfuller.com
# 200
# H.B. Fuller, experts in industrial adhesives, industrial coatings, industrial sealants and specialty materials in two dozen markets. Learn more.
# cabotog.gcs-web.com
# 200
# The Investor Relations website contains information about Cabot Corporation's business for stockholders, potential investors, and financial analysts.
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# www.beazer.com
# 200
# One of the nation’s largest homebuilders, Beazer Homes builds homes that set the industry standard for energy efficiency and personalization.
# www.bdbiosciences.com
# 200
# BD Biosciences provides flow cytometers, reagents, tools, and a wide range of services to support the work of researchers and clinicians who understand disease and improve care.
# www.buffalowildwings.com
# 200
# Enjoy all Buffalo Wild Wings to you has to offer when you order delivery or pick it up yourself or stop by a location near you. Buffalo Wild Wings to you is the ultimate place to get together with your friends, watch sports, drink beer, and eat wings.
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# www.assurant.com
# 200
# We help our global clients protect and support the major purchases consumers make — like homes, cars, appliances, and phones — in new and thoughtful ways.
# www.brookdale.com
# www.brookdale.com
# www.amscan.com
# 200
# None
# www.aftonchemical.com
# www.agstatesagency.com
# 200
# None
# www.bet.com
# 200
# BET.com is your home for all the latest celebrity, music, fashion, entertainment and African-American news. Check out your favorite BET shows and watch video!
# uhs.jibeapply.com
# 200
# UHS Careers
# www.greenmountainenergy.com
# 200
# Green Mountain Energy is a 100% renewable energy company providing clean electricity to consumers & businesses in TX, IL, PA, NY, MA, NJ, MD, & OR. Join our mission.
# www.moorscabot.com
# 200
# Wealth management founded on a relationship.
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# www.calumet.com
# www.middleby.com
# 200
# Middleby is a world leader in manufacturing innovative cooking equipment for the commercial, residential, and industrial foodservice markets.
# www.liveventures.com
# 200
# Live Ventures
# www.belden.com
# 200
# We design, manufacture and market networking, connectivity, cable products and solutions for industrial automation, smart buildings and broadcast markets.
# aloft-hotels.marriott.com
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.stanleyblackanddecker.com
# 200
# Headquartered in the USA, Stanley Black & Decker is the world’s largest tool company with 50 manufacturing American facilities and more than 100 worldwide.
# www.stanleyblackanddecker.com
# 200
# Headquartered in the USA, Stanley Black & Decker is the world’s largest tool company with 50 manufacturing American facilities and more than 100 worldwide.
# www.assurant.com
# 200
# We help our global clients protect and support the major purchases consumers make — like homes, cars, appliances, and phones — in new and thoughtful ways.
# www.carespot.com
# 200
# None
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# www.zimmerbiomet.com
# 200
# As a global medical technology leader, Zimmer Biomet pushes the boundaries of implant innovation to redefine what's possible across all stages of the patient journey.
# www.zimmerbiomet.com
# 200
# As a global medical technology leader, Zimmer Biomet pushes the boundaries of implant innovation to redefine what's possible across all stages of the patient journey.
# www.outback.com
# insurance.adp.com
# 200
# ADPIA (Automatic Data Processing Insurance Agency) is here to offer simple business insurance options for your company.
# www.arcolasecurities.com
# 200
# Arcola Securities
# www.stanleyblackanddecker.com
# 200
# Headquartered in the USA, Stanley Black & Decker is the world’s largest tool company with 50 manufacturing American facilities and more than 100 worldwide.
# www.outback.com
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.gpreinc.com
# 200
# We are a leading agri-tech company committed to transforming our platform to process annually renewable crops into more sustainable, high-value ingredients.
# www.carrabbas.com
# www.carrabbas.com
# www.guess.com
# us.brinks.com
# 200
# When you choose Brink’s, you’ll help your business save time and money while optimizing your operations, protecting your funds, managing your cash.
# us.brinks.com
# 200
# When you choose Brink’s, you’ll help your business save time and money while optimizing your operations, protecting your funds, managing your cash.
# us.brinks.com
# 200
# When you choose Brink’s, you’ll help your business save time and money while optimizing your operations, protecting your funds, managing your cash.
# www.blackhillscorp.com
# www.gbrx.com
# 200
# The Greenbrier Companies can trace its roots to a 1919 steel fabricator company in Portland, OR. Since then, we’ve evolved to become a global leader in transportation manufacturing and freight services.
# www.ensignnr.com
# 200
# Ensign Natural Resources is a private equity backed exploration and production company focused on acquiring, developing, and producing US unconventional resources.
# www.hhzf23.com
# www.mongodb.com
# 200
# Get your ideas to market faster with a developer data platform built on the leading modern database. MongoDB makes working with data easy.
# www.ocgoodwill.org
# new.siemens.com
# 200
# Visit Siemens, the technology company focused on industry, infrastructure, transport, and healthcare.
# www.tpb.co
# 200
# Founded by Dave Friedberg, The Production Board (TPB) is a holding company of businesses established to solve the most fundamental problems that affect our planet, by reimagining systems of production in agriculture, food, biomanufacturing, human health and life sciences. TPB builds new businesses from scratch based on emerging scientific discoveries, partners with exceptional talent, and provides them with the capital, infrastructure and market insights needed to deliver a 10x improvement in the cost, energy, time, or carbon footprint of conventional systems.
# www.tecovas.com
# 200
# Tecovas offers beautiful, handmade western boots & accessories sold directly to you at honest prices. Free shipping, returns, & exchanges.
# www.oilstatesintl.com
# 200
#
# www.kindermorgan.com
# 200
# We're one of North America's largest energy infrastructure companies. Our pipelines transport natural gas, carbon dioxide (CO2) and more. Contact us today.
# www.zerohash.com
# 200
# None
# www.pinecrestnnv.org
# 200
# Our mission is to provide an innovative, challenging curriculum in a loving environment that furthers a philosophy of respect and high expectations for all students, parents, teachers, and staff.
# www.turnriver.com
# 200
# None
# drugdevelopment.labcorp.com
# 200
# Labcorp's global research, development and testing organization provides drug and medical device development services. We serve pharmaceutical and biotechnology companies.
# www.ftdi.com
# 200
# For more than 100 years, FTD has stood for quality, creativity and worldwide floral delivery. Our network of florists continues to be the lifeblood of FTD. We continue to support our floral network through our innovative spirit and commitment to raising the awareness of giving flowers. New products and technology solutions are designed to help you increase revenue and drive local business to your shop.
# www.masterdesignguide.com
# 200
# Phoenix Contact - the innovative market leader of industrial connection technology, automation technology, electronic Interface systems and surge protection
# www.cex.io
# 200
# The leading cryptocurrency exchange platform offers different trading options, provides 24/7 customer support, high level of security, and stable deposits and withdrawals. Buy &amp; sell crypto &amp; bitcoin online with CEX.IO
# www.nmhealthcarevalue.org
# jobs.owenscorning.com
# 200
# Apply online for jobs at Owens Corning Career Site
# www.porsche.com
# 200
# Welcome to the official Porsche Website with detailed information about Porsche Models, Pre-owned Cars, Porsche Motorsport, the company, etc.
# www.dsmiami.com
# www.spectrumvisionpartners.com
# www.oneok.com
# www.rubyseas.com
# 200
# Seafood Company with decades of experience in international seafood markets. We specialize in fish and seafood commodity items such as tilapia, swai, grouper, shrimp, scallops, crab and lobster from our Bahama processing plant.
# www.gulfside.org
# 200
# GHS is a non-profit organization offering hospice, skilled home health care, and palliative care for serious, chronic and late stage illnesses.
# www.ridebeep.com
# 200
# Beep is an Autonomous Mobility as a Service provider servicing public transit operators, communities, campuses and airports.
# www.xperiencerg.com
# 200
# Xperience Restaurant Group is a leading full-service casual dining operator! Check out all of the brands that we operate!
# www.rrd.com
# 200
# RRD offers the most trusted portfolio of marketing, packaging, print, and supply chain solutions. We transform customer touchpoints into moments of impact.
# www.nexeoplastics.com
# 200
# Nexeo Plastics distributes plastic and polymer resins from top suppliers for automotive parts, medical applications, packaging, 3D printing, and more.
# www.credit-suisse.com
# 200
# Credit Suisse Group is a leading financial services company, advising clients in all aspects of finance, across the globe and around the clock.
# www.altoneuroscience.com
# 200
# Precision medicine for the brain is here. We are pioneering an approach to psychiatric drug development which matches the right patient with the right Alto drug based on AI-derived brain biomarkers.
# www.dresserutility.com
# www.berryglobal.com
# 200
# Berry Global, leaders in plastic packaging manufacturing, process & sustainable product innovation & design. Learn more about our capabilities
# www.bold.com
# www.nationsconstruction.com
# 200
# Are you in need of a reliable construction company in Houston, TX? Nations Construction is the company for you. Contact us today!
# www.trmc-al.com
# 200
# None
# www.aflac.com
# 200
# Aflac provides supplemental insurance to help pay out-of-pocket expenses your major medical insurance doesn't cover. Get started with a quote today!
# www.bfly.com
# 200
# Butterfly Equity is a Los Angeles-based private equity firm specializing in the food sector from seed to fork across the following key verticals: agriculture & aquaculture, food & beverage products, food distribution and foodservice. Our team has significant experience across food, private equity and technology and has been involved in investing more than $10 billion of equity capital in companies ranging from growth-stage to Fortune 500 enterprises.
# www.onarchipelago.com
# 200
# Archipelago helps you overcome challenges you experience in working with traditional spreadsheet property schedules.
# www.rapiddeploy.com
# 200
# Every moment matters in the mission to save lives. RapidDeploy is the leading cloud-native platform for Public Safety. We provide Next Generation solutions that deliver intelligent information and drive better outcomes in mission critical situations.
# www.altg.com
# 200
# Alta is your source for new and used material handling and construction equipment for sale with 57 locations in Florida, Illinois, Michigan, New England, New York, Northern Indiana, and Ohio.
# www.core4ce.com
# www.desktopmetal.com
# 200
# Desktop Metal™ exists to make metal 3D printing and carbon fiber 3D printing accessible to all engineers, designers, and manufacturers.
# www.enochianbio.com
# www.contixo.com
# 200
# Help your child grow and prepare for the next stage of their life. Invest in their future with Contixo education al products such as kids tablets, STEM products, and more. Explore our products today!
# www.missionhealth.org
# www.illingworthresearch.com
# 200
# Passion for research, compassion for patients. Clincal research services designed to make clincal research easier for the patient.
# www.digitalocean.com
# 200
# Simple, scalable cloud hosting solutions built for small and mid-sized businesses.
# www.kwu.edu
# 200
# Discover The Power of AND at Kansas Wesleyan University!
# www.workday.com
# 200
# Workday Enterprise Management Cloud gives organizations of all sizes the power to adapt through finance, HR, planning, spend management, and analytics applications. Move beyond ERP and deliver extraordinary results in a changing world. Learn more.
# www.aveciapharma.com
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.welltower.com
# 200
# None
# www.pingcap.com
# 200
# TiDB is an advanced, open-source, distributed SQL database for modern apps. MySQL compatible, TiDB powers companies like Block, Catalyst, and Capcom.
# www.usaretirement.org
# 200
# American Retirement Association (ARA) is a nonprofit organization comprised of five associations, dedicated to the nation’s private retirement system.
# www.tsys.com
# www.momentus.space
# 200
# None
# www.vikingpest.com
# secure.libertycable.com
# 200
# None
# www.kindredhospitals.com
# 200
# At Kindred, our mission is to help our patients reach their highest potential for health and healing with intensive medical and rehabilitative care through a compassionate patient experience.
# www.intervenn.com
# www.havenparkcommunities.com
# www.tmacompanies.com
# 200
# TMA
# www.kkr.com
# 200
# KKR is a leading global investment firm offering solutions in alternative assets spanning real estate, private credit, private equity, and infrastructure, as well as liquid credit, capital markets and insurance.
# www.alector.com
# 200
# Alector is a biopharmaceutical company that develops therapies for the treatment of neurodegeneration diseases.
# www.republicservices.jobs
# 200
# Be part of a team and make a difference with Republic Services. Join us now and help us leave the planet better than we found it.
# www.vanguardkia.com
# 200
# Get a new or used Kia from Vanguard Kia of Arlington. Browse our online inventory, schedule service, or order parts today!
# www.creelighting.com
# 200
# Cree Lighting is an LED lighting pioneer with deep roots and even deeper expertise. Shop our solutions today from LED outdoor lights to recessed lighting!
# www.columbuslibrary.org
# 200
# Columbus Metropolitan Library offers helpful services and resources to the Columbus, Ohio community. Browse our library, find information, and access our tools today!
# www.crestrockpartners.com
# 200
# Crest Rock Partners is an operationally focused investment firm dedicated
# to making control-oriented investments in the lower middle market. We
# invest in Software, Technology, Business Services and Industrial companies
# where we can bring substantial value to the companies and management teams
# we partner with.
# www.esprovisions.com
# 200
# Eastern Standard Provisions delivers expertly crafted, one-of-a-kind artisanal soft pretzels, Liège Belgian waffles, sourdough hard pretzel pieces, artfully blended sauces, and gourmet flavored salts and sugars. Because when it comes to snacking, you should love every bite.
# www.oakleafsurgical.com
# 200
# None
# www.indusholdingsinc.com
# 200
#
# www.thewengergroup.com
# 200
# We're a comprehensive Agricultural Company that includes Wenger Feeds, Dutchland Farms, Nutrify, Risser Grain, and Hoober Feeds.
# www.trewautomation.com
# 200
# Find TREW smart material handling automation | Warehouse Execution (WES), Warehouse Control (WCS), Robotics, Order Fulfillment and Conveyor Systems.
# www.bain.com
# 200
# Bain & Company is a top management consulting firm. We advise leaders on strategy, marketing, organization, operations, IT and M&A, across all industries and geographies.
# www.oceansoundpartners.com
# 200
# None
# www.savionenergy.com
# 200
# Savion delivers utility-scale solar and energy storage project development. Advancing photovoltaic energy to decarbonize the grid and deploy modern power.
# www.ferro.com
# www.sonalasense.com
# 200
# SonALAsense is the first company to advance Sonodynamic Therapy into clinical trials.
# www.coinmetrics.io
# www.arystalifescience.com
# www.saintlukeskc.org
# 200
# Saint Luke’s Health System consists of 16 area hospitals and campuses and several primary and specialty care practices, and provides a range of inpatient, outpatient, and home care services.
# www.bestchevrolet.com
# 200
# Welcome to Best Chevrolet in Kenner, LA! Supplying the New Orleans, Metairie & Baton Rouge area with quality new Chevys & used cars for sale. Visit us today!
# wordpress-352188-1092167.cloudwaysapps.com
# www.kadiant.com
# 200
# Kadiant provides world-class Applied Behavior Analysis (ABA) therapy for children. In-home, center, school, and community-based services.
# www.junehomes.com
# 200
# June Homes is a network of fully furnished bedrooms in prime spots available on flexible month-to-month terms in major American cities.
# www.minneapolisfoundation.org
# www.allianzlife.com
# 200
# Allianz Life offers annuities, life insurance, and Buffered ETFs that can help you manage risks to your retirement security.
# www.residentialhealthcaregroup.com
# www.patrickind.com
# 200
# For more than half a century, Patrick and its network of trusted, independent brands have worked to improve the quality of everyday life through better component products and building materials for our partners. Better living starts here.
# www.winktowebsterpipeline.com
# www.calix.com
# 200
# At Calix, we live to empower Communication Service providers of all sizes to simplify their business, excite their subscribers and grow their value.
# www.coalitioninc.com
# 200
# Coalition combines comprehensive cyber insurance coverage and security services to help businesses prevent digital risk before it strikes.
# www.infobip.com
# 200
# Engage your customers and prospects with simple drag and drop email, SMS, chatbot or build custom solutions with the best in class APIs
# www.biogen.com
# 200
# Biogen is a leading global biotechnology company that pioneers science and drives innovations for complex and devastating diseases. Biogen is advancing a pipeline of potential therapies across neurology, neuropsychiatry, specialized immunology and rare disease and remains acutely focused on its purpose of serving humanity through science while advancing a healthier, more sustainable and equitable world.
# jobs.uhsinc.com
# 200
# UHS Careers
# www.scdunedin.com
# 200
# None
# www.itw.com
# 200
# Find out why our decentralized business model, customer-back innovation and support of our colleagues and community give us the competitive advantage.
# www.mosaic.co
# 200
# Mosaic Group
# www.oxy.com
# 200
# We are a best-in-class, low-cost operator with assets in the United States, Middle East, Africa and Latin America, applying technology to drive operational excellence and leveraging our global leadership in carbon management to advance our business.
# www.1635marketst.com
# www.hilton.com
# 200
# Explore Hilton's portfolio of hotels and distinct brands across the globe. Book directly for the best rates during your next stay. Expect better, expect Hilton.
# www.chilewich.com
# 200
# We make beautiful, durable and easy to clean placemats, indoor-outdoor mats, rugs, woven floor mats and runners. Free shipping on orders $200+. Shop the full collection.
# www.hibercell.com
# www.commsell.com
# www.springworkstx.com
# www.prudentamerican.com
# 200
# None
# www.mananalu.com
# 200
# Jason Momoa, founder of Mananalu, is creating a WAVE OF CHANGE to unplastic the planet by eliminating single-use plastic bottles.
# www.ocpna.com
# www.sciphermedicine.com
# www.emoryhealthcare.org
# 200
# Emory is your one-stop shop for all of your health care needs, both in sickness and in health.
# www.smartshift.com
# 200
# smartShift is the most advanced SAP transformation tool powered by intelligent automation AI, built by real SAP experts. Move to S/4HANA fast without disrupting business operations while reducing long timelines and operational risks.
# www.precisionbiosciences.com
# www.bhhsvdw.com
# 200
# Find homes for sale. Meet network agents who can help you buy or sell with confidence. Search for luxury properties, investment properties and other real estate.
# www.revescoproperties.com
# 200
#
# www.hiltongrandvacations.com
# 200
# At Hilton Grand Vacations, we believe life is incomplete without vacations. Learn how you can see the world from the comfort of our timeshare resorts
#
# www.mh.dental
# 200
#
# www.flexwheels.com
# www.energixrenewables.com
# 200
# Energix Renewables. A breakthrough green utility, committed to our future on the planet
# www.rocnation.com
# 200
# Roc Nation is a full-service entertainment company, inclusive of artist and athlete management, label, publishing, touring, film / TV and new ventures.
# www.bnbrenewables.com
# 200
# BNB Renewable Energy Holdings is a leading developer of wind, solar, and
# biogas power plants, focused primarily on helping utilities and Fortune 500
# companies in North and Latin America green their energy mix. BNB has
# originated in excess of 200MW of generation currently in operation, with
# another 200MW-plus under construction and a development pipeline of
# 1,200MW, including projects in Ohio, New Jersey, Connecticut, Pennsylvania,
# North Carolina, Florida, Utah, Illinois, Texas, and Mexico.
# www.welltower.com
# 200
# None
# ir.nasdaq.com
# 200
# The Investor Relations website contains information about Nasdaq, Inc.'s business for stockholders, potential investors, and financial analysts.
# www.yktal.com
# www.aterian.io
# 200
# At Aterian, we transform the way companies approach online sales. We empower brands of all sizes with technology and services that increase sales, automate marketing strategies, and provide continuous critical business intelligence.
# www.housby.com
# 200
# Housby is the home of Online Truck Sales, Mack Trucks, Used Trucks, Volvo Construction Equipment, Isuzu, Truck Service, Truck Parts and Mixers in Des Moines, IA
# www.novamedsurgeryofnashua.com
# 200
# None
# www.currentbyge.com
# 200
# None
# www.leamericas.com
# 200
# Linde is a global leader in the production, processing, storage and distribution of hydrogen.
# www.nspencer.k12.in.us
# www.morganstanley.com
# 200
# Discover how we help individuals, families, institutions and governments raise, manage and distribute the capital they need to achieve their goals.
# www.locomation.ai
# www.nexeoplastics.com
# 200
# Nexeo Plastics distributes plastic and polymer resins from top suppliers for automotive parts, medical applications, packaging, 3D printing, and more.
# www.sarens.com
# 200
# Sarens is the recognized worldwide leader and reference in heavy lifting and engineered transport.
# www.baystatehealth.org
# 200
# Baystate Health is a not-for-profit health system in western Massachusetts providing both specialized and primary care 200+ medical practices and 5 hospitals.
# www.basf.com
# 200
# None
# www.revitalize.earth
# 200
# Revitalize Earth is on a mission to raise the frequency of the planet through global wellness centers, cutting-edge agriculture, plant based medicines and indigenous job creation. The donations we receive here will help expedite this process and make a larger impact on those around us.
# www.tdxcorp.com
# 200
# None
# www.selectmedical.com
# www.selectmedical.com
# www.gogcg.com
# 200
# Making Connections Possible At GCG We Make Connections Possible through a nationwide network of facilities providing the wire, cable, automation and associated products and services that ensure connections, among families and friends, co-workers and customers, and the industrial equipment used across the country. Serving a wide variety of industries our experienced teams are Service-Oriented, Responsive […]
# www.kikcorp.com
# www.bluewhitelegalcapital.com
# 200
# None
# www.jackchevrolet.com
# 200
# Jack Chevrolet. The highest-rated Chevrolet dealership in Maine. We include a 15-year/ 150,000-mile warranty on all new and most pre-owned vehicles.
# www.aig.com
# 200
# American International Group, Inc, (AIG), is a global insurance organization providing a range of insurance and other financial services. Get to know us better.
# www.umoja-biopharma.com
# www.bkmedical.com
# www.celona.io
# 200
# At Celona, weâre engineering the future of networks with blazing fast 5G LAN solutions for the enterprise
# www.opwglobal.com
# 200
# OPW is the only manufacturer that can deliver the best quality loading arms, from pre-manufactured to custom designed for your specifications. Contact us today!
# www.sauers.com
# 200
# Shop Sauer Brands expansive line of mayonnaise, pourable salad dressings, condiments, sauces, spices, extracts and flavorings online!
# www.ameritas.com
# 200
# Competitive insurance and financial strategies do more than target your long-term financial goals. They give you freedom to enjoy today.
# www.ftportfolios.com
# 200
# None
# www.carlyle.com
# 200
# With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities.
# www.tmlt.io
# 200
# State-of-the-art privacy technology that delivers better data insights to every enterprise.
# www.latitude38ent.com
# 200
#
# www.radicleinsights.com
# 200
# Radicle's network of hypergrowth professionals helps you surface critical insights, identify actionable opportunities, and hire transformational talent.
# www.pfizer.com
# 200
# Discover the commonalities and differences between biologics vs. biosimilars — especially when it comes to cost.
# www.uhaul.com
# www.uhaul.com
# www.welltower.com
# 200
# None
# www.kindermorgan.com
# 200
# We're one of North America's largest energy infrastructure companies. Our pipelines transport natural gas, carbon dioxide (CO2) and more. Contact us today.
# www.ritzcarlton.com
# 200
# Reserve now & choose from our collection of luxury hotel and resorts as you plan your next travel experience. Join our members Club for exclusive benefits.
# www.logisticspropco.com
# 200
# LPC is a logistics real estate platform focused on the acquisition, development & management of logistics properties in key North American markets.
# www.fmdiversion.gov
# 200
# The Metro Flood Diversion Authority (MFDA) is responsible for delivering the timely construction of the Fargo-Moorhead Area Diversion.
# www.victoriacp.com
# 200
# Victoria Capital Partners is managed by one of the most experienced private equity teams in South America, the senior members of which have been working together for an average of 13 years, investing in more than 20 companies since 1995.
# www.cambridgetrust.com
# 200
# Cambridge Trust is dedicated to providing private banking, business banking, and wealth management services.
# www.skims.com
# 200
# None
# www.enesco.com
# www.finhabits.com
# 200
# Finhabits ofrece el servicio de inversiones en la bolsa de valores de los Estados Unidos. Es la app financiera #1 en la comunidad latina de USA.
# www.rex-lumber.com
# www.thewaltdisneycompany.com
# 200
# The mission of The Walt Disney Company is to be one of the world's leading producers and providers of entertainment and information.
# www.epicmid.com
# www.arizonacollisioncenter.com
# www.hayesvalleyinn.com
# www.sea-electric.com
# www.kadiant.com
# 200
# Kadiant provides world-class Applied Behavior Analysis (ABA) therapy for children. In-home, center, school, and community-based services.
# www.thealliedgrp.com
# 200
# The Allied Group is New England's leading provider of fulfillment services. Allied Group offers printing, kitting, mailing and fulfillment services all under one roof. Allied Printing is the only ISO certified supplier in Rhode Island.

# %%
url_descriptions_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   URL       300 non-null    object
#  1   metadata  267 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB

# %% [markdown]
# As we can see 30 organizations hadn't meta tag inside their html

# %%
metadata_csv = 'metadata_empresas.csv'

# Guardar el DataFrame en un archivo CSV
url_descriptions_all.to_csv(metadata_csv, index=False)

# %% [markdown]
# Now we want to see how many error have meen obtained during the request of the html because different reasons

# %%
errores_metadata = url_descriptions_all
errores_metadata['errores'] = url_descriptions_all['metadata'].apply(lambda x: str(x).lower().find('error'))

# %%
errores_metadata['errores'].value_counts(normalize=True)
# Out:
# errores
# -1    0.766667
#  8    0.233333
# Name: proportion, dtype: float64

# %% [markdown]
# # We obtain a correct summarize of the organization role with the meta tag in 76% of the cases.

# %% [markdown]
# ### OBTAIN ALL THE HTML OF THE WEB

# %%
# Ejemplo: Extraer todos los enlaces de la página
links = html.find_all('a')

# Imprimir los enlaces encontrados
for link in links:
    print(link.get('href'))

# %%
print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <link href="https://www.carlyle.com/themes/carlyle_2020/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://www.carlyle.com/themes/carlyle_2020/favicons/favicon.ico" rel="shortcut icon"/>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"abf569a42c",applicationID:"65780628"};;/*! For license information please see nr-loader-rum-1.248.0.min.js.LICENSE.txt */
# (()=>{var e,t,n={234:(e,t,n)=>{"use strict";n.d(t,{P_:()=>h,Mt:()=>m,C5:()=>s,DL:()=>w,OP:()=>j,lF:()=>R,Yu:()=>_,Dg:()=>v,CX:()=>c,GE:()=>A,sU:()=>T});var r=n(8632),i=n(9567);const a={beacon:r.ce.beacon,errorBeacon:r.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},o={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!o[e])throw new Error("Info for ".concat(e," was never set"));return o[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");o[e]=(0,i.D)(t,a);const n=(0,r.ek)(e);n&&(n.info=o[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=n(7056),l=n(50);const f=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,sampling_rate:50,error_sampling_rate:50,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector=t+",[data-nr-mask]":null===t?e.mask_selector=t:(0,l.Z)("An invalid session_replay.mask_selector was provided and will not be used",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},g={},p="All configuration objects require an agent identifier!";function h(e){if(!e)throw new Error(p);if(!g[e])throw new Error("Configuration for ".concat(e," was never set"));return g[e]}function v(e,t){if(!e)throw new Error(p);g[e]=(0,i.D)(t,f());const n=(0,r.ek)(e);n&&(n.init=g[e])}function m(e,t){if(!e)throw new Error(p);var n=h(e);if(n){for(var r=t.split("."),i=0;i<r.length-1;i++)if("object"!=typeof(n=n[r[i]]))return;n=n[r[r.length-1]]}return n}const b={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},y={};function w(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!y[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return y[e]}function A(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");y[e]=(0,i.D)(t,b);const n=(0,r.ek)(e);n&&(n.loader_config=y[e])}const _=(0,r.mF)().o;var x=n(385),D=n(6818);const k={buildEnv:D.Re,customTransaction:void 0,disabled:! ...
#   </script>
#   <meta content="With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities." name="description"/>
#   <meta content="With $382 billion of assets under management, Carlyle’s purpose is to invest wisely and create value on behalf of our investors, portfolio companies, and communities." name="abstract"/>
#   <link href="https://www.carlyle.com" rel="canonical"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="https://www.carlyle.com/" rel="shortlink"/>
#   <meta content="vI2GWdIwhbFrrCS3pX3Lf5r0iM0JJw51pedRWVlPuoI" name="google-site-verification"/>
#   <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.carlyle.com/" hreflang="en" rel="alternate"/>
#   <link href="https://www.carlyle.com/ja" hreflang="ja" rel="alternate"/>
#   <link href="https://www.carlyle.com/zh-hans" hreflang="zh-hans" rel="alternate"/>
#   <script defer="" src="/sites/default/files/google_tag/gtm/google_tag.script.js?s4euv4">
#   </script>
#   <script>
#    window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};
#   </script>
#   <title>
#    Carlyle | Global Investment Firm
#   </title>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/core.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/controlgroup.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/checkboxradio.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/resizable.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/button.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/dialog.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/ajax-progress.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/align.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/autocomplete-loading.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/fieldgroup.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/container-inline.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/clearfix.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/details.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/hidden.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/item-list.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/js.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/nowrap.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/position-container.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/progress.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/reset-appearance.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/resize.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/sticky-header.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/system-status-counter.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/system-status-report-counters.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/system-status-report-general-info.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/tabledrag.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/tablesort.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/system/components/tree-child.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/jquery_ui/assets/vendor/jquery.ui/themes/base/core.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/jquery_ui/assets/vendor/jquery.ui/themes/base/accordion.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/views/views.module.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/filter/filter.caption.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/media/filter.caption.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/eu_cookie_compliance/css/eu_cookie_compliance.bare.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/assets/vendor/jquery.ui/themes/base/theme.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/addtoany/css/addtoany.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/jquery_ui/assets/vendor/jquery.ui/themes/base/theme.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/extlink/extlink.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/better_exposed_filters/css/better_exposed_filters.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/modules/contrib/paragraphs/css/paragraphs.unpublished.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/core/assets/vendor/normalize-css/normalize.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/stable/css/core/normalize-fixes.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/action-links.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/breadcrumb.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/button.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/collapse-processed.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/container-inline.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/details.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/exposed-filters.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/field.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/form.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/icons.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/inline-form.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/item-list.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/link.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/links.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/menu.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/more-link.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/pager.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/tabledrag.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/tableselect.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/tablesort.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/tabs.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/textarea.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/ui-dialog.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/messages.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/progress.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/dialog.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/file.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/core/themes/classy/css/components/node.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/themes/carlyle_2020/dist/css/styles.css?s4euv4" media="all" rel="stylesheet"/>
#   <link href="/libraries/fullpage.js/dist/fullpage.min.css?s4euv4" media="all" rel="stylesheet"/>
#   <script src="/core/assets/vendor/modernizr/modernizr.min.js?v=3.11.7">
#   </script>
#   <script src="/core/misc/modernizr-additional-tests.js?v=3.11.7">
#   </script>
#   <meta content="2Y2hej7s3nXX9HyOiRt8ZoZ5bImc4N2_iigmai9tSpY" name="google-site-verification"/>
#  </head>
#  <body class="language-en path-frontpage page-node-type-section-page">
#   <a class="visually-hidden focusable skip-link" href="#main-content">
#    Skip to main content
#   </a>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TJZNN3L" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <div class="page--wrapper">
#     <header class="section section--header">
#      <div class="region region-header">
#       <div class="block-carlyle-2020-logo block block-system block-system-branding-block" id="block-carlyle-2020-logo">
#        <a class="site-logo" href="/" rel="home" title="Home">
#         <span>
#          Carlyle Group Logo/Homepage Link
#         </span>
#        </a>
#       </div>
#       <div class="language-switcher-language-url block-carlyle-2020-languageswitcher block block-language block-language-blocklanguage-interface block-language-block-language-interface" id="block-carlyle-2020-languageswitcher" role="navigation">
#        <ul class="links">
#         <li class="en is-active" data-drupal-link-system-path="node/32221" hreflang="en">
#          <a class="language-link is-active" data-drupal-link-system-path="node/32221" href="/carlyle-group" hreflang="en">
#           English
#          </a>
#         </li>
#         <li class="ja" data-drupal-link-system-path="node/32221" hreflang="ja">
#          <a class="language-link" data-drupal-link-system-path="node/32221" href="/ja/carlyle-group" hreflang="ja">
#           日本語
#          </a>
#         </li>
#         <li class="zh-hans" data-drupal-link-system-path="node/32221" hreflang="zh-hans">
#          <a class="language-link" data-drupal-link-system-path="node/32221" href="/zh-hans/carlyle-group" hreflang="zh-hans">
#           简体中文
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="views-exposed-form bef-exposed-form search-form block-carlyle-2020-search-form block block-views block-views-exposed-filter-blockacquia-search-page-1 block-views-exposed-filter-block-acquia-search-page-1" data-drupal-selector="views-exposed-form-acquia-search-page-1" id="block-carlyle-2020-search-form">
#        <form accept-charset="UTF-8" action="/search-results" id="views-exposed-form-acquia-search-page-1" method="get">
#         <div class="form--inline clearfix">
#          <div class="js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-search form-item-search">
#           <input aria-label="Search" class="form-text" data-drupal-selector="edit-search" id="edit-search" maxlength="128" name="search" placeholder="Search" size="30" type="text" value=""/>
#          </div>
#          <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions">
#           <button class="button js-form-submit form-submit" data-drupal-selector="edit-submit-acquia-search" id="edit-submit-acquia-search" type="submit" value="Search">
#            <span class="visually-hidden">
#             Search
#            </span>
#           </button>
#          </div>
#         </div>
#        </form>
#       </div>
#       <div class="language-search-buttons block-carlyle2020languagesearchbuttons block-type--basic block block-block-content block-block-contenteddbfee4-8a3a-4533-8877-ffe479da866e block-block-content-eddbfee4-8a3a-4533-8877-ffe479da866e" id="block-carlyle2020languagesearchbuttons">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <button class="language-trigger">
#          <span>
#           Language Switcher
#          </span>
#         </button>
#         <button class="search-trigger">
#          <span>
#           Search
#          </span>
#         </button>
#        </div>
#       </div>
#       <button aria-controls="block-carlyle-2020-menu" aria-expanded="false" class="menu-trigger">
#        <div class="visually-hidden">
#         Menu
#        </div>
#        <span>
#        </span>
#        <span>
#        </span>
#        <span>
#        </span>
#       </button>
#       <nav aria-labelledby="block-carlyle-2020-menu-menu" class="block-carlyle-2020-menu block block-menu navigation menu--carlyle-2020" id="block-carlyle-2020-menu" role="navigation">
#        <h2 class="visually-hidden" id="block-carlyle-2020-menu-menu">
#         Carlyle 2020
#        </h2>
#        <div class="block-carlyle-2020-menu-quote block-type--basic block block-block-content block-block-contentb4d7d3f5-5135-444e-9f3b-ed430f6e5bc7 block-block-content-b4d7d3f5-5135-444e-9f3b-ed430f6e5bc7" id="block-carlyle-2020-menu-quote">
#         <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#          <h2>
#           Value creation and impact are at the center of everything we do.
#          </h2>
#         </div>
#        </div>
#        <ul class="menu">
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/32196" href="/our-firm">
#           Our Firm
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/34386" href="/our-firm/global-private-equity">
#           Global Private Equity
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/32236" href="/our-firm/global-credit">
#           Global Credit
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/32226" href="/our-firm/global-investment-solutions">
#           Global Investment Solutions
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/32231" href="/global-insights">
#           Global Insights
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/33886" href="/esg">
#           ESG
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/35336" href="/diversity">
#           Diversity, Equity, and Inclusion
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/32201" href="/careers">
#           Careers
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/32206" href="/news-media">
#           News &amp; Media
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/32216" href="/contact-us">
#           Contact
#          </a>
#         </li>
#         <li class="menu-item">
#          <a href="https://lpconnect.carlyle.com/">
#           LP Login
#          </a>
#         </li>
#         <li class="menu-item">
#          <a href="http://ir.carlyle.com/">
#           Shareholders
#          </a>
#         </li>
#        </ul>
#        <div class="menu-cta block-menu-cta block-type--basic block block-block-content block-block-content63affc6d-9b6e-43e6-bef3-b20e4df87698 block-block-content-63affc6d-9b6e-43e6-bef3-b20e4df87698" id="block-menu-cta">
#         <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#          <p>
#           <a class="menu-cta" href="https://www.carlyle.com/investor-relations/annual-report-2022">
#            2022 Annual Report
#           </a>
#          </p>
#         </div>
#        </div>
#        <div class="block-footersocialitemslist-4 block-type--footer_social_menu block block-block-content block-block-content4df4afe7-a62c-4d86-b71c-7d3a442ad920 block-block-content-4df4afe7-a62c-4d86-b71c-7d3a442ad920" id="block-footersocialitemslist-4">
#         <div class="field field--name-field-footer-menu field--type-entity-reference-revisions field--label-hidden field__items">
#          <div class="field__item">
#           <a class="social-icon twitter" href="https://twitter.com/onecarlyle" style="background-image:url(/sites/default/files/2023-10/x_0.svg)" target="_blank">
#            <span>
#             twitter
#            </span>
#           </a>
#          </div>
#          <div class="field__item">
#           <a class="social-icon youtube" href="https://www.youtube.com/onecarlyle/" style="background-image:url(/sites/default/files/2023-10/bi_youtube%20%281%29.svg)" target="_blank">
#            <span>
#             youtube
#            </span>
#           </a>
#          </div>
#          <div class="field__item">
#           <a class="social-icon linkedin" href="https://linkedin.com/company/the-carlyle-group" style="background-image:url(/sites/default/files/2023-10/linkedin-blue%20%281%29.svg)" target="_blank">
#            <span>
#             linkedin
#            </span>
#           </a>
#          </div>
#          <div class="field__item">
#           <a class="social-icon instagram" href="https://www.instagram.com/onecarlyle/" style="background-image:url(/sites/default/files/2023-10/instagram-blue.svg)" target="_blank">
#            <span>
#             instagram
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </nav>
#      </div>
#     </header>
#     <div class="section section--content" id="main-content">
#      <div class="region region-content">
#       <div class="hidden" data-drupal-messages-fallback="">
#       </div>
#       <div class="block-mainpagecontent block block-system block-system-main-block" id="block-mainpagecontent">
#        <article about="/carlyle-group" class="node--title-the-carlyle-group node node--type-section-page node--promoted node--view-mode-full" data-history-node-id="32221" role="article">
#         <div class="node__content">
#          <nav aria-label="Section Navigation" class="section-nav" role="navigation">
#           <ul>
#            <li data-menuanchor="our-firm">
#             <a class="our-firm" href="#our-firm">
#              Our Firm
#             </a>
#             <hr/>
#            </li>
#            <li data-menuanchor="our-approach">
#             <a class="our-approach" href="#our-approach">
#              Our Approach
#             </a>
#             <hr/>
#            </li>
#            <li data-menuanchor="our-insights">
#             <a class="our-insights" href="#our-insights">
#              Our Insights
#             </a>
#             <hr/>
#            </li>
#            <li data-menuanchor="our-impact">
#             <a class="our-impact" href="#our-impact">
#              Our Impact
#             </a>
#             <hr/>
#            </li>
#            <li data-menuanchor="our-news">
#             <a class="our-news" href="#our-news">
#              Our News
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <div class="field field--name-field-sections field--type-bricks-revisioned field--label-hidden field__items" id="fullpage">
#           <div class="brick brick--type--section brick--id--111 brick-type--section section splash" data-anchor="splash">
#            <hr class="left"/>
#            <h2 class="section-title">
#             Splash
#            </h2>
#            <div class="field field--name-field-background-image field--type-entity-reference field--label-hidden field__item">
#             <article class="media media--type-video media--view-mode-default">
#              <div class="field field--name-field-media-video-file field--type-file field--label-visually_hidden">
#               <div class="field__label visually-hidden">
#                Video file
#               </div>
#               <div class="field__item">
#                <video autoplay="" data-autoplay="" loop="" muted="" playsinline="" preload="">
#                 <source src="/sites/default/files/2020-03/3D_Intro_Loop_V2.mp4" type="video/mp4"/>
#                 <p>
#                  Sorry, your browser doesn't support embedded videos
#                 </p>
#                </video>
#               </div>
#              </div>
#             </article>
#            </div>
#            <div class="clearfix text-formatted field field--name-field-content field--type-text-long field--label-hidden field__item">
#             <h2>
#              As a global investment firm we work together to create long-term value for our investors, companies, shareholders, people and communities.
#             </h2>
#             <p>
#              <a alt="Notices &amp; Disclaimers link" class="btn white" href="https://www.carlyle.com/notices-and-disclaimers" target="_blank" title="Notices &amp; Disclaimers">
#               Notices &amp; Disclaimers
#              </a>
#              <a alt="LP Login link" class="btn white" href="https://lpconnect.carlyle.com/" target="_blank" title="LP Login">
#               LP Login
#              </a>
#              <a alt="Annual Report 2022 link" class="btn white" href="https://www.carlyle.com/investor-relations/annual-report-2022" target="_blank" title="Annual Report 2022">
#               Annual Report 2022
#              </a>
#              <a alt="Impact Review 2022 link" class="btn white" href="/esg/esg-report-2023" target="_blank" title="2023 ESG Report">
#               2023 ESG Report
#              </a>
#              <a alt="Q1 2023 Financial Results link" class="btn white" href="https://ir.carlyle.com/static-files/aef1f37c-384a-43fb-8e7d-ab7f5b75322b" target="_blank" title="Q3 2023 Financial Results">
#               Q3 2023 Financial Results
#              </a>
#             </p>
#            </div>
#            <hr class="right"/>
#           </div>
#           <div class="brick brick--type--section brick--id--141 brick-type--section section our-firm" data-anchor="our-firm">
#            <hr class="left"/>
#            <h2 class="section-title">
#             Our Firm
#            </h2>
#            <div class="brick brick--type--slide brick--id--116 brick-type--slide foreground-white has-bg-image has-mobile-bg-image slide" data-color="white">
#             <div class="field field--name-field-heading field--type-string field--label-hidden field__item">
#              Who We Are
#             </div>
#             <div class="slide--content">
#              <div class="clearfix text-formatted field field--name-field-content field--type-text-long field--label-hidden field__item">
#               <h2>
#                With 28 offices across 4 continents and more than 2,200 professionals worldwide, we leverage our global network to deliver our best thinking and drive positive change.
#               </h2>
#              </div>
#              <div class="field field--name-field-background-image field--type-entity-reference field--label-hidden field__item">
#               <article class="media media--type-video media--view-mode-background">
#                <div class="field field--name-field-media-video-file field--type-file field--label-visually_hidden">
#                 <div class="field__label visually-hidden">
#                  Video file
#                 </div>
#                 <div class="field__item">
#                  <video autoplay="" data-autoplay="" loop="" muted="" playsinline="" preload="">
#                   <source src="/sites/default/files/2020-03/2_CG_Landing_OurFirm.mp4" type="video/mp4"/>
#                   <p>
#                    Sorry, your browser doesn't support embedded videos
#                   </p>
#                  </video>
#                 </div>
#                </div>
#               </article>
#              </div>
#              <div class="field field--name-field-mobile-background-image field--type-entity-reference field--label-hidden field__item">
#               <article class="media media--type-image media--view-mode-background">
#                <div class="field field--name-field-media-image field--type-image field--label-visually_hidden">
#                 <div class="field__label visually-hidden">
#                  Image
#                 </div>
#                 <div class="field__item">
#                  <picture>
#                   <source media="all and (min-width: 1041px)" srcset="/sites/default/files/styles/image_component_large_1x/public/2020-02/3_mobile.jpg?itok=ooOHJKZ8 1x, /sites/default/files/styles/image_component_large_1_5x/public/2020-02/3_mobile.jpg?itok=dmXoO9bS 1.5x, /sites/default/files/styles/image_component_large_2x/public/2020-02/3_mobile.jpg?itok=_TlTQErb 2x" type="image/jpeg"/>
#                   <source media="all and (min-width: 481px) and (max-width: 1040px)" srcset="/sites/default/files/styles/image_component_medium_1x/public/2020-02/3_mobile.jpg?itok=pcViY8kn 1x, /sites/default/files/styles/image_component_medium_1_5x/public/2020-02/3_mobile.jpg?itok=Lti9sopt 1.5x, /sites/default/files/styles/image_component_medium_2x/public/2020-02/3_mobile.jpg?itok=VUWvzxdi 2x" type="image/jpeg"/>
#                   <source media="all and (max-width: 480px)" srcset="/sites/default/files/styles/image_component_small_1x/public/2020-02/3_mobile.jpg?itok=MNnfmOS1 1x, /sites/default/files/styles/image_component_small_1_5x/public/2020-02/3_mobile.jpg?itok=ukQ_9TWS 1.5x, /sites/default/files/styles/image_component_small_2x/public/2020-02/3_mobile.jpg?itok=goziRc79 2x" type="image/jpeg"/>
#                   <img alt="Staircases in an office building" src="/sites/default/files/styles/image_component/public/2020-02/3_mobile.jpg?itok=VrP-bsCo" typeof="foaf:Image"/>
#                  </picture>
#                 </div>
#                </div>
#               </article>
#              </div>
#             </div>
#            </div>
#            <div class="brick brick--type--slide brick--id--121 brick-type--slide foreground-white background-medium_blue has-bg-image slide" data-bkg="medium_blue" data-color="white">
#             <div class="field field--name-field-heading field--type-string field--label-hidden field__item">
#              Our Business Segments
#             </div>
#             <div class="slide--content">
#              <div class="clearfix text-formatted field field--name-field-content field--type-text-long field--label-hidden field__item">
#               <h2>
#                We manage $382 billion in assets, spanning 3 business segments and 600 investment vehicles, investing wisely and responsibly over the long-term.
#               </h2>
#               <h6 class="arrow">
#                View our segments
#               </h6>
#               <div class="structured-link-list with-icons">
#                <a class="corporate-equity" href="/global-private-equity">
#                 Global Private Equity
#                 <span>
#                  Creating Global Opportunities Through Local Insight
#                 </span>
#                </a>
#                <a class="global-credit" href="/global-credit">
#                 Global Credit
#                </a>
#                <a class="investment-solutions" href="/investment-solutions">
#                 Global Investment Solutions
#                 <span>
#                  Creating Custom Opportunities
#                 </span>
#                </a>
#               </div>
#              </div>
#              <div class="field field--name-field-background-image field--type-entity-reference field--label-hidden field__item">
#               <article class="media media--type-video media--view-mode-background">
#                <div class="field field--name-field-media-video-file field--type-file field--label-visually_hidden">
#                 <div class="field__label visually-hidden">
#                  Video file
#                 </div>
#                 <div class="field__item">
#                  <video autoplay="" data-autoplay="" loop="" muted="" playsinline="" preload="">
#                   <source src="/sites/default/files/2020-03/3_CG_Landing_BusinessSegments.mp4" type="video/mp4"/>
#                   <p>
#                    Sorry, your browser doesn't support embedded videos
#                   </p>
#                  </video>
#                 </div>
#                </div>
#               </article>
#              </div>
#             </div>
#            </div>
#            <div class="brick brick--type--slide brick--id--126 brick-type--slide foreground-white background-medium_blue has-bg-image slide" data-bkg="medium_blue" data-color="white">
#             <div class="field field--name-field-heading field--type-string field--label-hidden field__item">
#              Our Offices
#             </div>
#             <div class="slide--content">
#              <div class="clearfix text-formatted field field--name-field-content field--type-text-long field--label-hidden field__item">
#               <h2 class="text-center">
#                Explore our global reach
#               </h2>
#               <h6 class="arrow text-center">
#                Browse offices by region
#               </h6>
#               <div class="map">
#                <div class="vertical-link-list">
#                 <a href="/contact-us-0">
#                  Asia-Pacific
#                 </a>
#                 <a href="/contact-us-0">
#                  Europe
#                 </a>
#                 <a href="/contact-us-0">
#                  North America
#                 </a>
#                 <a href="/contact-us-0">
#                  South America
#                 </a>
#                 <a href="/contact-us-0">
#                  UAE
#                 </a>
#                </div>
#                <div class="map-locations">
#                 <!-- NORTH AMERICA -->
#                 <div class="location location--washington">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Washington D.C., United States
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--los-angeles">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Los Angeles, United States
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--menlo">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Menlo Park, United States
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--nyc">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    New York City, United States
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--miami">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Miami, United States
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--sf">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    San Francisco, United States
#                   </h4>
#                  </div>
#                 </div>
#                 <!-- SOUTH AMERICA -->
#                 <!-- <div class="location location--peru">
#             <div class="location__icon"></div>
#             <div class="location-info">
#                 <h4 class="location__name">Lima, Peru</h4>
#             </div>
#         </div> -->
#                 <!-- EUROPE -->
#                 <div class="location location--london">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    London, England
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--paris">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Paris, France
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--munich">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Munich, Germany
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--dublin">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Dublin, Ireland
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--milan">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Milan, Italy
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--luxembourg">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Luxembourg, Luxembourg
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--barcelona">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Barcelona, Spain
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--amsterdam">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Amsterdam, The Netherlands
#                   </h4>
#                  </div>
#                 </div>
#                 <!-- AFRICA -->
#                 <!-- ASIA-PACIFIC -->
#                 <div class="location location--sydney">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name location__name--break">
#                    Sydney, Australia
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--beijing">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Beijing, China
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--shanghai">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Shanghai, China
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--hong-kong">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name location__name--break">
#                    Hong Kong, China
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--mumbai">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Mumbai, India
#                   </h4>
#                  </div>
#                 </div>
#                 <!-- <div class="location location--jakarta">
#             <div class="location__icon"></div>
#             <div class="location-info">
#                 <h4 class="location__name location__name--break">Jakarta, Indonesia</h4>
#             </div>
#         </div> -->
#                 <div class="location location--japan">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Tokyo, Japan
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--singapore">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name location__name--break">
#                    Singapore, Singapore
#                   </h4>
#                  </div>
#                 </div>
#                 <div class="location location--seoul">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name location__name--break">
#                    Seoul, South Korea
#                   </h4>
#                  </div>
#                 </div>
#                 <!-- UEA -->
#                 <div class="location location--dubai">
#                  <div class="location__icon">
#                  </div>
#                  <div class="location-info">
#                   <h4 class="location__name">
#                    Abu Dhabi
#                   </h4>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <p class="text-align-center">
#                <a class="btn white" href="/contact-us-0">
#                 View All Locations
#                </a>
#               </p>
#              </div>
#              <div class="field field--name-field-background-image field--type-entity-reference field--label-hidden field__item">
#               <article class="media media--type-video media--view-mode-background">
#                <div class="field field--name-field-media-video-file field--type-file field--label-visually_hidden">
#                 <div class="field__label visually-hidden">
#                  Video file
#                 </div>
#                 <div class="field__item">
#                  <video autoplay="" data-autoplay="" loop="" muted="" playsinline="" preload="">
#                   <source src="/sites/default/files/2020-03/CG_OurFirm_OurOffices_DotsBacgkround_V1.mp4" type="video/mp4"/>
#                   <p>
#                    Sorry, your browser doesn't support embedded videos
#                   </p>
#                  </video>
#                 </div>
#                </div>
#               </article>
#              </div>
#             </div>
#            </div>
#            <div class="brick brick--type--slide brick--id--131 brick-type--slide foreground-white background-medium_blue has-bg-image slide" data-bkg="medium_blue" data-color="white">
#             <div class="field field--name-field-heading field--type-string field--label-hidden field__item">
#              Our People
#             </div>
#             <div class="slide--content">
#              <div class="clearfix text-formatted field field--name-field-content field--type-text-long field--label-hidden field__item">
#               <div class="columns columns--70_30">
#                <div class="column">
#                 <h2>
#                  Our people make us unique.
#                 </h2>
#                 <p>
#                  The strength of our global team is essential to our success.
#                 </p>
#                </div>
#                <div class="column vertical-link-list">
#                 <h6 class="arrow">
#                  Meet our team
#                 </h6>
#                 <div class="row">
#                  <a class="animate-border" href="/our-people#board-of-directors">
#                   Board of Directors
#                  </a>
#                 </div>
#                 <div class="row">
#                  <a class="animate-border" href="/our-people#leadership-team">
#                   Our Leadership Team
#                  </a>
#                 </div>
#                 <div class="row">
#                  <a class="animate-border" href="/our-people#operating-executives">
#                   Operating Executives &amp; Advisors
#                  </a>
#                 </div>
#                 <div class="row">
#                  <a class="animate-border" href="/our-people#block-views-block-bio-block-1">
#                   Directory
#                  </a>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="field field--name-field-background-image field--type-entity-reference field--label-hidden field__item">
#               <article class="media media--type-video media--view-mode-background">
#                <div class="field field--name-field-media-video-file field--type-file field--label-visually_hidden">
#                 <div class="field__label visually-hidden">
#                  Video file
#                 </div>
#                 <div class="field__item">
#                  <video autoplay="" data-autoplay="" loop="" muted="" playsinline="" preload="">
#                   <source src="/sites/default/files/2020-03/4_CG_Landing_OurPeople.mp4" type="video/mp4"/>
#                   <p>
#                    Sorry, your browser doesn't support embedded videos
#                   </p>
#                  </video>
#                 </div>
#                </div>
#               </article>
#              </div>
#             </div>
#            </div>
# ...
#                 <label class="option" for="edit-sort-bef-combine-search-api-relevance-desc--2">
#                  Most relevant first
#                 </label>
#                </div>
#                <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
#                 <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-created-desc-2" id="edit-sort-bef-combine-created-desc--2" name="sort_bef_combine" type="radio" value="created_DESC"/>
#                 <label class="option" for="edit-sort-bef-combine-created-desc--2">
#                  Newest first
#                 </label>
#                </div>
#                <div class="js-form-item form-item js-form-type-radio form-type-radio js-form-item-sort-bef-combine form-item-sort-bef-combine">
#                 <input class="form-radio" data-drupal-selector="edit-sort-bef-combine-created-asc-2" id="edit-sort-bef-combine-created-asc--2" name="sort_bef_combine" type="radio" value="created_ASC"/>
#                 <label class="option" for="edit-sort-bef-combine-created-asc--2">
#                  Oldest first
#                 </label>
#                </div>
#               </div>
#              </div>
#             </div>
#            </fieldset>
#           </div>
#          </details>
#          <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions--2">
#           <button class="button js-form-submit form-submit" data-drupal-selector="edit-submit-acquia-search-2" id="edit-submit-acquia-search--2" type="submit" value="Search">
#            <span class="visually-hidden">
#             Search
#            </span>
#           </button>
#          </div>
#         </div>
#        </form>
#       </div>
#       <div class="language-switcher-language-url block-carlyle-2020-languageswitcher-section-page block block-language block-language-blocklanguage-interface block-language-block-language-interface" id="block-carlyle-2020-languageswitcher-section-page" role="navigation">
#        <ul class="links">
#         <li class="en is-active" data-drupal-link-system-path="node/32221" hreflang="en">
#          <a class="language-link is-active" data-drupal-link-system-path="node/32221" href="/carlyle-group" hreflang="en">
#           English
#          </a>
#         </li>
#         <li class="ja" data-drupal-link-system-path="node/32221" hreflang="ja">
#          <a class="language-link" data-drupal-link-system-path="node/32221" href="/ja/carlyle-group" hreflang="ja">
#           日本語
#          </a>
#         </li>
#         <li class="zh-hans" data-drupal-link-system-path="node/32221" hreflang="zh-hans">
#          <a class="language-link" data-drupal-link-system-path="node/32221" href="/zh-hans/carlyle-group" hreflang="zh-hans">
#           简体中文
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <footer class="section section--footer">
#      <div class="region region-footer">
#       <nav aria-labelledby="block-carlyle-2020-footer-menu-menu" class="block-carlyle-2020-footer-menu block block-menu navigation menu--footer" id="block-carlyle-2020-footer-menu" role="navigation">
#        <h2 class="visually-hidden" id="block-carlyle-2020-footer-menu-menu">
#         Footer Menu
#        </h2>
#        <ul class="menu">
#         <li class="menu-item menu-item--active-trail">
#          <a class="is-active" data-drupal-link-system-path="&lt;front&gt;" href="/">
#           Home
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/33251" href="/notices-and-disclaimers">
#           Notices &amp; Disclaimers
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/33251" href="/notices-and-disclaimers#notice-regarding-fake-news-and-fraudulent-activity">
#           Phishing and Fraud
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/33251" href="/notices-and-disclaimers#transparency--reporting">
#           Transparency &amp; Reporting
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/33251" href="/notices-and-disclaimers#cookies-policy">
#           Cookies Policy
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/33251" href="/notices-and-disclaimers#privacy-notice">
#           Privacy Notice
#          </a>
#         </li>
#         <li class="menu-item">
#          <a data-drupal-link-system-path="node/33251" href="/notices-and-disclaimers#terms-of-use-policy">
#           Terms of Use Policy
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#      <style>
#       #block-footersocialitemslist-4 .field--name-field-footer-menu {
#       display: flex;
#     align-items: center;
#     gap: 10px;
# }
# #block-footersocialitemslist-4{
#   padding: 5px 10px;
# }
# body.path-frontpage footer #block-footersocialitemslist-4{
#   position: fixed;
#   height: 40px;
#     bottom: 10px;
#     left: 30px;
# }
# footer .section-dark .block-type--footer_social_menu .social-icon {
#     filter: brightness(1) invert(0) !important;
# }
# footer .block-type--footer_social_menu .social-icon {
#     filter: brightness(0) invert(1);
# }
#      </style>
#     </footer>
#    </div>
#   </div>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/32221","currentPathIsAdmin":false,"isFront":true,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"addtoany\/addtoany.front,better_exposed_filters\/general,better_exposed_filters\/select_all_none,carlyle_2020\/global-scripts,carlyle_2020\/global-styling,classy\/base,classy\/file,classy\/messages,classy\/node,core\/drupal.collapse,core\/drupal.form,core\/normalize,core\/picturefill,eu_cookie_compliance\/eu_cookie_compliance_bare,extlink\/drupal.extlink,media\/filter.caption,paragraphs\/drupal.paragraphs.unpublished,system\/base,views\/views.module,webform\/webform.dialog","theme":"carlyle_2020","theme_token":"89RbUssuL9SCLgv6GU0leclnSMRk4raKJnyOQ1cZKZY"},"ajaxTrustedUrl":{"\/search-results":true},"webform":{"dialog":{"options":{"narrow":{"title":"Narrow","width":600},"normal":{"title":"Normal","width":800},"wide":{"title":"Wide","width":1000}},"entity_type":"node","entity_id":"32221"}},"data":{"extlink":{"extTarget":true,"extTargetNoOverride":false,"extNofollow":false,"extNoreferrer":false,"extFollowNoOverride":false,"extClass":"0","extLabel":"(link is external)","extImgClass":false,"extSubdomains":true,"extExclude":"(lightvideo)|(secure|.reportingsystem|carlyle.cn|carlyle.jp)|(ir.carlyle.com)|(youtu.be)|(youtube\\.com)|(carlyle.com)|(cardinalcapitalgroup\\.com)|(facebook\\.com\/onecarlyle)|(twitter\\.com\/onecarlyle)|(linkedin\\.com\/company\/the-carlyle-group)|(instagram\\.com\/onecarlyle\/)","extInclude":"","extCssExclude":"","extCssExplicit":"","extAlert":true,"extAlertText":"This link will take you to an external web site. We are not responsible for their content.","mailtoClass":"0","mailtoLabel":"(link sends email)","extUseFontAwesome":false,"extIconPlacement":"append","extFaLinkClasses":"fa fa-external-link","extFaMailtoClasses":"fa fa-envelope-o","whitelistedDomains":null}},"eu_cookie_compliance":{"cookie_policy_version":"1.0.0","popup_enabled":true,"popup_agreed_enabled":false,"popup_hide_agreed":false,"popup_clicking_confirmation":false,"popup_scrolling_confirmation":false,"popup_html_info":"\u003Cdiv aria-labelledby=\u0022popup-text\u0022  class=\u0022eu-cookie-compliance-banner eu-cookie-compliance-banner-info eu-cookie-compliance-banner--opt-in\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n        \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022 role=\u0022document\u0022\u003E\n      \u003Cp\u003EWe use cookies to enhance your experience on our site. By using our site, you agree to our use of cookies. For more information, see our \u003Ca href=\u0022https:\/\/www.carlyle.com\/cookies-policy\u0022\u003ECookies Policy\u003C\/a\u003E.\u003C\/p\u003E\n          \u003C\/div\u003E\n\n    \n    \u003Cdiv id=\u0022popup-buttons\u0022 class=\u0022eu-cookie-compliance-buttons\u0022\u003E\n            \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button eu-cookie-compliance-secondary-button\u0022\u003EAccept\u003C\/button\u003E\n              \u003Cbutton type=\u0022button\u0022 class=\u0022decline-button eu-cookie-compliance-default-button\u0022\u003EDeny\u003C\/button\u003E\n          \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E","use_mobile_message":false,"mobile_popup_html_info":"\u003Cdiv aria-labelledby=\u0022popup-text\u0022  class=\u0022eu-cookie-compliance-banner eu-cookie-compliance-banner-info eu-cookie-compliance-banner--opt-in\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n        \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022 role=\u0022document\u0022\u003E\n      \n          \u003C\/div\u003E\n\n    \n    \u003Cdiv id=\u0022popup-buttons\u0022 class=\u0022eu-cookie-compliance-buttons\u0022\u003E\n            \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button eu-cook ...
#   </script>
#   <script src="/core/assets/vendor/jquery/jquery.min.js?v=3.6.3">
#   </script>
#   <script src="/core/misc/polyfills/nodelist.foreach.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/polyfills/element.matches.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/polyfills/object.assign.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/css-escape/css.escape.js?v=1.5.1">
#   </script>
#   <script src="/core/assets/vendor/es6-promise/es6-promise.auto.min.js?v=4.2.8">
#   </script>
#   <script src="/core/assets/vendor/once/once.min.js?v=1.0.1">
#   </script>
#   <script src="/core/assets/vendor/jquery-once/jquery.once.min.js?v=2.2.3">
#   </script>
#   <script src="/core/misc/drupalSettingsLoader.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/drupal.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/drupal.init.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/debounce.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/version-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/data-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/disable-selection-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/form-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/jquery-patch-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/scroll-parent-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/unique-id-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/focusable-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/ie-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/keycode-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/plugin-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/safe-active-element-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/safe-blur-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widget-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widgets/controlgroup-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/form-reset-mixin-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/labels-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widgets/mouse-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widgets/checkboxradio-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widgets/draggable-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widgets/resizable-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widgets/button-min.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/jquery.ui/ui/widgets/dialog-min.js?v=9.5.10">
#   </script>
#   <script src="/modules/contrib/jquery_ui/assets/vendor/jquery.ui/ui/version-min.js?v=1.13.2">
#   </script>
#   <script src="/modules/contrib/jquery_ui/assets/vendor/jquery.ui/ui/keycode-min.js?v=1.13.2">
#   </script>
#   <script src="/modules/contrib/jquery_ui/assets/vendor/jquery.ui/ui/unique-id-min.js?v=1.13.2">
#   </script>
#   <script src="/modules/contrib/jquery_ui/assets/vendor/jquery.ui/ui/widget-min.js?v=1.13.2">
#   </script>
#   <script src="/modules/contrib/jquery_ui/assets/vendor/jquery.ui/ui/widgets/accordion-min.js?v=1.13.2">
#   </script>
#   <script src="/core/assets/vendor/picturefill/picturefill.min.js?v=3.0.3">
#   </script>
#   <script src="/core/assets/vendor/tabbable/index.umd.min.js?v=5.3.3">
#   </script>
#   <script async="" src="https://static.addtoany.com/menu/page.js">
#   </script>
#   <script src="/modules/contrib/addtoany/js/addtoany.js?v=9.5.10">
#   </script>
#   <script src="/libraries/fullpage.js/dist/fullpage.extensions.min.js?s4euv4">
#   </script>
#   <script src="/themes/carlyle_2020/dist/js/vendor.js?s4euv4">
#   </script>
#   <script src="/themes/carlyle_2020/src/js/vendor/fullpage.scrollHorizontally.min.js?s4euv4">
#   </script>
#   <script src="/themes/carlyle_2020/dist/js/app.js?s4euv4">
#   </script>
#   <script src="/core/misc/progress.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/jquery.once.bc.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/loadjs/loadjs.min.js?v=4.2.0">
#   </script>
#   <script src="/core/modules/responsive_image/js/responsive_image.ajax.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/ajax.js?v=9.5.10">
#   </script>
#   <script src="/core/themes/stable/js/ajax.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/displace.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/jquery.tabbable.shim.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/position.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/dialog/dialog.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/dialog/dialog.position.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/dialog/dialog.jquery-ui.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/dialog/dialog.ajax.js?v=9.5.10">
#   </script>
#   <script src="/modules/contrib/webform/js/webform.drupal.dialog.js?v=9.5.10">
#   </script>
#   <script src="/modules/contrib/webform/js/webform.dialog.js?v=9.5.10">
#   </script>
#   <script src="/modules/contrib/extlink/extlink.js?v=9.5.10">
#   </script>
#   <script src="/core/assets/vendor/js-cookie/js.cookie.min.js?v=3.0.1">
#   </script>
#   <script defer="" src="/modules/contrib/eu_cookie_compliance/js/eu_cookie_compliance.min.js?v=9.5.10">
#   </script>
#   <script src="/modules/contrib/better_exposed_filters/js/better_exposed_filters.js?v=4.x">
#   </script>
#   <script src="/modules/contrib/better_exposed_filters/js/bef_select_all_none.js?v=4.x">
#   </script>
#   <script src="/core/misc/form.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/details-summarized-content.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/details-aria.js?v=9.5.10">
#   </script>
#   <script src="/core/misc/collapse.js?v=9.5.10">
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"abf569a42c","applicationID":"65780628","transactionName":"M1ZbZBFZCxcFVk1QVwoceFMXUQoKS0VYXl07UFhTC10=","queueTime":4,"applicationTime":58,"atts":"HxFYEllDGBk=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %% [markdown]
# I dind't develop so much si option as it has too much noise and i don't know if it could be neccesary to analize all that info to extract some value data from this
